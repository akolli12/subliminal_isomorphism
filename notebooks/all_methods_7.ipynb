# %% [markdown]
# # All 8 extraction algorithms
#
# Same τ and τ_log build as `raw_vs_log.ipynb`, plus four **aggregate** methods that use the entire (i, v) slice of τ instead of picking one witness coordinate.
#
# **Single-witness methods** (use one $(i_j, v_j)$ per $j$):
# 1. max-spread + raw cost
# 2. max-min spread + raw cost  (top1 − top2 margin)
# 3. max-spread + log cost
# 4. max-min spread + log cost
#
# **Aggregate methods** (use all $n^2$ cells in the (i, v) slice — no witness needed):
# 5. aggregate L2  + log cost   ←  paper's choice (Assumption `positional-leakage`)
# 6. aggregate L1  + log cost
# 7. aggregate L∞  + log cost
# 8. aggregate L2  + raw cost
#
# All eight methods report top-1 / top-N / mean rank, plus a union row.

# %%
import sys, random, itertools
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import linear_sum_assignment

import config
from model import TinyTransformer

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
N = config.N
EPS = 1e-12
print(f'N = {N}, device = {DEVICE}')
# Out:
# N = 7, device = cuda

# %%
CHECKPOINT = PROJECT_ROOT / 'checkpoints' / 'model_10000_7.pt'

def load_model(path):
    m = TinyTransformer().to(DEVICE)
    m.load_state_dict(torch.load(path, map_location=DEVICE))
    m.eval()
    return m

model = load_model(CHECKPOINT)
print(f'Loaded {CHECKPOINT.name}')
# Out:
# Loaded model_10000_7.pt
# /home/akash10/miniconda3/envs/aug-spm/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /tmp/ipykernel_702800/1577372277.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   m.load_state_dict(torch.load(path, map_location=DEVICE))

# %%
@torch.no_grad()
def sample_psi_unconstrained(model, phis):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    psi_start = config.PSI.start
    psi_buf = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    seq = torch.cat([phis.to(DEVICE), psi_buf], dim=1)
    for j in range(N):
        logits = model(seq)
        step_logits = logits[:, psi_start - 1 + j, :]
        probs = F.softmax(step_logits, dim=-1)
        sampled = torch.multinomial(probs, num_samples=1).squeeze(-1)
        seq[:, psi_start + j] = sampled
    return seq[:, psi_start:psi_start + N]

def is_perm_rows(samples, n):
    sorted_, _ = torch.sort(samples, dim=1)
    expected = torch.arange(n, device=samples.device).unsqueeze(0).expand_as(sorted_)
    return (sorted_ == expected).all(dim=1)

@torch.no_grad()
def sample_psi_rejection(model, phis, max_attempts=200):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    phis = phis.to(DEVICE)
    out     = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    pending = torch.ones(B,        dtype=torch.bool, device=DEVICE)
    for _ in range(max_attempts):
        idx = torch.nonzero(pending, as_tuple=False).squeeze(1)
        if idx.numel() == 0:
            break
        psis_try = sample_psi_unconstrained(model, phis[idx])
        valid = is_perm_rows(psis_try, N)
        out[idx[valid]] = psis_try[valid]
        pending[idx[valid]] = False
    if pending.any():
        raise RuntimeError(
            f'{int(pending.sum().item())} rows still invalid after {max_attempts} attempts'
        )
    return out

def marginal_matrix(samples, n=N):
    return F.one_hot(samples.long(), n).float().mean(dim=0)

def random_phis_with_constraint(B, j, u, n=N, seed=None):
    g = torch.Generator()
    if seed is not None: g.manual_seed(seed)
    other_positions = torch.tensor([i for i in range(n) if i != j], dtype=torch.long)
    other_values    = torch.tensor([v for v in range(n) if v != u], dtype=torch.long)
    keys = torch.rand((B, n - 1), generator=g)
    perms = keys.argsort(dim=1)
    perm_values = other_values[perms]
    out = torch.zeros((B, n), dtype=torch.long)
    out[:, j] = u
    out[:, other_positions] = perm_values
    return out

# %%
def best_assignment(C):
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    row_ind, col_ind = linear_sum_assignment(C_np)
    return torch.tensor(col_ind, dtype=torch.long), float(C_np[row_ind, col_ind].sum())

def top_k_assignments(C, k=None):
    n = C.shape[0]
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    rows = np.arange(n)
    scored = [
        (C_np[rows, list(perm)].sum(), perm)
        for perm in itertools.permutations(range(n))
    ]
    scored.sort(key=lambda x: x[0])
    if k is not None:
        scored = scored[:k]
    return [(torch.tensor(p, dtype=torch.long), float(c)) for c, p in scored]

# %% [markdown]
# ## Build τ and τ_log
#
# K1 phis per (j, u); K2 psis per phi. Per-phi marginal computed first, then both raw average and log-then-average over the K1 phis.

# %%
tau     = {}
tau_log = {}

seed = 42
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

K1 = 2**9      # phis per (j, u)
K2 = 2**9         # psis per phi (large to keep log-bias small)
CHUNK = 2**17     # rows per model.forward call

for j in range(N):
    for u in range(N):
        phis = random_phis_with_constraint(K1, j=j, u=u)
        sum_p     = torch.zeros((N, N), device=DEVICE)
        sum_log_p = torch.zeros((N, N), device=DEVICE)

        if K2 <= CHUNK:
            phi_chunk = max(1, CHUNK // K2)
            psi_subchunk = K2
        else:
            phi_chunk = 1
            psi_subchunk = CHUNK

        for phi_start in range(0, K1, phi_chunk):
            P = min(phi_chunk, K1 - phi_start)
            this_phis = phis[phi_start:phi_start + P]
            counts = torch.zeros((P, N, N), device=DEVICE)
            for psi_start in range(0, K2, psi_subchunk):
                S = min(psi_subchunk, K2 - psi_start)
                phi_rep = this_phis.repeat_interleave(S, dim=0)
                psis    = sample_psi_rejection(model, phi_rep)
                psis    = psis.view(P, S, N)
                counts += F.one_hot(psis.long(), N).float().sum(dim=1)
            M_per_phi = counts / K2
            sum_p     += M_per_phi.sum(dim=0)
            sum_log_p += torch.log(M_per_phi.clamp_min(EPS)).sum(dim=0)

        avg_p     = sum_p / K1
        avg_log_p = sum_log_p / K1
        for i in range(N):
            for v in range(N):
                tau[(i, j, v, u)]     = avg_p[i, v]
                tau_log[(i, j, v, u)] = avg_log_p[i, v]
        print(f'  cell (j={j}, u={u}) done')
# Out:
#   cell (j=0, u=0) done
#   cell (j=0, u=1) done
#   cell (j=0, u=2) done
#   cell (j=0, u=3) done

# %%
tau
# Out:
# {(0, 0, 0, 0): tensor(0.0686, device='cuda:0'),
#  (0, 0, 1, 0): tensor(0.2701, device='cuda:0'),
#  (0, 0, 2, 0): tensor(0.3215, device='cuda:0'),
#  (0, 0, 3, 0): tensor(0.0324, device='cuda:0'),
#  (0, 0, 4, 0): tensor(0.0719, device='cuda:0'),
#  (0, 0, 5, 0): tensor(0.2355, device='cuda:0'),
#  (1, 0, 0, 0): tensor(0.1833, device='cuda:0'),
#  (1, 0, 1, 0): tensor(0.2172, device='cuda:0'),
#  (1, 0, 2, 0): tensor(0.2515, device='cuda:0'),
#  (1, 0, 3, 0): tensor(0.1328, device='cuda:0'),
#  (1, 0, 4, 0): tensor(0.1828, device='cuda:0'),
#  (1, 0, 5, 0): tensor(0.0322, device='cuda:0'),
#  (2, 0, 0, 0): tensor(0.1256, device='cuda:0'),
#  (2, 0, 1, 0): tensor(0.0868, device='cuda:0'),
#  (2, 0, 2, 0): tensor(0.1784, device='cuda:0'),
#  (2, 0, 3, 0): tensor(0.1798, device='cuda:0'),
#  (2, 0, 4, 0): tensor(0.1927, device='cuda:0'),
#  (2, 0, 5, 0): tensor(0.2367, device='cuda:0'),
#  (3, 0, 0, 0): tensor(0.1154, device='cuda:0'),
#  (3, 0, 1, 0): tensor(0.1105, device='cuda:0'),
#  (3, 0, 2, 0): tensor(0.1665, device='cuda:0'),
#  (3, 0, 3, 0): tensor(0.1555, device='cuda:0'),
#  (3, 0, 4, 0): tensor(0.2052, device='cuda:0'),
#  (3, 0, 5, 0): tensor(0.2470, device='cuda:0'),
#  (4, 0, 0, 0): tensor(0.2262, device='cuda:0'),
#  (4, 0, 1, 0): tensor(0.1689, device='cuda:0'),
#  (4, 0, 2, 0): tensor(0.0461, device='cuda:0'),
#  (4, 0, 3, 0): tensor(0.2710, device='cuda:0'),
#  (4, 0, 4, 0): tensor(0.1374, device='cuda:0'),
#  (4, 0, 5, 0): tensor(0.1503, device='cuda:0'),
#  (5, 0, 0, 0): tensor(0.2807, device='cuda:0'),
#  (5, 0, 1, 0): tensor(0.1465, device='cuda:0'),
#  (5, 0, 2, 0): tensor(0.0361, device='cuda:0'),
#  (5, 0, 3, 0): tensor(0.2285, device='cuda:0'),
#  (5, 0, 4, 0): tensor(0.2099, device='cuda:0'),
#  (5, 0, 5, 0): tensor(0.0983, device='cuda:0'),
#  (0, 0, 0, 1): tensor(0.0205, device='cuda:0'),
#  (0, 0, 1, 1): tensor(0.0952, device='cuda:0'),
#  (0, 0, 2, 1): tensor(0.3925, device='cuda:0'),
#  (0, 0, 3, 1): tensor(0.1492, device='cuda:0'),
#  (0, 0, 4, 1): tensor(0.0978, device='cuda:0'),
#  (0, 0, 5, 1): tensor(0.2448, device='cuda:0'),
#  (1, 0, 0, 1): tensor(0.1376, device='cuda:0'),
#  (1, 0, 1, 1): tensor(0.2440, device='cuda:0'),
#  (1, 0, 2, 1): tensor(0.1448, device='cuda:0'),
#  (3, 0, 2, 2): tensor(0.1505, device='cuda:0'),
#  (3, 0, 3, 2): tensor(0.1209, device='cuda:0'),
#  (3, 0, 4, 2): tensor(0.1302, device='cuda:0'),
#  (3, 0, 5, 2): tensor(0.2552, device='cuda:0'),
#  (4, 0, 0, 2): tensor(0.1548, device='cuda:0'),
#  (4, 0, 1, 2): tensor(0.1448, device='cuda:0'),
#  (4, 0, 2, 2): tensor(0.1766, device='cuda:0'),
#  (4, 0, 3, 2): tensor(0.2059, device='cuda:0'),
#  (4, 0, 4, 2): tensor(0.2181, device='cuda:0'),
#  (4, 0, 5, 2): tensor(0.0998, device='cuda:0'),
#  (5, 0, 0, 2): tensor(0.2254, device='cuda:0'),
#  (5, 0, 1, 2): tensor(0.2878, device='cuda:0'),
#  (5, 0, 2, 2): tensor(0.0477, device='cuda:0'),
#  (5, 0, 3, 2): tensor(0.2078, device='cuda:0'),
#  (5, 0, 4, 2): tensor(0.0606, device='cuda:0'),
#  (5, 0, 5, 2): tensor(0.1708, device='cuda:0'),
#  (0, 0, 0, 3): tensor(0.1189, device='cuda:0'),
#  (0, 0, 1, 3): tensor(0.1508, device='cuda:0'),
#  (0, 0, 2, 3): tensor(0.1690, device='cuda:0'),
#  (0, 0, 3, 3): tensor(0.0723, device='cuda:0'),
#  (0, 0, 4, 3): tensor(0.2225, device='cuda:0'),
#  (0, 0, 5, 3): tensor(0.2665, device='cuda:0'),
#  (1, 0, 0, 3): tensor(0.2745, device='cuda:0'),
#  (1, 0, 1, 3): tensor(0.1316, device='cuda:0'),
#  (1, 0, 2, 3): tensor(0.1604, device='cuda:0'),
#  (1, 0, 3, 3): tensor(0.1636, device='cuda:0'),
#  (1, 0, 4, 3): tensor(0.1117, device='cuda:0'),
#  (1, 0, 5, 3): tensor(0.1582, device='cuda:0'),
#  (2, 0, 0, 3): tensor(0.2492, device='cuda:0'),
#  (2, 0, 1, 3): tensor(0.1410, device='cuda:0'),
#  (2, 0, 2, 3): tensor(0.1220, device='cuda:0'),
#  (2, 0, 3, 3): tensor(0.0924, device='cuda:0'),
#  (2, 0, 4, 3): tensor(0.1555, device='cuda:0'),
#  (2, 0, 5, 3): tensor(0.2399, device='cuda:0'),
#  (3, 0, 0, 3): tensor(0.0578, device='cuda:0'),
#  (3, 0, 1, 3): tensor(0.1151, device='cuda:0'),
#  (3, 0, 2, 3): tensor(0.2328, device='cuda:0'),
#  (3, 0, 3, 3): tensor(0.1747, device='cuda:0'),
#  (3, 0, 4, 3): tensor(0.2797, device='cuda:0'),
#  (3, 0, 5, 3): tensor(0.1398, device='cuda:0'),
#  (4, 0, 0, 3): tensor(0.1400, device='cuda:0'),
#  (4, 0, 1, 3): tensor(0.1855, device='cuda:0'),
#  (4, 0, 2, 3): tensor(0.1511, device='cuda:0'),
#  (4, 0, 3, 3): tensor(0.2866, device='cuda:0'),
#  (4, 0, 4, 3): tensor(0.1732, device='cuda:0'),
#  (4, 0, 5, 3): tensor(0.0636, device='cuda:0'),
#  (5, 0, 0, 3): tensor(0.1595, device='cuda:0'),
#  (5, 0, 1, 3): tensor(0.2760, device='cuda:0'),
#  (5, 0, 2, 3): tensor(0.1647, device='cuda:0'),
#  (5, 0, 3, 3): tensor(0.2104, device='cuda:0'),
#  (5, 0, 4, 3): tensor(0.0573, device='cuda:0'),
#  (5, 0, 5, 3): tensor(0.1320, device='cuda:0'),
#  (0, 0, 0, 4): tensor(0.1280, device='cuda:0'),
#  (0, 0, 1, 4): tensor(0.0543, device='cuda:0'),
#  (0, 0, 2, 4): tensor(0.2066, device='cuda:0'),
#  (0, 0, 3, 4): tensor(0.1001, device='cuda:0'),
#  (0, 0, 4, 4): tensor(0.2772, device='cuda:0'),
#  (0, 0, 5, 4): tensor(0.2338, device='cuda:0'),
#  (1, 0, 0, 4): tensor(0.2151, device='cuda:0'),
#  (1, 0, 1, 4): tensor(0.1393, device='cuda:0'),
#  (1, 0, 2, 4): tensor(0.2188, device='cuda:0'),
#  (1, 0, 3, 4): tensor(0.2177, device='cuda:0'),
#  (1, 0, 4, 4): tensor(0.0658, device='cuda:0'),
#  (1, 0, 5, 4): tensor(0.1432, device='cuda:0'),
#  (2, 0, 0, 4): tensor(0.2109, device='cuda:0'),
#  (2, 0, 1, 4): tensor(0.1481, device='cuda:0'),
#  (2, 0, 2, 4): tensor(0.0971, device='cuda:0'),
#  (2, 0, 3, 4): tensor(0.2133, device='cuda:0'),
#  (2, 0, 4, 4): tensor(0.1954, device='cuda:0'),
#  (2, 0, 5, 4): tensor(0.1352, device='cuda:0'),
#  (3, 0, 0, 4): tensor(0.1333, device='cuda:0'),
#  (3, 0, 1, 4): tensor(0.1654, device='cuda:0'),
#  (3, 0, 2, 4): tensor(0.1812, device='cuda:0'),
#  (3, 0, 3, 4): tensor(0.1882, device='cuda:0'),
#  (3, 0, 4, 4): tensor(0.0789, device='cuda:0'),
#  (3, 0, 5, 4): tensor(0.2531, device='cuda:0'),
#  (4, 0, 0, 4): tensor(0.1626, device='cuda:0'),
#  (4, 0, 1, 4): tensor(0.3190, device='cuda:0'),
#  (4, 0, 2, 4): tensor(0.2105, device='cuda:0'),
#  (4, 0, 3, 4): tensor(0.1110, device='cuda:0'),
#  (4, 0, 4, 4): tensor(0.1022, device='cuda:0'),
#  (4, 0, 5, 4): tensor(0.0946, device='cuda:0'),
#  (5, 0, 0, 4): tensor(0.1501, device='cuda:0'),
#  (5, 0, 1, 4): tensor(0.1739, device='cuda:0'),
#  (5, 0, 2, 4): tensor(0.0858, device='cuda:0'),
#  (5, 0, 3, 4): tensor(0.1697, device='cuda:0'),
#  (5, 0, 4, 4): tensor(0.2804, device='cuda:0'),
#  (5, 0, 5, 4): tensor(0.1401, device='cuda:0'),
#  (0, 0, 0, 5): tensor(0.0709, device='cuda:0'),
#  (0, 0, 1, 5): tensor(0.1141, device='cuda:0'),
#  (0, 0, 2, 5): tensor(0.1768, device='cuda:0'),
#  (0, 0, 3, 5): tensor(0.2052, device='cuda:0'),
#  (0, 0, 4, 5): tensor(0.2822, device='cuda:0'),
#  (0, 4, 5, 3): tensor(0.1757, device='cuda:0'),
#  (1, 4, 0, 3): tensor(0.1842, device='cuda:0'),
#  (1, 4, 1, 3): tensor(0.1545, device='cuda:0'),
#  (1, 4, 2, 3): tensor(0.1578, device='cuda:0'),
#  (1, 4, 3, 3): tensor(0.1585, device='cuda:0'),
#  (1, 4, 4, 3): tensor(0.1712, device='cuda:0'),
#  (1, 4, 5, 3): tensor(0.1738, device='cuda:0'),
#  (2, 4, 0, 3): tensor(0.2355, device='cuda:0'),
#  (2, 4, 1, 3): tensor(0.1726, device='cuda:0'),
#  (2, 4, 2, 3): tensor(0.1495, device='cuda:0'),
#  (2, 4, 3, 3): tensor(0.1130, device='cuda:0'),
#  (2, 4, 4, 3): tensor(0.1548, device='cuda:0'),
#  (2, 4, 5, 3): tensor(0.1747, device='cuda:0'),
#  (3, 4, 0, 3): tensor(0.1379, device='cuda:0'),
#  (3, 4, 1, 3): tensor(0.1205, device='cuda:0'),
#  (3, 4, 2, 3): tensor(0.1619, device='cuda:0'),
#  (3, 4, 3, 3): tensor(0.1627, device='cuda:0'),
#  (3, 4, 4, 3): tensor(0.2108, device='cuda:0'),
#  (3, 4, 5, 3): tensor(0.2063, device='cuda:0'),
#  (4, 4, 0, 3): tensor(0.1916, device='cuda:0'),
#  (4, 4, 1, 3): tensor(0.2540, device='cuda:0'),
#  (4, 4, 2, 3): tensor(0.1439, device='cuda:0'),
#  (4, 4, 3, 3): tensor(0.1615, device='cuda:0'),
#  ...}

# %% [markdown]
# ## Tensorize τ and τ_log for the aggregate methods
#
# Build dense `(N, N, N, N)` tensors on DEVICE so the aggregate cost reduces to one broadcast subtract + reduce over `(i, v)` — no per-cell Python loops.

# %%
def to_tensor(tau_dict):
    """Pack {(i, j, v, u): scalar} → tensor of shape (N, N, N, N) indexed [i, j, v, u]."""
    T = torch.zeros((N, N, N, N), device=DEVICE)
    for i in range(N):
        for j in range(N):
            for v in range(N):
                for u in range(N):
                    T[i, j, v, u] = tau_dict[(i, j, v, u)]
    return T

tau_tensor     = to_tensor(tau)
tau_log_tensor = to_tensor(tau_log)
print(f'tau_tensor    : {tuple(tau_tensor.shape)}, device={tau_tensor.device}')
print(f'tau_log_tensor: {tuple(tau_log_tensor.shape)}, device={tau_log_tensor.device}')
# Out:
# tau_tensor    : (6, 6, 6, 6), device=cuda:0
# tau_log_tensor: (6, 6, 6, 6), device=cuda:0

# %% [markdown]
# ## Pick witnesses (for the four single-witness methods)

# %%
def pick_witnesses(tau_dict):
    """Return (opts_max_spread, opts_max_min_spread): each {j: (i_j, v_j)}."""
    opts_ms, opts_mm = {}, {}
    for j in range(N):
        scores_ms = torch.zeros((N, N))
        scores_mm = torch.zeros((N, N))
        for i in range(N):
            for v in range(N):
                u_func = torch.tensor([tau_dict[(i, j, v, u)].item()
                                       if torch.is_tensor(tau_dict[(i, j, v, u)])
                                       else tau_dict[(i, j, v, u)]
                                       for u in range(N)])
                scores_ms[i, v] = u_func.max() - u_func.min()
                sorted_, _ = torch.sort(u_func, descending=True)
                scores_mm[i, v] = sorted_[0] - sorted_[1]
        i_ms = (scores_ms.argmax() // N).item(); v_ms = (scores_ms.argmax() % N).item()
        i_mm = (scores_mm.argmax() // N).item(); v_mm = (scores_mm.argmax() % N).item()
        opts_ms[j], opts_mm[j] = (i_ms, v_ms), (i_mm, v_mm)
    return opts_ms, opts_mm

opts_max_spread,     opts_max_min_spread     = pick_witnesses(tau)
opts_max_spread_log, opts_max_min_spread_log = pick_witnesses(tau_log)

print('raw — opts_max_spread:    ', opts_max_spread)
print('raw — opts_max_min_spread:', opts_max_min_spread)
print('log — opts_max_spread:    ', opts_max_spread_log)
print('log — opts_max_spread:    ', opts_max_min_spread_log)
# Out:
# raw — opts_max_spread:     {0: (0, 2), 1: (1, 0), 2: (0, 2), 3: (4, 2), 4: (2, 4), 5: (0, 4)}
# raw — opts_max_min_spread: {0: (4, 1), 1: (1, 4), 2: (1, 5), 3: (2, 5), 4: (3, 1), 5: (0, 0)}
# log — opts_max_spread:     {0: (0, 1), 1: (3, 0), 2: (1, 1), 3: (4, 2), 4: (0, 0), 5: (0, 4)}
# log — opts_max_spread:     {0: (0, 1), 1: (1, 5), 2: (1, 1), 3: (2, 5), 4: (3, 1), 5: (2, 1)}

# %% [markdown]
# ## Extract over all permutations — all 8 methods
#
# For each test phi:
# 1. Sample `B` psis (chunked by `B_CHUNK`); compute `mm` and `log_mm`.
# 2. For each of the 8 methods, build cost matrix `C[j, u]`, run brute-force ranking, record rank of truth.
# 3. Track top-1 / top-N / mean rank per method, plus union (any method).
#
# **Cost matrix construction by method `kind`:**
# - `raw` — single witness, raw scale: `C[j,u] = |τ[i_j,j,v_j,u] - mm[i_j,v_j]|`
# - `log` — single witness, log scale: `C[j,u] = |τ_log[i_j,j,v_j,u] - log_mm[i_j,v_j]|`
# - `agg_l2_log` / `agg_l1_log` / `agg_linf_log` — aggregate over (i, v) of `|log_mm - τ_log[:, j, :, u]|` under L2 / L1 / L∞
# - `agg_l2_raw` — same but raw: aggregate L2 of `|mm - τ[:, j, :, u]|`

# %%
B = K2                                                 # psi samples per test phi
B_CHUNK = CHUNK                                           # forward-pass batch size
permutations = list(itertools.permutations(range(N)))

seed = 0
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

# (witness_dict_or_None, tau_dict_or_None, kind)
METHODS = {
    'max-min raw':       (opts_max_min_spread,     tau,     'raw'),
    'max     raw':       (opts_max_spread,         tau,     'raw'),
    'max-min log':       (opts_max_min_spread_log, tau_log, 'log'),
    'max     log':       (opts_max_spread_log,     tau_log, 'log'),
    'aggregate L2  log': (None, None, 'agg_l2_log'),
    'aggregate L1  log': (None, None, 'agg_l1_log'),
    'aggregate L\u221E  log': (None, None, 'agg_linf_log'),
    'aggregate L2  raw': (None, None, 'agg_l2_log'),
    'aggregate L1  raw': (None, None, 'agg_l1_raw'),
    'aggregate L\u221E  raw': (None, None, 'agg_linf_raw'),
}

ranks = {m: [] for m in METHODS}
top1  = {m: 0  for m in METHODS}
topN  = {m: 0  for m in METHODS}
union_top1 = 0
union_topN = 0

def build_cost(kind, opts_dict, tau_dict, mm, log_mm):
    """Return (N, N) cost matrix on CPU."""
    if kind == 'raw':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            p_j = mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - p_j)
        return C
    if kind == 'log':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            lp_j = log_mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - lp_j)
        return C

    # aggregate methods: broadcast (N, N) test marginal vs. (N, N, N, N) tau tensor
    if kind == 'agg_l2_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    if kind == 'agg_l2_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    raise ValueError(f'unknown kind: {kind}')

for permutation in permutations:
    base = torch.tensor(permutation, device=DEVICE).long()
    counts = torch.zeros((N, N), device=DEVICE)
    for start in range(0, B, B_CHUNK):
        S = min(B_CHUNK, B - start)
        perm_rep = base.unsqueeze(0).expand(S, -1).contiguous()
        psis = sample_psi_rejection(model, perm_rep)
        counts += F.one_hot(psis.long(), N).float().sum(dim=0)
    mm     = counts / B
    log_mm = torch.log(mm.clamp_min(EPS))

    truth_tup = tuple(permutation)
    print(f'truth = {truth_tup}')
    iter_in_top1 = iter_in_topN = False

    for name, (opts_dict, tau_dict, kind) in METHODS.items():
        C = build_cost(kind, opts_dict, tau_dict, mm, log_mm)
        full   = top_k_assignments(C, k=None)
        top_N  = full[:N]
        rank   = next(i + 1 for i, (p, _) in enumerate(full) if tuple(p.tolist()) == truth_tup)
        in_top = rank <= N
        ranks[name].append(rank)
        if rank == 1:
            top1[name] += 1
            iter_in_top1 = True
        if in_top:
            topN[name] += 1
            iter_in_topN = True
        print(f'  {name:<22}  best={full[0][0].tolist()} (cost {full[0][1]:.4f})  '
              f'rank={rank}/{len(permutations)}  in-top-{N}={in_top}')
    if iter_in_top1: union_top1 += 1
    if iter_in_topN: union_topN += 1
    print()
# Out:
# truth = (0, 1, 2, 3, 4, 5)
#   max-min raw             best=[5, 3, 2, 1, 4, 0] (cost 1.7438)  rank=292/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.5629)  rank=125/720  in-top-6=False
#   max-min log             best=[0, 2, 3, 1, 4, 5] (cost 59.2282)  rank=276/720  in-top-6=False
#   max     log             best=[0, 1, 4, 2, 3, 5] (cost 45.5943)  rank=73/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 3, 2, 5, 4] (cost 436.8802)  rank=26/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 3, 2, 5, 4] (cost 2526.5706)  rank=27/720  in-top-6=False
#   aggregate L∞  log       best=[0, 3, 1, 2, 5, 4] (cost 106.6442)  rank=76/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 3, 2, 5, 4] (cost 436.8802)  rank=26/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 2, 5, 4, 3] (cost 52.1239)  rank=16/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 3, 2, 1, 5, 4] (cost 4.8083)  rank=20/720  in-top-6=False
#
# truth = (0, 1, 2, 3, 5, 4)
#   max-min raw             best=[5, 1, 2, 4, 3, 0] (cost 0.4589)  rank=125/720  in-top-6=False
#   max     raw             best=[2, 1, 3, 0, 4, 5] (cost 0.4822)  rank=439/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 1, 5, 3] (cost 54.4018)  rank=66/720  in-top-6=False
#   max     log             best=[0, 4, 2, 1, 3, 5] (cost 45.9868)  rank=17/720  in-top-6=False
#   aggregate L2  log       best=[0, 3, 2, 1, 5, 4] (cost 408.8002)  rank=46/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 4, 1, 5, 3] (cost 2359.8955)  rank=77/720  in-top-6=False
#   aggregate L∞  log       best=[2, 1, 4, 0, 5, 3] (cost 104.1864)  rank=66/720  in-top-6=False
#   aggregate L2  raw       best=[0, 3, 2, 1, 5, 4] (cost 408.8002)  rank=46/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 3, 2, 5, 4] (cost 33.2610)  rank=3/720  in-top-6=True
#   aggregate L∞  raw       best=[0, 3, 2, 1, 5, 4] (cost 3.6507)  rank=11/720  in-top-6=False
#
# truth = (0, 1, 2, 4, 3, 5)
#   max-min raw             best=[5, 3, 2, 1, 4, 0] (cost 1.9157)  rank=217/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6371)  rank=269/720  in-top-6=False
#   max-min log             best=[0, 2, 3, 1, 4, 5] (cost 59.3180)  rank=165/720  in-top-6=False
#   max     log             best=[0, 4, 1, 2, 3, 5] (cost 52.7104)  rank=106/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 2, 3, 5] (cost 471.3514)  rank=99/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2749.0503)  rank=73/720  in-top-6=False
#   aggregate L∞  log       best=[3, 0, 1, 2, 4, 5] (cost 111.4743)  rank=303/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 2, 3, 5] (cost 471.3514)  rank=99/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 2, 5, 4, 3] (cost 57.2801)  rank=38/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 3, 2, 1, 4, 5] (cost 5.2227)  rank=22/720  in-top-6=False
#
# truth = (0, 1, 2, 4, 5, 3)
#   max-min raw             best=[0, 1, 4, 3, 5, 2] (cost 0.6315)  rank=29/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.0305)  rank=143/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 4, 1, 3] (cost 49.2198)  rank=14/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 46.9940)  rank=4/720  in-top-6=True
#   aggregate L2  log       best=[2, 5, 4, 1, 0, 3] (cost 405.8225)  rank=15/720  in-top-6=False
#   aggregate L1  log       best=[2, 5, 4, 1, 0, 3] (cost 2347.8511)  rank=17/720  in-top-6=False
#   aggregate L∞  log       best=[5, 1, 2, 0, 4, 3] (cost 102.2854)  rank=8/720  in-top-6=False
#   aggregate L2  raw       best=[2, 5, 4, 1, 0, 3] (cost 405.8225)  rank=15/720  in-top-6=False
#   aggregate L1  raw       best=[1, 4, 5, 2, 0, 3] (cost 30.3960)  rank=123/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 4, 2, 5, 3, 1] (cost 3.1071)  rank=170/720  in-top-6=False
#
# truth = (0, 1, 2, 5, 3, 4)
#   max-min raw             best=[3, 1, 5, 2, 4, 0] (cost 0.4749)  rank=36/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.3520)  rank=246/720  in-top-6=False
#   max-min log             best=[0, 3, 2, 5, 1, 4] (cost 47.6379)  rank=17/720  in-top-6=False
#   max     log             best=[0, 5, 2, 4, 3, 1] (cost 46.8767)  rank=9/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 4, 2, 5, 3] (cost 408.3788)  rank=131/720  in-top-6=False
#   aggregate L1  log       best=[0, 5, 4, 1, 2, 3] (cost 2365.9463)  rank=170/720  in-top-6=False
#   aggregate L∞  log       best=[4, 1, 2, 0, 5, 3] (cost 102.6130)  rank=422/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 4, 2, 5, 3] (cost 408.3788)  rank=131/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 5, 2, 3, 4] (cost 32.1751)  rank=5/720  in-top-6=True
#   aggregate L∞  raw       best=[1, 3, 2, 4, 5, 0] (cost 2.9317)  rank=242/720  in-top-6=False
#
# truth = (0, 1, 2, 5, 4, 3)
#   max-min raw             best=[4, 1, 2, 5, 3, 0] (cost 1.1028)  rank=36/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.1682)  rank=43/720  in-top-6=False
#   max-min log             best=[0, 3, 2, 5, 1, 4] (cost 53.8054)  rank=95/720  in-top-6=False
#   max     log             best=[0, 5, 2, 4, 1, 3] (cost 55.3917)  rank=2/720  in-top-6=True
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 391.3658)  rank=12/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 4, 1, 5, 3] (cost 2261.9263)  rank=21/720  in-top-6=False
#   aggregate L∞  log       best=[0, 2, 4, 5, 1, 3] (cost 100.3394)  rank=3/720  in-top-6=True
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 391.3658)  rank=12/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 5, 4, 3, 2] (cost 36.8417)  rank=11/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 1, 4, 0, 2, 3] (cost 3.8922)  rank=5/720  in-top-6=True
#
# truth = (0, 1, 3, 2, 4, 5)
#   max-min raw             best=[4, 1, 5, 2, 3, 0] (cost 1.0807)  rank=138/720  in-top-6=False
#   max     raw             best=[0, 1, 2, 3, 4, 5] (cost 0.4381)  rank=2/720  in-top-6=True
#   max-min log             best=[0, 4, 3, 1, 2, 5] (cost 55.1579)  rank=107/720  in-top-6=False
#   max     log             best=[0, 5, 4, 2, 1, 3] (cost 55.7437)  rank=59/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 3, 2, 5, 4] (cost 420.8204)  rank=14/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 3, 2, 5, 4] (cost 2462.4446)  rank=17/720  in-top-6=False
#   aggregate L∞  log       best=[0, 3, 1, 2, 5, 4] (cost 102.4852)  rank=9/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 3, 2, 5, 4] (cost 420.8204)  rank=14/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 5, 2, 3, 4] (cost 32.6659)  rank=14/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 1, 4, 2, 3, 5] (cost 4.1410)  rank=31/720  in-top-6=False
#
# truth = (0, 1, 3, 2, 5, 4)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.3746)  rank=401/720  in-top-6=False
#   max     raw             best=[3, 4, 0, 2, 1, 5] (cost 0.9567)  rank=67/720  in-top-6=False
#   max-min log             best=[0, 1, 3, 2, 4, 5] (cost 64.2985)  rank=6/720  in-top-6=True
#   max     log             best=[0, 1, 4, 2, 3, 5] (cost 48.5743)  rank=6/720  in-top-6=True
#   aggregate L2  log       best=[0, 1, 3, 2, 5, 4] (cost 444.9200)  rank=1/720  in-top-6=True
#   aggregate L1  log       best=[0, 1, 3, 2, 5, 4] (cost 2597.1726)  rank=1/720  in-top-6=True
#   aggregate L∞  log       best=[0, 1, 3, 2, 5, 4] (cost 105.5333)  rank=1/720  in-top-6=True
#   aggregate L2  raw       best=[0, 1, 3, 2, 5, 4] (cost 444.9200)  rank=1/720  in-top-6=True
#   aggregate L1  raw       best=[0, 1, 3, 2, 5, 4] (cost 44.5182)  rank=1/720  in-top-6=True
#   aggregate L∞  raw       best=[0, 1, 3, 2, 5, 4] (cost 4.4394)  rank=1/720  in-top-6=True
#
# truth = (0, 1, 3, 4, 2, 5)
#   max-min raw             best=[4, 1, 2, 3, 0, 5] (cost 0.7379)  rank=31/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 0.6021)  rank=497/720  in-top-6=False
#   max-min log             best=[0, 4, 3, 1, 2, 5] (cost 54.9764)  rank=19/720  in-top-6=False
#   max     log             best=[0, 5, 4, 2, 1, 3] (cost 61.6691)  rank=255/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 3, 2, 5, 4] (cost 447.1735)  rank=25/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 3, 2, 5, 4] (cost 2604.3613)  rank=23/720  in-top-6=False
#   aggregate L∞  log       best=[5, 2, 1, 0, 4, 3] (cost 108.1988)  rank=393/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 3, 2, 5, 4] (cost 447.1735)  rank=25/720  in-top-6=False
#   aggregate L1  raw       best=[4, 1, 3, 0, 2, 5] (cost 30.5312)  rank=8/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 1, 0, 5, 3, 2] (cost 2.9230)  rank=160/720  in-top-6=False
#
# truth = (0, 1, 3, 4, 5, 2)
#   max-min raw             best=[4, 1, 5, 2, 3, 0] (cost 1.3659)  rank=97/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 0, 4, 2] (cost 0.5354)  rank=255/720  in-top-6=False
#   max-min log             best=[4, 2, 5, 3, 1, 0] (cost 50.9909)  rank=437/720  in-top-6=False
#   max     log             best=[4, 5, 0, 1, 3, 2] (cost 48.0639)  rank=286/720  in-top-6=False
#   aggregate L2  log       best=[4, 3, 1, 0, 5, 2] (cost 438.8508)  rank=145/720  in-top-6=False
#   aggregate L1  log       best=[4, 2, 1, 0, 3, 5] (cost 2572.1641)  rank=127/720  in-top-6=False
#   aggregate L∞  log       best=[4, 2, 1, 0, 5, 3] (cost 104.5724)  rank=115/720  in-top-6=False
#   aggregate L2  raw       best=[4, 3, 1, 0, 5, 2] (cost 438.8508)  rank=145/720  in-top-6=False
#   aggregate L1  raw       best=[3, 1, 4, 0, 2, 5] (cost 35.2926)  rank=237/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 1, 4, 2, 3, 5] (cost 3.8128)  rank=205/720  in-top-6=False
#
# truth = (0, 1, 3, 5, 2, 4)
#   max-min raw             best=[4, 1, 5, 2, 3, 0] (cost 1.8815)  rank=131/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6371)  rank=166/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=480/720  in-top-6=False
#   max     log             best=[4, 1, 0, 2, 3, 5] (cost 44.5344)  rank=191/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 2, 3, 5] (cost 459.5883)  rank=86/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2683.8486)  rank=73/720  in-top-6=False
#   aggregate L∞  log       best=[0, 4, 1, 5, 3, 2] (cost 106.4966)  rank=95/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 2, 3, 5] (cost 459.5883)  rank=86/720  in-top-6=False
#   aggregate L1  raw       best=[4, 3, 1, 0, 2, 5] (cost 57.2389)  rank=15/720  in-top-6=False
#   aggregate L∞  raw       best=[1, 3, 2, 5, 0, 4] (cost 5.1600)  rank=75/720  in-top-6=False
#
# truth = (0, 1, 3, 5, 4, 2)
#   max-min raw             best=[4, 5, 1, 2, 3, 0] (cost 1.1149)  rank=441/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 1.2740)  rank=124/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=393/720  in-top-6=False
#   max     log             best=[4, 0, 5, 2, 3, 1] (cost 44.7545)  rank=517/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 5, 2, 3, 4] (cost 460.2156)  rank=166/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 2, 3, 4] (cost 2684.1348)  rank=171/720  in-top-6=False
#   aggregate L∞  log       best=[1, 0, 3, 5, 4, 2] (cost 106.1356)  rank=13/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 5, 2, 3, 4] (cost 460.2156)  rank=166/720  in-top-6=False
#   aggregate L1  raw       best=[2, 1, 3, 5, 0, 4] (cost 56.5965)  rank=59/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 1, 3, 5, 0, 4] (cost 5.1177)  rank=52/720  in-top-6=False
#
# truth = (0, 1, 4, 2, 3, 5)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.4957)  rank=545/720  in-top-6=False
#   max     raw             best=[3, 4, 0, 2, 1, 5] (cost 0.9294)  rank=85/720  in-top-6=False
#   max-min log             best=[0, 1, 5, 2, 4, 3] (cost 65.5714)  rank=25/720  in-top-6=False
#   max     log             best=[0, 4, 1, 2, 3, 5] (cost 52.3413)  rank=4/720  in-top-6=True
#   aggregate L2  log       best=[0, 1, 5, 2, 3, 4] (cost 422.7983)  rank=2/720  in-top-6=True
#   aggregate L1  log       best=[0, 1, 5, 2, 3, 4] (cost 2437.1130)  rank=2/720  in-top-6=True
#   aggregate L∞  log       best=[2, 1, 3, 0, 5, 4] (cost 101.7294)  rank=52/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 5, 2, 3, 4] (cost 422.7983)  rank=2/720  in-top-6=True
#   aggregate L1  raw       best=[0, 1, 3, 2, 5, 4] (cost 41.7641)  rank=40/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 4, 3, 2, 5, 1] (cost 4.4589)  rank=93/720  in-top-6=False
#
# truth = (0, 1, 4, 2, 5, 3)
#   max-min raw             best=[4, 0, 1, 3, 2, 5] (cost 0.4782)  rank=352/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 0.6334)  rank=163/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 48.0499)  rank=62/720  in-top-6=False
#   max     log             best=[0, 5, 2, 4, 1, 3] (cost 58.6327)  rank=10/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 405.4260)  rank=3/720  in-top-6=True
#   aggregate L1  log       best=[0, 5, 4, 1, 2, 3] (cost 2347.2493)  rank=4/720  in-top-6=True
#   aggregate L∞  log       best=[0, 2, 1, 5, 4, 3] (cost 103.9036)  rank=29/720  in-top-6=False
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 405.4260)  rank=3/720  in-top-6=True
#   aggregate L1  raw       best=[2, 0, 1, 3, 5, 4] (cost 32.8614)  rank=396/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 0, 5, 1, 3, 4] (cost 2.5046)  rank=328/720  in-top-6=False
#
# truth = (0, 1, 4, 3, 2, 5)
#   max-min raw             best=[4, 1, 2, 3, 5, 0] (cost 0.4860)  rank=237/720  in-top-6=False
#   max     raw             best=[4, 1, 3, 2, 0, 5] (cost 0.3854)  rank=14/720  in-top-6=False
#   max-min log             best=[0, 5, 4, 2, 1, 3] (cost 55.3971)  rank=82/720  in-top-6=False
#   max     log             best=[0, 5, 4, 2, 1, 3] (cost 52.8983)  rank=260/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 4, 2, 5, 3] (cost 399.9386)  rank=58/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 4, 2, 5, 3] (cost 2322.1274)  rank=78/720  in-top-6=False
#   aggregate L∞  log       best=[0, 1, 4, 2, 5, 3] (cost 98.6315)  rank=65/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 4, 2, 5, 3] (cost 399.9386)  rank=58/720  in-top-6=False
#   aggregate L1  raw       best=[4, 1, 3, 0, 2, 5] (cost 31.4736)  rank=17/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 5, 3, 1, 2, 4] (cost 2.6703)  rank=123/720  in-top-6=False
#
# truth = (0, 1, 4, 3, 5, 2)
#   max-min raw             best=[4, 5, 1, 2, 3, 0] (cost 0.9508)  rank=372/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 1.2232)  rank=324/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 3, 1, 0] (cost 39.8158)  rank=537/720  in-top-6=False
#   max     log             best=[4, 0, 2, 5, 3, 1] (cost 44.5211)  rank=569/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 4, 5, 3, 2] (cost 448.5442)  rank=140/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 4, 5, 3, 2] (cost 2610.1802)  rank=146/720  in-top-6=False
#   aggregate L∞  log       best=[3, 0, 1, 5, 4, 2] (cost 105.5869)  rank=318/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 4, 5, 3, 2] (cost 448.5442)  rank=140/720  in-top-6=False
#   aggregate L1  raw       best=[2, 0, 1, 5, 3, 4] (cost 49.6541)  rank=278/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 5, 0, 4, 1, 3] (cost 4.6864)  rank=487/720  in-top-6=False
#
# truth = (0, 1, 4, 5, 2, 3)
#   max-min raw             best=[4, 1, 5, 2, 3, 0] (cost 1.6276)  rank=140/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.3424)  rank=372/720  in-top-6=False
#   max-min log             best=[1, 0, 5, 2, 4, 3] (cost 61.4369)  rank=451/720  in-top-6=False
#   max     log             best=[4, 1, 0, 2, 3, 5] (cost 44.3964)  rank=578/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 5, 3, 2, 4] (cost 436.8905)  rank=2/720  in-top-6=True
#   aggregate L1  log       best=[0, 1, 4, 5, 2, 3] (cost 2525.7905)  rank=1/720  in-top-6=True
#   aggregate L∞  log       best=[2, 1, 5, 0, 3, 4] (cost 104.2366)  rank=135/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 5, 3, 2, 4] (cost 436.8905)  rank=2/720  in-top-6=True
#   aggregate L1  raw       best=[3, 1, 4, 0, 2, 5] (cost 48.7907)  rank=11/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 1, 2, 5, 3, 4] (cost 4.4195)  rank=37/720  in-top-6=False
#
# truth = (0, 1, 4, 5, 3, 2)
#   max-min raw             best=[4, 5, 1, 2, 3, 0] (cost 1.1149)  rank=435/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 1.2701)  rank=218/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=502/720  in-top-6=False
#   max     log             best=[4, 0, 5, 2, 3, 1] (cost 44.7505)  rank=406/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 5, 2, 3, 4] (cost 451.1263)  rank=94/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 2, 3, 4] (cost 2621.4143)  rank=78/720  in-top-6=False
#   aggregate L∞  log       best=[1, 0, 3, 5, 4, 2] (cost 106.1278)  rank=53/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 5, 2, 3, 4] (cost 451.1263)  rank=94/720  in-top-6=False
#   aggregate L1  raw       best=[2, 1, 3, 5, 0, 4] (cost 56.5027)  rank=137/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 1, 3, 5, 0, 4] (cost 5.1138)  rank=31/720  in-top-6=False
#
# truth = (0, 1, 5, 2, 3, 4)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 0.8150)  rank=485/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6293)  rank=332/720  in-top-6=False
#   max-min log             best=[0, 4, 5, 2, 1, 3] (cost 57.3970)  rank=102/720  in-top-6=False
#   max     log             best=[0, 1, 4, 2, 3, 5] (cost 41.9950)  rank=2/720  in-top-6=True
#   aggregate L2  log       best=[4, 1, 3, 0, 2, 5] (cost 415.7249)  rank=15/720  in-top-6=False
#   aggregate L1  log       best=[4, 1, 3, 0, 2, 5] (cost 2401.4702)  rank=20/720  in-top-6=False
#   aggregate L∞  log       best=[2, 1, 3, 0, 5, 4] (cost 101.3874)  rank=331/720  in-top-6=False
#   aggregate L2  raw       best=[4, 1, 3, 0, 2, 5] (cost 415.7249)  rank=15/720  in-top-6=False
#   aggregate L1  raw       best=[1, 5, 3, 0, 2, 4] (cost 48.2804)  rank=127/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 1, 5, 0, 2, 3] (cost 4.6860)  rank=50/720  in-top-6=False
#
# truth = (0, 1, 5, 2, 4, 3)
#   max-min raw             best=[5, 1, 2, 3, 4, 0] (cost 1.1552)  rank=40/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.5237)  rank=2/720  in-top-6=True
#   max-min log             best=[4, 0, 5, 2, 1, 3] (cost 55.5925)  rank=365/720  in-top-6=False
#   max     log             best=[4, 5, 0, 2, 3, 1] (cost 43.9428)  rank=151/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 5, 2, 3, 4] (cost 425.8313)  rank=7/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 5, 2, 3, 4] (cost 2472.0156)  rank=5/720  in-top-6=True
#   aggregate L∞  log       best=[0, 1, 5, 4, 3, 2] (cost 103.3654)  rank=13/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 5, 2, 3, 4] (cost 425.8313)  rank=7/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 5, 2, 3, 4] (cost 52.4911)  rank=3/720  in-top-6=True
#   aggregate L∞  raw       best=[3, 1, 5, 2, 0, 4] (cost 4.8748)  rank=6/720  in-top-6=True
#
# truth = (0, 1, 5, 3, 2, 4)
#   max-min raw             best=[4, 5, 2, 3, 1, 0] (cost 0.5556)  rank=462/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.5707)  rank=523/720  in-top-6=False
#   max-min log             best=[0, 4, 5, 2, 1, 3] (cost 57.5138)  rank=35/720  in-top-6=False
#   max     log             best=[0, 2, 4, 1, 3, 5] (cost 45.4513)  rank=56/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 5, 3, 2, 4] (cost 449.6915)  rank=1/720  in-top-6=True
#   aggregate L1  log       best=[0, 1, 3, 2, 5, 4] (cost 2617.3057)  rank=2/720  in-top-6=True
#   aggregate L∞  log       best=[0, 1, 3, 2, 5, 4] (cost 103.6402)  rank=133/720  in-top-6=False
#   aggregate L2  raw       best=[0, 1, 5, 3, 2, 4] (cost 449.6915)  rank=1/720  in-top-6=True
#   aggregate L1  raw       best=[1, 5, 3, 0, 2, 4] (cost 46.0169)  rank=11/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 5, 3, 1, 2, 4] (cost 4.5719)  rank=3/720  in-top-6=True
#
# truth = (0, 1, 5, 3, 4, 2)
#   max-min raw             best=[4, 5, 1, 2, 3, 0] (cost 1.1032)  rank=324/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 1.2740)  rank=462/720  in-top-6=False
#   max-min log             best=[4, 5, 3, 2, 1, 0] (cost 42.6405)  rank=570/720  in-top-6=False
#   max     log             best=[4, 0, 5, 2, 3, 1] (cost 44.7545)  rank=557/720  in-top-6=False
#   aggregate L2  log       best=[2, 0, 5, 4, 3, 1] (cost 447.4984)  rank=153/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 2, 3, 4] (cost 2602.1084)  rank=155/720  in-top-6=False
#   aggregate L∞  log       best=[3, 0, 1, 5, 4, 2] (cost 105.7448)  rank=136/720  in-top-6=False
#   aggregate L2  raw       best=[2, 0, 5, 4, 3, 1] (cost 447.4984)  rank=153/720  in-top-6=False
#   aggregate L1  raw       best=[2, 1, 3, 5, 0, 4] (cost 56.4558)  rank=97/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 1, 3, 5, 0, 4] (cost 5.0982)  rank=64/720  in-top-6=False
#
# truth = (0, 1, 5, 4, 2, 3)
#   max-min raw             best=[5, 1, 2, 3, 4, 0] (cost 0.9795)  rank=150/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.1838)  rank=68/720  in-top-6=False
#   max-min log             best=[4, 5, 0, 2, 1, 3] (cost 49.0261)  rank=381/720  in-top-6=False
#   max     log             best=[4, 5, 0, 2, 3, 1] (cost 42.4612)  rank=318/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 5, 4, 2, 3] (cost 412.1539)  rank=1/720  in-top-6=True
#   aggregate L1  log       best=[0, 1, 5, 4, 2, 3] (cost 2375.6821)  rank=1/720  in-top-6=True
#   aggregate L∞  log       best=[0, 1, 5, 4, 2, 3] (cost 103.3476)  rank=1/720  in-top-6=True
#   aggregate L2  raw       best=[0, 1, 5, 4, 2, 3] (cost 412.1539)  rank=1/720  in-top-6=True
#   aggregate L1  raw       best=[0, 1, 5, 2, 3, 4] (cost 44.3688)  rank=2/720  in-top-6=True
#   aggregate L∞  raw       best=[1, 5, 4, 2, 0, 3] (cost 4.5116)  rank=116/720  in-top-6=False
#
# truth = (0, 1, 5, 4, 3, 2)
#   max-min raw             best=[4, 1, 3, 2, 5, 0] (cost 0.2581)  rank=78/720  in-top-6=False
#   max     raw             best=[5, 1, 3, 2, 4, 0] (cost 0.5925)  rank=586/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 0, 3] (cost 44.8178)  rank=706/720  in-top-6=False
#   max     log             best=[4, 0, 2, 5, 3, 1] (cost 44.3972)  rank=530/720  in-top-6=False
#   aggregate L2  log       best=[2, 5, 4, 0, 1, 3] (cost 400.4441)  rank=343/720  in-top-6=False
#   aggregate L1  log       best=[2, 5, 4, 1, 0, 3] (cost 2323.6736)  rank=359/720  in-top-6=False
#   aggregate L∞  log       best=[3, 1, 4, 0, 5, 2] (cost 95.5997)  rank=174/720  in-top-6=False
#   aggregate L2  raw       best=[2, 5, 4, 0, 1, 3] (cost 400.4441)  rank=343/720  in-top-6=False
#   aggregate L1  raw       best=[2, 1, 5, 3, 0, 4] (cost 31.8043)  rank=40/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 3, 1, 4, 5, 0] (cost 3.0741)  rank=455/720  in-top-6=False
#
# truth = (0, 2, 1, 3, 4, 5)
#   max-min raw             best=[5, 0, 2, 1, 4, 3] (cost 0.4805)  rank=75/720  in-top-6=False
#   max     raw             best=[4, 3, 1, 2, 0, 5] (cost 0.2543)  rank=150/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 1, 3, 5] (cost 55.8110)  rank=65/720  in-top-6=False
#   max     log             best=[0, 3, 2, 1, 4, 5] (cost 55.0137)  rank=33/720  in-top-6=False
#   aggregate L2  log       best=[0, 3, 2, 1, 5, 4] (cost 433.3377)  rank=53/720  in-top-6=False
#   aggregate L1  log       best=[0, 3, 2, 1, 5, 4] (cost 2520.9084)  rank=78/720  in-top-6=False
#   aggregate L∞  log       best=[0, 3, 2, 1, 4, 5] (cost 102.3504)  rank=11/720  in-top-6=False
#   aggregate L2  raw       best=[0, 3, 2, 1, 5, 4] (cost 433.3377)  rank=53/720  in-top-6=False
#   aggregate L1  raw       best=[0, 3, 2, 1, 5, 4] (cost 30.1724)  rank=10/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 3, 1, 2, 4, 5] (cost 2.9894)  rank=39/720  in-top-6=False
#
# truth = (0, 2, 1, 3, 5, 4)
#   max-min raw             best=[4, 3, 5, 2, 1, 0] (cost 0.3095)  rank=75/720  in-top-6=False
#   max     raw             best=[0, 3, 5, 2, 1, 4] (cost 1.2515)  rank=186/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 50.6229)  rank=173/720  in-top-6=False
#   max     log             best=[0, 4, 2, 1, 3, 5] (cost 41.1313)  rank=81/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 404.2988)  rank=48/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 4, 1, 5, 3] (cost 2337.5601)  rank=70/720  in-top-6=False
#   aggregate L∞  log       best=[0, 3, 4, 1, 5, 2] (cost 100.1410)  rank=97/720  in-top-6=False
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 404.2988)  rank=48/720  in-top-6=False
#   aggregate L1  raw       best=[4, 0, 5, 3, 1, 2] (cost 30.2188)  rank=63/720  in-top-6=False
#   aggregate L∞  raw       best=[1, 0, 5, 4, 3, 2] (cost 3.0808)  rank=559/720  in-top-6=False
#
# truth = (0, 2, 1, 4, 3, 5)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5074)  rank=404/720  in-top-6=False
#   max     raw             best=[3, 0, 4, 2, 1, 5] (cost 0.8798)  rank=196/720  in-top-6=False
#   max-min log             best=[0, 1, 5, 2, 4, 3] (cost 66.6678)  rank=49/720  in-top-6=False
#   max     log             best=[0, 4, 3, 2, 1, 5] (cost 54.2901)  rank=213/720  in-top-6=False
#   aggregate L2  log       best=[3, 0, 1, 2, 4, 5] (cost 467.9624)  rank=207/720  in-top-6=False
#   aggregate L1  log       best=[2, 0, 4, 1, 3, 5] (cost 2713.8455)  rank=152/720  in-top-6=False
#   aggregate L∞  log       best=[3, 1, 2, 0, 5, 4] (cost 109.3950)  rank=409/720  in-top-6=False
#   aggregate L2  raw       best=[3, 0, 1, 2, 4, 5] (cost 467.9624)  rank=207/720  in-top-6=False
#   aggregate L1  raw       best=[5, 0, 4, 2, 3, 1] (cost 46.6920)  rank=623/720  in-top-6=False
#   aggregate L∞  raw       best=[3, 0, 4, 1, 5, 2] (cost 3.5696)  rank=393/720  in-top-6=False
#
# truth = (0, 2, 1, 4, 5, 3)
#   max-min raw             best=[2, 4, 1, 3, 0, 5] (cost 0.4489)  rank=186/720  in-top-6=False
#   max     raw             best=[5, 1, 0, 2, 4, 3] (cost 0.2448)  rank=602/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 51.6027)  rank=28/720  in-top-6=False
#   max     log             best=[0, 5, 2, 4, 1, 3] (cost 63.6718)  rank=51/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 421.2126)  rank=9/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 4, 1, 5, 3] (cost 2443.2224)  rank=11/720  in-top-6=False
#   aggregate L∞  log       best=[5, 1, 2, 0, 4, 3] (cost 105.6373)  rank=4/720  in-top-6=True
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 421.2126)  rank=9/720  in-top-6=False
#   aggregate L1  raw       best=[1, 2, 3, 0, 5, 4] (cost 24.6789)  rank=71/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 2.1952)  rank=12/720  in-top-6=False
#
# truth = (0, 2, 1, 5, 3, 4)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5113)  rank=186/720  in-top-6=False
#   max     raw             best=[0, 4, 5, 2, 1, 3] (cost 2.2963)  rank=402/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=493/720  in-top-6=False
#   max     log             best=[4, 1, 0, 2, 3, 5] (cost 44.5344)  rank=233/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 5, 3, 2, 0] (cost 469.0919)  rank=263/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 5, 3, 2, 0] (cost 2736.9236)  rank=248/720  in-top-6=False
#   aggregate L∞  log       best=[2, 4, 3, 5, 0, 1] (cost 106.0225)  rank=236/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 5, 3, 2, 0] (cost 469.0919)  rank=263/720  in-top-6=False
#   aggregate L1  raw       best=[0, 4, 2, 5, 1, 3] (cost 57.7321)  rank=352/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 5, 2, 3, 1, 4] (cost 5.2032)  rank=157/720  in-top-6=False
#
# truth = (0, 2, 1, 5, 4, 3)
#   max-min raw             best=[0, 1, 2, 3, 4, 5] (cost 0.4920)  rank=132/720  in-top-6=False
#   max     raw             best=[5, 3, 0, 2, 4, 1] (cost 0.1497)  rank=98/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 48.6324)  rank=33/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 56.9208)  rank=43/720  in-top-6=False
#   aggregate L2  log       best=[5, 2, 4, 1, 0, 3] (cost 412.4341)  rank=42/720  in-top-6=False
#   aggregate L1  log       best=[5, 2, 4, 1, 0, 3] (cost 2379.8074)  rank=47/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 2, 1, 4, 0] (cost 107.0263)  rank=5/720  in-top-6=True
#   aggregate L2  raw       best=[5, 2, 4, 1, 0, 3] (cost 412.4341)  rank=42/720  in-top-6=False
#   aggregate L1  raw       best=[2, 0, 1, 3, 4, 5] (cost 27.4983)  rank=85/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 3, 4, 5, 0, 1] (cost 2.5347)  rank=168/720  in-top-6=False
#
# truth = (0, 2, 3, 1, 4, 5)
#   max-min raw             best=[3, 0, 2, 1, 4, 5] (cost 0.6111)  rank=14/720  in-top-6=False
#   max     raw             best=[2, 3, 1, 0, 4, 5] (cost 0.4131)  rank=144/720  in-top-6=False
#   max-min log             best=[0, 4, 3, 1, 2, 5] (cost 56.3194)  rank=7/720  in-top-6=False
#   max     log             best=[0, 2, 3, 1, 4, 5] (cost 57.0827)  rank=1/720  in-top-6=True
#   aggregate L2  log       best=[0, 2, 3, 1, 4, 5] (cost 453.2490)  rank=1/720  in-top-6=True
#   aggregate L1  log       best=[0, 2, 3, 1, 4, 5] (cost 2641.9705)  rank=1/720  in-top-6=True
#   aggregate L∞  log       best=[2, 1, 3, 0, 4, 5] (cost 108.5955)  rank=3/720  in-top-6=True
#   aggregate L2  raw       best=[0, 2, 3, 1, 4, 5] (cost 453.2490)  rank=1/720  in-top-6=True
#   aggregate L1  raw       best=[0, 2, 3, 1, 4, 5] (cost 35.7942)  rank=1/720  in-top-6=True
#   aggregate L∞  raw       best=[2, 0, 3, 1, 4, 5] (cost 2.6245)  rank=30/720  in-top-6=False
#
# truth = (0, 2, 3, 1, 5, 4)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5074)  rank=525/720  in-top-6=False
#   max     raw             best=[1, 3, 2, 0, 4, 5] (cost 0.4503)  rank=266/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 3, 1, 5] (cost 52.3532)  rank=341/720  in-top-6=False
#   max     log             best=[0, 4, 2, 1, 3, 5] (cost 42.8030)  rank=58/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 1, 3, 4, 5] (cost 435.5942)  rank=10/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 1, 3, 4, 5] (cost 2544.0457)  rank=10/720  in-top-6=False
#   aggregate L∞  log       best=[3, 2, 1, 0, 4, 5] (cost 105.6127)  rank=215/720  in-top-6=False
#   aggregate L2  raw       best=[0, 2, 1, 3, 4, 5] (cost 435.5942)  rank=10/720  in-top-6=False
#   aggregate L1  raw       best=[0, 2, 1, 3, 4, 5] (cost 34.2733)  rank=28/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 0, 3, 1, 4, 5] (cost 3.0477)  rank=141/720  in-top-6=False
#
# truth = (0, 2, 3, 4, 1, 5)
#   max-min raw             best=[1, 0, 4, 3, 2, 5] (cost 0.9032)  rank=96/720  in-top-6=False
#   max     raw             best=[2, 4, 0, 1, 5, 3] (cost 1.1068)  rank=317/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 3, 0] (cost 49.1121)  rank=604/720  in-top-6=False
#   max     log             best=[4, 5, 2, 1, 0, 3] (cost 53.7563)  rank=652/720  in-top-6=False
#   aggregate L2  log       best=[4, 5, 2, 1, 0, 3] (cost 412.0201)  rank=148/720  in-top-6=False
#   aggregate L1  log       best=[4, 5, 2, 1, 0, 3] (cost 2368.5996)  rank=160/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 2, 4, 1, 0] (cost 108.4778)  rank=18/720  in-top-6=False
#   aggregate L2  raw       best=[4, 5, 2, 1, 0, 3] (cost 412.0201)  rank=148/720  in-top-6=False
#   aggregate L1  raw       best=[2, 4, 3, 5, 1, 0] (cost 37.6586)  rank=44/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 0, 3, 4, 1, 5] (cost 3.5219)  rank=33/720  in-top-6=False
#
# truth = (0, 2, 3, 4, 5, 1)
#   max-min raw             best=[2, 0, 1, 3, 4, 5] (cost 1.3351)  rank=434/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6371)  rank=638/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=461/720  in-top-6=False
#   max     log             best=[4, 0, 3, 2, 1, 5] (cost 47.8499)  rank=611/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 2, 3, 5] (cost 484.7974)  rank=174/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2825.6770)  rank=180/720  in-top-6=False
#   aggregate L∞  log       best=[2, 4, 1, 5, 0, 3] (cost 112.5579)  rank=185/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 2, 3, 5] (cost 484.7974)  rank=174/720  in-top-6=False
#   aggregate L1  raw       best=[1, 5, 3, 0, 2, 4] (cost 59.5223)  rank=15/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 4, 1, 3, 0, 5] (cost 5.3817)  rank=105/720  in-top-6=False
#
# truth = (0, 2, 3, 5, 1, 4)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5113)  rank=562/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6526)  rank=440/720  in-top-6=False
#   max-min log             best=[1, 2, 5, 3, 4, 0] (cost 57.7883)  rank=586/720  in-top-6=False
#   max     log             best=[1, 0, 4, 2, 3, 5] (cost 38.6655)  rank=461/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 5, 2, 3, 4] (cost 462.6111)  rank=377/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 2, 3, 4] (cost 2697.6353)  rank=351/720  in-top-6=False
#   aggregate L∞  log       best=[1, 0, 5, 3, 4, 2] (cost 104.2117)  rank=276/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 5, 2, 3, 4] (cost 462.6111)  rank=377/720  in-top-6=False
#   aggregate L1  raw       best=[2, 0, 5, 3, 4, 1] (cost 57.2581)  rank=215/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 0, 4, 1, 3, 5] (cost 5.1596)  rank=253/720  in-top-6=False
#
# truth = (0, 2, 3, 5, 4, 1)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.4957)  rank=256/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6447)  rank=375/720  in-top-6=False
#   max-min log             best=[5, 4, 2, 1, 3, 0] (cost 47.3576)  rank=580/720  in-top-6=False
#   max     log             best=[4, 1, 2, 3, 0, 5] (cost 50.1300)  rank=634/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 3, 5, 2, 4] (cost 443.9145)  rank=3/720  in-top-6=True
#   aggregate L1  log       best=[1, 0, 3, 5, 2, 4] (cost 2577.4988)  rank=3/720  in-top-6=True
#   aggregate L∞  log       best=[2, 1, 3, 5, 4, 0] (cost 106.3298)  rank=40/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 3, 5, 2, 4] (cost 443.9145)  rank=3/720  in-top-6=True
#   aggregate L1  raw       best=[1, 0, 5, 3, 4, 2] (cost 49.3757)  rank=47/720  in-top-6=False
#   aggregate L∞  raw       best=[1, 0, 5, 4, 3, 2] (cost 4.4648)  rank=220/720  in-top-6=False
#
# truth = (0, 2, 4, 1, 3, 5)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 0.5885)  rank=672/720  in-top-6=False
#   max     raw             best=[3, 4, 1, 2, 0, 5] (cost 0.5170)  rank=450/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 1, 3, 4] (cost 50.2215)  rank=79/720  in-top-6=False
#   max     log             best=[0, 4, 2, 1, 3, 5] (cost 38.3497)  rank=5/720  in-top-6=True
#   aggregate L2  log       best=[4, 2, 1, 0, 5, 3] (cost 416.1477)  rank=152/720  in-top-6=False
#   aggregate L1  log       best=[4, 2, 1, 0, 5, 3] (cost 2414.2061)  rank=129/720  in-top-6=False
#   aggregate L∞  log       best=[2, 1, 3, 0, 4, 5] (cost 101.7934)  rank=252/720  in-top-6=False
#   aggregate L2  raw       best=[4, 2, 1, 0, 5, 3] (cost 416.1477)  rank=152/720  in-top-6=False
#   aggregate L1  raw       best=[4, 1, 3, 0, 2, 5] (cost 41.9671)  rank=476/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 4, 3, 0, 1, 5] (cost 4.2189)  rank=449/720  in-top-6=False
#
# truth = (0, 2, 4, 1, 5, 3)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5113)  rank=532/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6371)  rank=640/720  in-top-6=False
#   max-min log             best=[1, 4, 2, 3, 5, 0] (cost 58.3586)  rank=711/720  in-top-6=False
#   max     log             best=[4, 0, 1, 2, 3, 5] (cost 41.6719)  rank=715/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 2, 3, 5] (cost 459.8832)  rank=693/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2684.1104)  rank=695/720  in-top-6=False
#   aggregate L∞  log       best=[1, 0, 3, 5, 4, 2] (cost 106.2039)  rank=673/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 2, 3, 5] (cost 459.8832)  rank=693/720  in-top-6=False
#   aggregate L1  raw       best=[1, 4, 5, 0, 2, 3] (cost 57.7142)  rank=139/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 0, 1, 3, 5, 2] (cost 5.1305)  rank=78/720  in-top-6=False
#
# truth = (0, 2, 4, 3, 1, 5)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 1.0753)  rank=678/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.5705)  rank=350/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 1, 4, 3] (cost 45.8718)  rank=504/720  in-top-6=False
#   max     log             best=[0, 5, 2, 4, 1, 3] (cost 56.4516)  rank=188/720  in-top-6=False
#   aggregate L2  log       best=[1, 2, 5, 0, 4, 3] (cost 437.3367)  rank=255/720  in-top-6=False
#   aggregate L1  log       best=[1, 2, 5, 0, 4, 3] (cost 2537.5059)  rank=223/720  in-top-6=False
#   aggregate L∞  log       best=[0, 5, 2, 3, 4, 1] (cost 103.2764)  rank=76/720  in-top-6=False
#   aggregate L2  raw       best=[1, 2, 5, 0, 4, 3] (cost 437.3367)  rank=255/720  in-top-6=False
#   aggregate L1  raw       best=[0, 3, 2, 5, 4, 1] (cost 49.6448)  rank=297/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 4.5627)  rank=161/720  in-top-6=False
#
# truth = (0, 2, 4, 3, 5, 1)
#   max-min raw             best=[5, 3, 2, 1, 4, 0] (cost 1.9157)  rank=360/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.6371)  rank=613/720  in-top-6=False
#   max-min log             best=[0, 2, 3, 1, 4, 5] (cost 59.3180)  rank=189/720  in-top-6=False
#   max     log             best=[0, 4, 1, 2, 3, 5] (cost 52.7104)  rank=191/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 2, 3, 5] (cost 464.6611)  rank=492/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2711.1311)  rank=497/720  in-top-6=False
#   aggregate L∞  log       best=[3, 0, 1, 2, 5, 4] (cost 110.8760)  rank=359/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 2, 3, 5] (cost 464.6611)  rank=492/720  in-top-6=False
#   aggregate L1  raw       best=[0, 3, 2, 1, 5, 4] (cost 57.5251)  rank=180/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 3, 2, 1, 5, 4] (cost 5.2415)  rank=162/720  in-top-6=False
#
# truth = (0, 2, 4, 5, 1, 3)
#   max-min raw             best=[5, 1, 4, 0, 3, 2] (cost 0.7768)  rank=521/720  in-top-6=False
#   max     raw             best=[3, 1, 0, 2, 4, 5] (cost 0.2838)  rank=571/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 44.5689)  rank=4/720  in-top-6=True
#   max     log             best=[0, 4, 2, 1, 3, 5] (cost 34.6345)  rank=420/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 407.7816)  rank=9/720  in-top-6=False
#   aggregate L1  log       best=[0, 2, 4, 1, 5, 3] (cost 2365.8208)  rank=11/720  in-top-6=False
#   aggregate L∞  log       best=[5, 1, 4, 0, 3, 2] (cost 99.0831)  rank=110/720  in-top-6=False
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 407.7816)  rank=9/720  in-top-6=False
#   aggregate L1  raw       best=[3, 1, 4, 0, 2, 5] (cost 37.5881)  rank=71/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 1, 4, 2, 3, 5] (cost 3.8597)  rank=108/720  in-top-6=False
#
# truth = (0, 2, 4, 5, 3, 1)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 0.9542)  rank=182/720  in-top-6=False
#   max     raw             best=[1, 3, 5, 2, 4, 0] (cost 1.2864)  rank=80/720  in-top-6=False
#   max-min log             best=[4, 5, 0, 1, 2, 3] (cost 53.2593)  rank=485/720  in-top-6=False
#   max     log             best=[4, 0, 5, 1, 3, 2] (cost 41.7429)  rank=362/720  in-top-6=False
#   aggregate L2  log       best=[2, 3, 4, 5, 0, 1] (cost 427.5622)  rank=65/720  in-top-6=False
#   aggregate L1  log       best=[2, 3, 4, 5, 0, 1] (cost 2482.7573)  rank=79/720  in-top-6=False
#   aggregate L∞  log       best=[2, 0, 3, 5, 4, 1] (cost 103.2866)  rank=181/720  in-top-6=False
#   aggregate L2  raw       best=[2, 3, 4, 5, 0, 1] (cost 427.5622)  rank=65/720  in-top-6=False
#   aggregate L1  raw       best=[3, 2, 4, 5, 0, 1] (cost 46.3150)  rank=23/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 3, 4, 1, 5, 0] (cost 4.3143)  rank=105/720  in-top-6=False
#
# truth = (0, 2, 5, 1, 3, 4)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 1.1339)  rank=86/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6526)  rank=114/720  in-top-6=False
#   max-min log             best=[5, 4, 2, 1, 3, 0] (cost 54.0660)  rank=241/720  in-top-6=False
#   max     log             best=[4, 1, 2, 0, 3, 5] (cost 45.4936)  rank=477/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 5, 2, 3, 0] (cost 431.6105)  rank=63/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 5, 2, 3, 0] (cost 2508.0789)  rank=55/720  in-top-6=False
#   aggregate L∞  log       best=[1, 3, 0, 5, 4, 2] (cost 102.8237)  rank=345/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 5, 2, 3, 0] (cost 431.6105)  rank=63/720  in-top-6=False
#   aggregate L1  raw       best=[1, 2, 5, 4, 3, 0] (cost 54.4681)  rank=41/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 4.8811)  rank=65/720  in-top-6=False
#
# truth = (0, 2, 5, 1, 4, 3)
#   max-min raw             best=[5, 0, 1, 4, 3, 2] (cost 0.4189)  rank=451/720  in-top-6=False
#   max     raw             best=[3, 0, 1, 2, 4, 5] (cost 0.2936)  rank=669/720  in-top-6=False
#   max-min log             best=[0, 4, 2, 5, 1, 3] (cost 54.9208)  rank=23/720  in-top-6=False
#   max     log             best=[0, 3, 2, 1, 4, 5] (cost 47.8776)  rank=136/720  in-top-6=False
#   aggregate L2  log       best=[0, 2, 4, 1, 5, 3] (cost 410.8020)  rank=10/720  in-top-6=False
#   aggregate L1  log       best=[5, 2, 4, 1, 0, 3] (cost 2366.4294)  rank=18/720  in-top-6=False
#   aggregate L∞  log       best=[3, 5, 4, 0, 2, 1] (cost 104.9368)  rank=195/720  in-top-6=False
#   aggregate L2  raw       best=[0, 2, 4, 1, 5, 3] (cost 410.8020)  rank=10/720  in-top-6=False
#   aggregate L1  raw       best=[0, 4, 5, 1, 2, 3] (cost 31.9372)  rank=9/720  in-top-6=False
#   aggregate L∞  raw       best=[3, 1, 0, 4, 2, 5] (cost 3.0158)  rank=442/720  in-top-6=False
#
# truth = (0, 2, 5, 3, 1, 4)
#   max-min raw             best=[5, 0, 1, 4, 3, 2] (cost 0.4566)  rank=576/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6526)  rank=136/720  in-top-6=False
#   max-min log             best=[4, 3, 2, 5, 1, 0] (cost 47.9313)  rank=544/720  in-top-6=False
#   max     log             best=[4, 1, 2, 0, 3, 5] (cost 42.6490)  rank=533/720  in-top-6=False
#   aggregate L2  log       best=[1, 2, 5, 3, 4, 0] (cost 438.7255)  rank=79/720  in-top-6=False
#   aggregate L1  log       best=[1, 2, 5, 3, 4, 0] (cost 2551.5310)  rank=55/720  in-top-6=False
#   aggregate L∞  log       best=[3, 4, 5, 0, 1, 2] (cost 103.9183)  rank=266/720  in-top-6=False
#   aggregate L2  raw       best=[1, 2, 5, 3, 4, 0] (cost 438.7255)  rank=79/720  in-top-6=False
#   aggregate L1  raw       best=[0, 3, 2, 5, 4, 1] (cost 45.0622)  rank=41/720  in-top-6=False
#   aggregate L∞  raw       best=[1, 0, 5, 4, 3, 2] (cost 4.1840)  rank=18/720  in-top-6=False
#
# truth = (0, 2, 5, 3, 4, 1)
#   max-min raw             best=[4, 5, 1, 0, 2, 3] (cost 0.6393)  rank=237/720  in-top-6=False
#   max     raw             best=[1, 3, 5, 2, 0, 4] (cost 1.4135)  rank=44/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 1, 3, 4] (cost 49.7007)  rank=473/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 47.8452)  rank=110/720  in-top-6=False
#   aggregate L2  log       best=[5, 2, 4, 1, 0, 3] (cost 405.9153)  rank=317/720  in-top-6=False
#   aggregate L1  log       best=[5, 2, 4, 1, 0, 3] (cost 2330.7344)  rank=378/720  in-top-6=False
#   aggregate L∞  log       best=[2, 3, 0, 1, 4, 5] (cost 101.8169)  rank=343/720  in-top-6=False
#   aggregate L2  raw       best=[5, 2, 4, 1, 0, 3] (cost 405.9153)  rank=317/720  in-top-6=False
#   aggregate L1  raw       best=[1, 0, 5, 3, 2, 4] (cost 37.8005)  rank=25/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 0, 5, 3, 2, 1] (cost 3.6284)  rank=44/720  in-top-6=False
#
# truth = (0, 2, 5, 4, 1, 3)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 0.8839)  rank=558/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.3830)  rank=293/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 1, 3, 4] (cost 53.7577)  rank=232/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 45.9354)  rank=18/720  in-top-6=False
#   aggregate L2  log       best=[4, 5, 2, 1, 0, 3] (cost 382.9300)  rank=49/720  in-top-6=False
#   aggregate L1  log       best=[4, 5, 2, 1, 0, 3] (cost 2197.4536)  rank=68/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 2, 1, 4, 0] (cost 97.5068)  rank=111/720  in-top-6=False
#   aggregate L2  raw       best=[4, 5, 2, 1, 0, 3] (cost 382.9300)  rank=49/720  in-top-6=False
#   aggregate L1  raw       best=[0, 3, 5, 4, 1, 2] (cost 43.7869)  rank=2/720  in-top-6=True
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 4.0552)  rank=11/720  in-top-6=False
#
# truth = (0, 2, 5, 4, 3, 1)
#   max-min raw             best=[4, 5, 1, 2, 3, 0] (cost 1.0329)  rank=270/720  in-top-6=False
#   max     raw             best=[1, 3, 5, 2, 0, 4] (cost 2.0698)  rank=103/720  in-top-6=False
#   max-min log             best=[4, 3, 2, 5, 1, 0] (cost 41.1959)  rank=687/720  in-top-6=False
#   max     log             best=[4, 1, 2, 0, 3, 5] (cost 40.2361)  rank=532/720  in-top-6=False
#   aggregate L2  log       best=[1, 2, 3, 5, 0, 4] (cost 409.8666)  rank=122/720  in-top-6=False
#   aggregate L1  log       best=[1, 2, 3, 5, 0, 4] (cost 2368.7837)  rank=133/720  in-top-6=False
#   aggregate L∞  log       best=[1, 2, 5, 3, 0, 4] (cost 100.0373)  rank=236/720  in-top-6=False
#   aggregate L2  raw       best=[1, 2, 3, 5, 0, 4] (cost 409.8666)  rank=122/720  in-top-6=False
#   aggregate L1  raw       best=[4, 0, 5, 3, 2, 1] (cost 51.3764)  rank=53/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 0, 5, 3, 2, 1] (cost 4.6305)  rank=108/720  in-top-6=False
#
# truth = (0, 3, 1, 2, 4, 5)
#   max-min raw             best=[5, 1, 2, 3, 4, 0] (cost 0.9901)  rank=246/720  in-top-6=False
#   max     raw             best=[3, 4, 1, 2, 0, 5] (cost 0.2791)  rank=113/720  in-top-6=False
#   max-min log             best=[0, 2, 3, 1, 4, 5] (cost 53.6614)  rank=100/720  in-top-6=False
#   max     log             best=[0, 4, 1, 2, 3, 5] (cost 52.5989)  rank=28/720  in-top-6=False
#   aggregate L2  log       best=[0, 1, 3, 2, 4, 5] (cost 424.4901)  rank=10/720  in-top-6=False
#   aggregate L1  log       best=[0, 1, 3, 2, 4, 5] (cost 2467.6868)  rank=12/720  in-top-6=False
#   aggregate L∞  log       best=[0, 3, 1, 2, 5, 4] (cost 103.0528)  rank=2/720  in-top-6=True
#   aggregate L2  raw       best=[0, 1, 3, 2, 4, 5] (cost 424.4901)  rank=10/720  in-top-6=False
#   aggregate L1  raw       best=[0, 1, 2, 3, 5, 4] (cost 40.6754)  rank=10/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 3, 1, 2, 5, 4] (cost 4.1478)  rank=3/720  in-top-6=True
#
# truth = (0, 3, 1, 2, 5, 4)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5113)  rank=94/720  in-top-6=False
#   max     raw             best=[2, 3, 1, 0, 4, 5] (cost 1.2021)  rank=57/720  in-top-6=False
#   max-min log             best=[0, 1, 3, 2, 4, 5] (cost 64.3630)  rank=44/720  in-top-6=False
# ...
#   aggregate L∞  log       best=[4, 3, 0, 2, 5, 1] (cost 107.7236)  rank=97/720  in-top-6=False
#   aggregate L2  raw       best=[5, 3, 4, 0, 1, 2] (cost 417.2489)  rank=19/720  in-top-6=False
#   aggregate L1  raw       best=[3, 1, 0, 5, 4, 2] (cost 47.5503)  rank=44/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 5, 1, 0, 3, 2] (cost 4.6307)  rank=22/720  in-top-6=False
#
# truth = (5, 4, 1, 2, 0, 3)
#   max-min raw             best=[2, 1, 0, 3, 4, 5] (cost 0.3049)  rank=182/720  in-top-6=False
#   max     raw             best=[2, 5, 3, 1, 4, 0] (cost 0.2752)  rank=136/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 4, 1, 3] (cost 51.6373)  rank=264/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 55.1780)  rank=322/720  in-top-6=False
#   aggregate L2  log       best=[4, 5, 2, 1, 0, 3] (cost 419.2631)  rank=26/720  in-top-6=False
#   aggregate L1  log       best=[4, 5, 2, 1, 0, 3] (cost 2427.5579)  rank=33/720  in-top-6=False
#   aggregate L∞  log       best=[5, 1, 2, 0, 4, 3] (cost 103.0807)  rank=136/720  in-top-6=False
#   aggregate L2  raw       best=[4, 5, 2, 1, 0, 3] (cost 419.2631)  rank=26/720  in-top-6=False
#   aggregate L1  raw       best=[3, 5, 4, 2, 0, 1] (cost 23.1225)  rank=92/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 5, 1, 0, 3, 2] (cost 2.3955)  rank=350/720  in-top-6=False
#
# truth = (5, 4, 1, 2, 3, 0)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 0.6314)  rank=45/720  in-top-6=False
#   max     raw             best=[5, 3, 4, 2, 1, 0] (cost 0.9781)  rank=131/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 3, 0] (cost 47.4865)  rank=429/720  in-top-6=False
#   max     log             best=[4, 0, 2, 5, 1, 3] (cost 48.4634)  rank=252/720  in-top-6=False
#   aggregate L2  log       best=[5, 4, 0, 2, 1, 3] (cost 445.2647)  rank=24/720  in-top-6=False
#   aggregate L1  log       best=[5, 4, 0, 2, 1, 3] (cost 2574.2407)  rank=39/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 1, 0, 4, 2] (cost 109.8655)  rank=36/720  in-top-6=False
#   aggregate L2  raw       best=[5, 4, 0, 2, 1, 3] (cost 445.2647)  rank=24/720  in-top-6=False
#   aggregate L1  raw       best=[5, 4, 2, 3, 1, 0] (cost 43.2472)  rank=7/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 0, 4, 2, 3, 1] (cost 2.8635)  rank=16/720  in-top-6=False
#
# truth = (5, 4, 1, 3, 0, 2)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 0.7238)  rank=81/720  in-top-6=False
#   max     raw             best=[2, 5, 3, 1, 4, 0] (cost 1.1957)  rank=106/720  in-top-6=False
#   max-min log             best=[4, 3, 2, 5, 1, 0] (cost 50.3953)  rank=319/720  in-top-6=False
#   max     log             best=[4, 5, 2, 1, 3, 0] (cost 50.4430)  rank=427/720  in-top-6=False
#   aggregate L2  log       best=[5, 3, 2, 4, 1, 0] (cost 408.7425)  rank=30/720  in-top-6=False
#   aggregate L1  log       best=[5, 3, 2, 4, 1, 0] (cost 2367.0073)  rank=39/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 2, 4, 1, 0] (cost 102.8892)  rank=17/720  in-top-6=False
#   aggregate L2  raw       best=[5, 3, 2, 4, 1, 0] (cost 408.7425)  rank=30/720  in-top-6=False
#   aggregate L1  raw       best=[5, 3, 2, 4, 1, 0] (cost 41.2041)  rank=137/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 4.5824)  rank=47/720  in-top-6=False
#
# truth = (5, 4, 1, 3, 2, 0)
#   max-min raw             best=[2, 0, 1, 3, 4, 5] (cost 1.3351)  rank=53/720  in-top-6=False
#   max     raw             best=[2, 4, 0, 1, 3, 5] (cost 1.3411)  rank=180/720  in-top-6=False
#   max-min log             best=[1, 0, 5, 2, 4, 3] (cost 63.5163)  rank=341/720  in-top-6=False
#   max     log             best=[4, 0, 3, 1, 2, 5] (cost 53.2227)  rank=452/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 0, 3, 2, 5] (cost 483.7527)  rank=220/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 3, 2, 5] (cost 2822.5991)  rank=234/720  in-top-6=False
#   aggregate L∞  log       best=[2, 1, 3, 0, 4, 5] (cost 113.6656)  rank=165/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 0, 3, 2, 5] (cost 483.7527)  rank=220/720  in-top-6=False
#   aggregate L1  raw       best=[4, 0, 3, 1, 2, 5] (cost 58.8764)  rank=361/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 0, 3, 1, 2, 5] (cost 5.3252)  rank=227/720  in-top-6=False
#
# truth = (5, 4, 2, 0, 1, 3)
#   max-min raw             best=[5, 1, 2, 4, 3, 0] (cost 0.4521)  rank=440/720  in-top-6=False
#   max     raw             best=[2, 4, 3, 1, 0, 5] (cost 1.3768)  rank=234/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 0, 3] (cost 40.0305)  rank=11/720  in-top-6=False
#   max     log             best=[4, 0, 2, 1, 5, 3] (cost 45.9810)  rank=14/720  in-top-6=False
#   aggregate L2  log       best=[5, 3, 2, 4, 1, 0] (cost 425.0983)  rank=2/720  in-top-6=True
#   aggregate L1  log       best=[5, 3, 2, 4, 1, 0] (cost 2447.2478)  rank=2/720  in-top-6=True
#   aggregate L∞  log       best=[5, 2, 0, 4, 1, 3] (cost 106.9729)  rank=19/720  in-top-6=False
#   aggregate L2  raw       best=[5, 3, 2, 4, 1, 0] (cost 425.0983)  rank=2/720  in-top-6=True
#   aggregate L1  raw       best=[5, 3, 2, 4, 1, 0] (cost 43.8212)  rank=13/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 3, 2, 4, 1, 0] (cost 3.3144)  rank=90/720  in-top-6=False
#
# truth = (5, 4, 2, 0, 3, 1)
#   max-min raw             best=[4, 1, 5, 2, 3, 0] (cost 1.5963)  rank=314/720  in-top-6=False
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6526)  rank=259/720  in-top-6=False
#   max-min log             best=[4, 0, 5, 2, 1, 3] (cost 52.5600)  rank=584/720  in-top-6=False
#   max     log             best=[1, 0, 4, 2, 3, 5] (cost 38.6655)  rank=430/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 5, 2, 3, 4] (cost 446.8815)  rank=186/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 2, 3, 4] (cost 2588.2029)  rank=242/720  in-top-6=False
#   aggregate L∞  log       best=[4, 1, 5, 0, 3, 2] (cost 105.0894)  rank=426/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 5, 2, 3, 4] (cost 446.8815)  rank=186/720  in-top-6=False
#   aggregate L1  raw       best=[4, 1, 5, 0, 3, 2] (cost 53.2142)  rank=66/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 1, 4, 2, 3, 5] (cost 5.1277)  rank=141/720  in-top-6=False
#
# truth = (5, 4, 2, 1, 0, 3)
#   max-min raw             best=[2, 1, 0, 4, 3, 5] (cost 0.4183)  rank=234/720  in-top-6=False
#   max     raw             best=[2, 5, 1, 4, 3, 0] (cost 0.3262)  rank=122/720  in-top-6=False
#   max-min log             best=[0, 5, 2, 1, 4, 3] (cost 51.4938)  rank=34/720  in-top-6=False
#   max     log             best=[0, 5, 2, 1, 4, 3] (cost 53.3647)  rank=14/720  in-top-6=False
#   aggregate L2  log       best=[4, 5, 2, 1, 0, 3] (cost 427.8040)  rank=5/720  in-top-6=True
#   aggregate L1  log       best=[4, 5, 2, 1, 0, 3] (cost 2461.3816)  rank=9/720  in-top-6=False
#   aggregate L∞  log       best=[4, 0, 2, 1, 5, 3] (cost 106.9177)  rank=13/720  in-top-6=False
#   aggregate L2  raw       best=[4, 5, 2, 1, 0, 3] (cost 427.8040)  rank=5/720  in-top-6=True
#   aggregate L1  raw       best=[3, 2, 4, 5, 0, 1] (cost 24.4975)  rank=28/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 1, 0, 2, 5, 3] (cost 1.5265)  rank=250/720  in-top-6=False
#
# truth = (5, 4, 2, 1, 3, 0)
#   max-min raw             best=[5, 0, 4, 1, 3, 2] (cost 1.1339)  rank=6/720  in-top-6=True
#   max     raw             best=[0, 1, 5, 2, 3, 4] (cost 1.6526)  rank=395/720  in-top-6=False
#   max-min log             best=[5, 4, 2, 1, 3, 0] (cost 54.0660)  rank=1/720  in-top-6=True
#   max     log             best=[4, 0, 1, 2, 3, 5] (cost 41.6719)  rank=151/720  in-top-6=False
#   aggregate L2  log       best=[1, 0, 5, 4, 3, 2] (cost 462.6664)  rank=22/720  in-top-6=False
#   aggregate L1  log       best=[1, 0, 5, 4, 3, 2] (cost 2699.7290)  rank=25/720  in-top-6=False
#   aggregate L∞  log       best=[1, 0, 5, 3, 4, 2] (cost 107.1009)  rank=152/720  in-top-6=False
#   aggregate L2  raw       best=[1, 0, 5, 4, 3, 2] (cost 462.6664)  rank=22/720  in-top-6=False
#   aggregate L1  raw       best=[5, 0, 2, 4, 1, 3] (cost 56.5191)  rank=17/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 4, 2, 1, 3, 0] (cost 5.0658)  rank=1/720  in-top-6=True
#
# truth = (5, 4, 2, 3, 0, 1)
#   max-min raw             best=[5, 0, 2, 3, 4, 1] (cost 0.2954)  rank=10/720  in-top-6=False
#   max     raw             best=[2, 5, 3, 1, 4, 0] (cost 1.3129)  rank=157/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 0, 3] (cost 46.5611)  rank=166/720  in-top-6=False
#   max     log             best=[4, 5, 2, 1, 3, 0] (cost 50.9347)  rank=170/720  in-top-6=False
#   aggregate L2  log       best=[5, 2, 4, 1, 0, 3] (cost 401.0468)  rank=21/720  in-top-6=False
#   aggregate L1  log       best=[5, 2, 4, 1, 0, 3] (cost 2315.4187)  rank=30/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 2, 4, 0, 1] (cost 99.3531)  rank=3/720  in-top-6=True
#   aggregate L2  raw       best=[5, 2, 4, 1, 0, 3] (cost 401.0468)  rank=21/720  in-top-6=False
#   aggregate L1  raw       best=[1, 4, 2, 5, 0, 3] (cost 39.2837)  rank=2/720  in-top-6=True
#   aggregate L∞  raw       best=[4, 2, 1, 5, 0, 3] (cost 4.1091)  rank=30/720  in-top-6=False
#
# truth = (5, 4, 2, 3, 1, 0)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 0.4947)  rank=4/720  in-top-6=True
#   max     raw             best=[0, 3, 5, 2, 1, 4] (cost 1.7711)  rank=324/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 3, 0] (cost 49.2525)  rank=37/720  in-top-6=False
#   max     log             best=[4, 1, 2, 5, 3, 0] (cost 46.3108)  rank=150/720  in-top-6=False
#   aggregate L2  log       best=[5, 3, 2, 4, 0, 1] (cost 392.1271)  rank=22/720  in-top-6=False
#   aggregate L1  log       best=[5, 3, 2, 4, 0, 1] (cost 2275.4768)  rank=59/720  in-top-6=False
#   aggregate L∞  log       best=[4, 3, 2, 5, 1, 0] (cost 97.8973)  rank=2/720  in-top-6=True
#   aggregate L2  raw       best=[5, 3, 2, 4, 0, 1] (cost 392.1271)  rank=22/720  in-top-6=False
#   aggregate L1  raw       best=[5, 3, 2, 4, 1, 0] (cost 36.9356)  rank=2/720  in-top-6=True
#   aggregate L∞  raw       best=[5, 4, 2, 3, 1, 0] (cost 3.9399)  rank=1/720  in-top-6=True
#
# truth = (5, 4, 3, 0, 1, 2)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 0.8150)  rank=14/720  in-top-6=False
#   max     raw             best=[0, 3, 5, 2, 1, 4] (cost 2.1578)  rank=397/720  in-top-6=False
#   max-min log             best=[0, 5, 4, 1, 2, 3] (cost 49.1261)  rank=148/720  in-top-6=False
#   max     log             best=[2, 0, 5, 1, 4, 3] (cost 52.1422)  rank=103/720  in-top-6=False
#   aggregate L2  log       best=[0, 5, 4, 2, 1, 3] (cost 411.4036)  rank=116/720  in-top-6=False
#   aggregate L1  log       best=[0, 5, 4, 2, 1, 3] (cost 2373.7632)  rank=166/720  in-top-6=False
#   aggregate L∞  log       best=[5, 2, 4, 3, 1, 0] (cost 98.5085)  rank=31/720  in-top-6=False
#   aggregate L2  raw       best=[0, 5, 4, 2, 1, 3] (cost 411.4036)  rank=116/720  in-top-6=False
#   aggregate L1  raw       best=[5, 3, 2, 4, 1, 0] (cost 44.6407)  rank=22/720  in-top-6=False
#   aggregate L∞  raw       best=[0, 5, 2, 3, 1, 4] (cost 4.3859)  rank=53/720  in-top-6=False
#
# truth = (5, 4, 3, 0, 2, 1)
#   max-min raw             best=[5, 0, 1, 3, 4, 2] (cost 0.5074)  rank=87/720  in-top-6=False
#   max     raw             best=[0, 3, 5, 2, 1, 4] (cost 0.7828)  rank=660/720  in-top-6=False
#   max-min log             best=[5, 4, 2, 1, 3, 0] (cost 42.9756)  rank=466/720  in-top-6=False
#   max     log             best=[4, 1, 2, 0, 3, 5] (cost 42.6187)  rank=558/720  in-top-6=False
#   aggregate L2  log       best=[1, 4, 3, 5, 2, 0] (cost 448.8866)  rank=4/720  in-top-6=True
#   aggregate L1  log       best=[1, 4, 3, 5, 2, 0] (cost 2600.5532)  rank=9/720  in-top-6=False
#   aggregate L∞  log       best=[1, 4, 5, 0, 3, 2] (cost 106.7145)  rank=22/720  in-top-6=False
#   aggregate L2  raw       best=[1, 4, 3, 5, 2, 0] (cost 448.8866)  rank=4/720  in-top-6=True
#   aggregate L1  raw       best=[1, 4, 3, 0, 2, 5] (cost 46.1495)  rank=33/720  in-top-6=False
#   aggregate L∞  raw       best=[2, 3, 4, 5, 0, 1] (cost 4.3024)  rank=254/720  in-top-6=False
#
# truth = (5, 4, 3, 1, 0, 2)
#   max-min raw             best=[5, 0, 3, 4, 1, 2] (cost 1.1603)  rank=21/720  in-top-6=False
#   max     raw             best=[3, 4, 0, 2, 1, 5] (cost 0.7696)  rank=272/720  in-top-6=False
#   max-min log             best=[4, 5, 0, 1, 2, 3] (cost 48.0190)  rank=61/720  in-top-6=False
#   max     log             best=[4, 0, 5, 1, 3, 2] (cost 38.7252)  rank=94/720  in-top-6=False
#   aggregate L2  log       best=[5, 3, 4, 2, 0, 1] (cost 430.6349)  rank=29/720  in-top-6=False
#   aggregate L1  log       best=[2, 5, 4, 1, 0, 3] (cost 2456.4827)  rank=39/720  in-top-6=False
#   aggregate L∞  log       best=[1, 5, 0, 2, 4, 3] (cost 107.1478)  rank=505/720  in-top-6=False
#   aggregate L2  raw       best=[5, 3, 4, 2, 0, 1] (cost 430.6349)  rank=29/720  in-top-6=False
#   aggregate L1  raw       best=[5, 4, 3, 2, 1, 0] (cost 48.8900)  rank=13/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 0, 1, 2, 3, 4] (cost 4.9876)  rank=119/720  in-top-6=False
#
# truth = (5, 4, 3, 1, 2, 0)
#   max-min raw             best=[2, 0, 1, 3, 4, 5] (cost 1.2960)  rank=422/720  in-top-6=False
#   max     raw             best=[2, 4, 0, 1, 3, 5] (cost 1.3215)  rank=86/720  in-top-6=False
#   max-min log             best=[5, 2, 0, 1, 4, 3] (cost 55.7868)  rank=105/720  in-top-6=False
#   max     log             best=[4, 0, 3, 1, 2, 5] (cost 53.2029)  rank=103/720  in-top-6=False
#   aggregate L2  log       best=[2, 4, 0, 1, 3, 5] (cost 470.1493)  rank=165/720  in-top-6=False
#   aggregate L1  log       best=[2, 4, 0, 1, 3, 5] (cost 2730.1152)  rank=123/720  in-top-6=False
#   aggregate L∞  log       best=[2, 4, 3, 1, 0, 5] (cost 111.4637)  rank=60/720  in-top-6=False
#   aggregate L2  raw       best=[2, 4, 0, 1, 3, 5] (cost 470.1493)  rank=165/720  in-top-6=False
#   aggregate L1  raw       best=[4, 0, 3, 1, 2, 5] (cost 57.7045)  rank=295/720  in-top-6=False
#   aggregate L∞  raw       best=[4, 0, 3, 1, 2, 5] (cost 5.2695)  rank=108/720  in-top-6=False
#
# truth = (5, 4, 3, 2, 0, 1)
#   max-min raw             best=[5, 4, 0, 3, 1, 2] (cost 1.4158)  rank=88/720  in-top-6=False
#   max     raw             best=[3, 4, 0, 2, 1, 5] (cost 0.9020)  rank=144/720  in-top-6=False
#   max-min log             best=[4, 5, 2, 1, 0, 3] (cost 45.9265)  rank=552/720  in-top-6=False
#   max     log             best=[4, 3, 2, 1, 0, 5] (cost 41.4736)  rank=629/720  in-top-6=False
#   aggregate L2  log       best=[4, 5, 2, 1, 0, 3] (cost 397.9591)  rank=112/720  in-top-6=False
#   aggregate L1  log       best=[4, 5, 2, 1, 0, 3] (cost 2246.7798)  rank=176/720  in-top-6=False
#   aggregate L∞  log       best=[5, 3, 4, 2, 0, 1] (cost 108.5906)  rank=49/720  in-top-6=False
#   aggregate L2  raw       best=[4, 5, 2, 1, 0, 3] (cost 397.9591)  rank=112/720  in-top-6=False
#   aggregate L1  raw       best=[5, 4, 3, 2, 1, 0] (cost 46.4719)  rank=8/720  in-top-6=False
#   aggregate L∞  raw       best=[5, 0, 4, 2, 3, 1] (cost 4.7589)  rank=31/720  in-top-6=False
#
# truth = (5, 4, 3, 2, 1, 0)
#   max-min raw             best=[5, 0, 4, 3, 1, 2] (cost 1.1627)  rank=12/720  in-top-6=False
#   max     raw             best=[2, 3, 4, 0, 1, 5] (cost 1.8600)  rank=121/720  in-top-6=False
#   max-min log             best=[4, 2, 5, 3, 1, 0] (cost 55.4375)  rank=2/720  in-top-6=True
#   max     log             best=[1, 0, 4, 2, 3, 5] (cost 38.6655)  rank=194/720  in-top-6=False
#   aggregate L2  log       best=[5, 4, 0, 2, 3, 1] (cost 489.4779)  rank=42/720  in-top-6=False
#   aggregate L1  log       best=[1, 4, 0, 2, 3, 5] (cost 2859.5339)  rank=48/720  in-top-6=False
#   aggregate L∞  log       best=[5, 2, 1, 0, 4, 3] (cost 113.5855)  rank=373/720  in-top-6=False
#   aggregate L2  raw       best=[5, 4, 0, 2, 3, 1] (cost 489.4779)  rank=42/720  in-top-6=False
#   aggregate L1  raw       best=[5, 4, 3, 2, 1, 0] (cost 58.9503)  rank=1/720  in-top-6=True
#   aggregate L∞  raw       best=[5, 0, 1, 2, 3, 4] (cost 5.3813)  rank=47/720  in-top-6=False

# %%
T = len(permutations)
print('=' * 90)
print(f'Summary over all {T} permutations of S_{N}')
print(f'Random baselines: top-1 ~ {100/T:.1f}%, top-{N} ~ {100*N/T:.1f}%, mean rank ~ {(T+1)/2:.1f}')
print('-' * 90)
print(f'{"method":<24} {"top-1":>10} {"top-N":>10} {"mean rank":>14}')
for m in METHODS:
    print(f'{m:<24} {top1[m]}/{T:<6} {topN[m]}/{T:<6} {sum(ranks[m])/T:>12.2f}')
print('-' * 90)
print(f'{"union (any method)":<24} {union_top1}/{T:<6} {union_topN}/{T:<6}')
# Out:
# ==========================================================================================
# Summary over all 720 permutations of S_6
# Random baselines: top-1 ~ 0.1%, top-6 ~ 0.8%, mean rank ~ 360.5
# ------------------------------------------------------------------------------------------
# method                        top-1      top-N      mean rank
# max-min raw              2/720    23/720          271.41
# max     raw              1/720    16/720          257.71
# max-min log              3/720    20/720          257.23
# max     log              2/720    27/720          231.05
# aggregate L2  log        33/720    127/720           95.25
# aggregate L1  log        29/720    111/720          104.28
# aggregate L∞  log        18/720    81/720          155.16
# aggregate L2  raw        33/720    127/720           95.25
# aggregate L1  raw        25/720    127/720           90.57
# aggregate L∞  raw        18/720    69/720          131.18
# ------------------------------------------------------------------------------------------
# union (any method)       88/720    301/720
