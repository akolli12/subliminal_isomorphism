# %% [markdown]
# # All 8 extraction algorithms
#
# Same τ and τ_log build as `raw_vs_log.ipynb`, plus four **aggregate** methods that use the entire (i, v) slice of τ instead of picking one witness coordinate.
#
# **Single-witness methods** (use one $(i_j, v_j)$ per $j$):
# 1. max-spread + raw cost
# 2. max-min spread + raw cost  (top1 − top2 margin)
# 3. max-spread + log cost
# 4. max-min spread + log cost
#
# **Aggregate methods** (use all $n^2$ cells in the (i, v) slice — no witness needed):
# 5. aggregate L2  + log cost   ←  paper's choice (Assumption `positional-leakage`)
# 6. aggregate L1  + log cost
# 7. aggregate L∞  + log cost
# 8. aggregate L2  + raw cost
#
# All eight methods report top-1 / top-N / mean rank, plus a union row.

# %%
import sys, random, itertools
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import linear_sum_assignment

import config
from model import TinyTransformer

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
N = config.N
EPS = 1e-12
print(f'N = {N}, device = {DEVICE}')
# Out:
# N = 7, device = cuda

# %%
CHECKPOINT = PROJECT_ROOT / 'checkpoints' / 'model_10000_7.pt'

def load_model(path):
    m = TinyTransformer().to(DEVICE)
    m.load_state_dict(torch.load(path, map_location=DEVICE))
    m.eval()
    return m

model = load_model(CHECKPOINT)
print(f'Loaded {CHECKPOINT.name}')
# Out:
# Loaded model_10000_7.pt
# /home/akash10/miniconda3/envs/aug-spm/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /tmp/ipykernel_702800/1577372277.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   m.load_state_dict(torch.load(path, map_location=DEVICE))

# %%
@torch.no_grad()
def sample_psi_unconstrained(model, phis):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    psi_start = config.PSI.start
    psi_buf = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    seq = torch.cat([phis.to(DEVICE), psi_buf], dim=1)
    for j in range(N):
        logits = model(seq)
        step_logits = logits[:, psi_start - 1 + j, :]
        probs = F.softmax(step_logits, dim=-1)
        sampled = torch.multinomial(probs, num_samples=1).squeeze(-1)
        seq[:, psi_start + j] = sampled
    return seq[:, psi_start:psi_start + N]

def is_perm_rows(samples, n):
    sorted_, _ = torch.sort(samples, dim=1)
    expected = torch.arange(n, device=samples.device).unsqueeze(0).expand_as(sorted_)
    return (sorted_ == expected).all(dim=1)

@torch.no_grad()
def sample_psi_rejection(model, phis, max_attempts=1000):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    phis = phis.to(DEVICE)
    out     = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    pending = torch.ones(B,        dtype=torch.bool, device=DEVICE)
    for _ in range(max_attempts):
        idx = torch.nonzero(pending, as_tuple=False).squeeze(1)
        if idx.numel() == 0:
            break
        psis_try = sample_psi_unconstrained(model, phis[idx])
        valid = is_perm_rows(psis_try, N)
        out[idx[valid]] = psis_try[valid]
        pending[idx[valid]] = False
    if pending.any():
        raise RuntimeError(
            f'{int(pending.sum().item())} rows still invalid after {max_attempts} attempts'
        )
    return out

@torch.no_grad()                                                                                                            
def sample_psi_rejection_fallback(model, phis, max_attempts=1000):
    """Whole-sequence rejection: resample any row whose psi isn't a permutation.                                            
                                                                                                                            
    Soft fail: if some rows are still invalid after max_attempts, keep their                                                
    last (possibly repeating) sample and print a warning instead of raising.                                                
    """         
    model.eval()                                                                                                            
    if phis.dim() == 1:                                                                                                     
        phis = phis.unsqueeze(0)
    B = phis.shape[0]                                                                                                       
    phis = phis.to(DEVICE)
    out     = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    pending = torch.ones(B,        dtype=torch.bool, device=DEVICE)                                                         
                                                                                                                            
    for _ in range(max_attempts):                                                                                           
        idx = torch.nonzero(pending, as_tuple=False).squeeze(1)                                                             
        if idx.numel() == 0:
            break
        psis_try = sample_psi_unconstrained(model, phis[idx])
        valid = is_perm_rows(psis_try, N)                                                                                   
        # Always write this attempt; rows that are still pending will get
        # overwritten next round, valid rows are frozen by `pending=False`.                                                 
        out[idx] = psis_try                                                                                                 
        pending[idx[valid]] = False                                                                                         
                                                                                                                            
    if pending.any():
        n_failed = int(pending.sum().item())                                                                                
        print(f"  [warn] {n_failed}/{B} rows still invalid after {max_attempts} "
            f"attempts; keeping last (possibly-invalid) sample")                                                          
                                                                                                                            
    return out      

def marginal_matrix(samples, n=N):
    return F.one_hot(samples.long(), n).float().mean(dim=0)

def random_phis_with_constraint(B, j, u, n=N, seed=None):
    g = torch.Generator()
    if seed is not None: g.manual_seed(seed)
    other_positions = torch.tensor([i for i in range(n) if i != j], dtype=torch.long)
    other_values    = torch.tensor([v for v in range(n) if v != u], dtype=torch.long)
    keys = torch.rand((B, n - 1), generator=g)
    perms = keys.argsort(dim=1)
    perm_values = other_values[perms]
    out = torch.zeros((B, n), dtype=torch.long)
    out[:, j] = u
    out[:, other_positions] = perm_values
    return out

# %%
def best_assignment(C):
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    row_ind, col_ind = linear_sum_assignment(C_np)
    return torch.tensor(col_ind, dtype=torch.long), float(C_np[row_ind, col_ind].sum())

def top_k_assignments(C, k=None):
    n = C.shape[0]
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    rows = np.arange(n)
    scored = [
        (C_np[rows, list(perm)].sum(), perm)
        for perm in itertools.permutations(range(n))
    ]
    scored.sort(key=lambda x: x[0])
    if k is not None:
        scored = scored[:k]
    return [(torch.tensor(p, dtype=torch.long), float(c)) for c, p in scored]

# %% [markdown]
# ## Build τ and τ_log
#
# K1 phis per (j, u); K2 psis per phi. Per-phi marginal computed first, then both raw average and log-then-average over the K1 phis.

# %%
tau     = {}
tau_log = {}

seed = 42
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

K1 = 2**9      # phis per (j, u)
K2 = 2**9         # psis per phi (large to keep log-bias small)
CHUNK = 2**17     # rows per model.forward call

for j in range(N):
    for u in range(N):
        phis = random_phis_with_constraint(K1, j=j, u=u)
        sum_p     = torch.zeros((N, N), device=DEVICE)
        sum_log_p = torch.zeros((N, N), device=DEVICE)

        if K2 <= CHUNK:
            phi_chunk = max(1, CHUNK // K2)
            psi_subchunk = K2
        else:
            phi_chunk = 1
            psi_subchunk = CHUNK

        for phi_start in range(0, K1, phi_chunk):
            P = min(phi_chunk, K1 - phi_start)
            this_phis = phis[phi_start:phi_start + P]
            counts = torch.zeros((P, N, N), device=DEVICE)
            for psi_start in range(0, K2, psi_subchunk):
                S = min(psi_subchunk, K2 - psi_start)
                phi_rep = this_phis.repeat_interleave(S, dim=0)
                psis    = sample_psi_rejection_fallback(model, phi_rep)
                psis    = psis.view(P, S, N)
                counts += F.one_hot(psis.long(), N).float().sum(dim=1)
            M_per_phi = counts / K2
            sum_p     += M_per_phi.sum(dim=0)
            sum_log_p += torch.log(M_per_phi.clamp_min(EPS)).sum(dim=0)

        avg_p     = sum_p / K1
        avg_log_p = sum_log_p / K1
        for i in range(N):
            for v in range(N):
                tau[(i, j, v, u)]     = avg_p[i, v]
                tau_log[(i, j, v, u)] = avg_log_p[i, v]
        print(f'  cell (j={j}, u={u}) done')
# Out:
#   cell (j=0, u=0) done
#   cell (j=0, u=1) done
#   cell (j=0, u=2) done
#   cell (j=0, u=3) done
#   cell (j=0, u=4) done
#   cell (j=0, u=5) done
#   cell (j=0, u=6) done
#   cell (j=1, u=0) done
#   cell (j=1, u=1) done
#   cell (j=1, u=2) done
#   cell (j=1, u=3) done
#   cell (j=1, u=4) done
#   cell (j=1, u=5) done
#   cell (j=1, u=6) done
#   cell (j=2, u=0) done
#   cell (j=2, u=1) done
#   cell (j=2, u=2) done
#   cell (j=2, u=3) done
#   cell (j=2, u=4) done
#   cell (j=2, u=5) done
#   cell (j=2, u=6) done
#   [warn] 88/131072 rows still invalid after 1000 attempts; keeping last (possibly-invalid) sample
#   cell (j=3, u=0) done
#   cell (j=3, u=1) done
#   cell (j=3, u=2) done
#   cell (j=3, u=3) done
#   cell (j=3, u=4) done
#   cell (j=3, u=5) done
#   cell (j=3, u=6) done
#   cell (j=4, u=0) done
#   cell (j=4, u=1) done
#   cell (j=4, u=2) done
#   cell (j=4, u=3) done
#   cell (j=4, u=4) done
#   cell (j=4, u=5) done
#   [warn] 93/131072 rows still invalid after 1000 attempts; keeping last (possibly-invalid) sample
#   cell (j=4, u=6) done
#   cell (j=5, u=0) done
#   cell (j=5, u=1) done
#   cell (j=5, u=2) done
#   cell (j=5, u=3) done
#   cell (j=5, u=4) done
#   cell (j=5, u=5) done
#   cell (j=5, u=6) done
#   cell (j=6, u=0) done
#   cell (j=6, u=1) done
#   cell (j=6, u=2) done
#   cell (j=6, u=3) done
#   cell (j=6, u=4) done
#   cell (j=6, u=5) done
#   cell (j=6, u=6) done

# %%
tau
# Out:
# {(0, 0, 0, 0): tensor(0.1462, device='cuda:0'),
#  (0, 0, 1, 0): tensor(0.1715, device='cuda:0'),
#  (0, 0, 2, 0): tensor(0.1461, device='cuda:0'),
#  (6, 0, 0, 3): tensor(0.0722, device='cuda:0'),
#  (6, 0, 1, 3): tensor(0.1977, device='cuda:0'),
#  (6, 0, 2, 3): tensor(0.2250, device='cuda:0'),
#  (6, 0, 3, 3): tensor(0.1397, device='cuda:0'),
#  (6, 0, 4, 3): tensor(0.1168, device='cuda:0'),
#  (6, 0, 5, 3): tensor(0.1316, device='cuda:0'),
#  (6, 0, 6, 3): tensor(0.1170, device='cuda:0'),
#  (0, 0, 0, 4): tensor(0.1240, device='cuda:0'),
#  (0, 0, 1, 4): tensor(0.1812, device='cuda:0'),
#  (0, 0, 2, 4): tensor(0.1156, device='cuda:0'),
#  (0, 0, 3, 4): tensor(0.1213, device='cuda:0'),
#  (0, 0, 4, 4): tensor(0.1121, device='cuda:0'),
#  (0, 0, 5, 4): tensor(0.2293, device='cuda:0'),
#  (0, 0, 6, 4): tensor(0.1165, device='cuda:0'),
#  (1, 0, 0, 4): tensor(0.2276, device='cuda:0'),
#  (1, 0, 1, 4): tensor(0.1899, device='cuda:0'),
#  (1, 0, 2, 4): tensor(0.1599, device='cuda:0'),
#  (1, 0, 3, 4): tensor(0.0588, device='cuda:0'),
#  (1, 0, 4, 4): tensor(0.1572, device='cuda:0'),
#  (1, 0, 5, 4): tensor(0.1371, device='cuda:0'),
#  (1, 0, 6, 4): tensor(0.0697, device='cuda:0'),
#  (2, 0, 0, 4): tensor(0.1590, device='cuda:0'),
#  (2, 0, 1, 4): tensor(0.0718, device='cuda:0'),
#  (2, 0, 2, 4): tensor(0.0348, device='cuda:0'),
#  (2, 0, 3, 4): tensor(0.1784, device='cuda:0'),
#  (2, 0, 4, 4): tensor(0.1346, device='cuda:0'),
#  (2, 0, 5, 4): tensor(0.2278, device='cuda:0'),
#  (2, 0, 6, 4): tensor(0.1937, device='cuda:0'),
#  (3, 0, 0, 4): tensor(0.1425, device='cuda:0'),
#  (3, 0, 1, 4): tensor(0.1489, device='cuda:0'),
#  (3, 0, 2, 4): tensor(0.1729, device='cuda:0'),
#  (3, 0, 3, 4): tensor(0.1665, device='cuda:0'),
#  (3, 0, 4, 4): tensor(0.1465, device='cuda:0'),
#  (3, 0, 5, 4): tensor(0.0832, device='cuda:0'),
#  (3, 0, 6, 4): tensor(0.1394, device='cuda:0'),
#  (4, 0, 0, 4): tensor(0.1912, device='cuda:0'),
#  (4, 0, 1, 4): tensor(0.1326, device='cuda:0'),
#  (4, 0, 2, 4): tensor(0.1003, device='cuda:0'),
#  (4, 0, 3, 4): tensor(0.1568, device='cuda:0'),
#  (4, 0, 4, 4): tensor(0.1541, device='cuda:0'),
#  (4, 0, 5, 4): tensor(0.0947, device='cuda:0'),
#  (4, 0, 6, 4): tensor(0.1703, device='cuda:0'),
#  (5, 0, 0, 4): tensor(0.0931, device='cuda:0'),
#  (5, 0, 1, 4): tensor(0.1043, device='cuda:0'),
#  (5, 0, 2, 4): tensor(0.2028, device='cuda:0'),
#  (5, 0, 3, 4): tensor(0.1708, device='cuda:0'),
#  (5, 0, 4, 4): tensor(0.1315, device='cuda:0'),
#  (0, 2, 3, 6): tensor(0.1281, device='cuda:0'),
#  (0, 2, 4, 6): tensor(0.0699, device='cuda:0'),
#  (0, 2, 5, 6): tensor(0.1511, device='cuda:0'),
#  (0, 2, 6, 6): tensor(0.1621, device='cuda:0'),
#  (1, 2, 0, 6): tensor(0.1675, device='cuda:0'),
#  (1, 2, 1, 6): tensor(0.1171, device='cuda:0'),
#  (1, 2, 2, 6): tensor(0.1361, device='cuda:0'),
#  (1, 2, 3, 6): tensor(0.0665, device='cuda:0'),
#  (1, 2, 4, 6): tensor(0.1963, device='cuda:0'),
#  (1, 2, 5, 6): tensor(0.1324, device='cuda:0'),
#  (1, 2, 6, 6): tensor(0.1843, device='cuda:0'),
#  (2, 2, 0, 6): tensor(0.2366, device='cuda:0'),
#  (2, 2, 1, 6): tensor(0.1269, device='cuda:0'),
#  (2, 2, 2, 6): tensor(0.0648, device='cuda:0'),
#  (2, 2, 3, 6): tensor(0.2190, device='cuda:0'),
#  (2, 2, 4, 6): tensor(0.1268, device='cuda:0'),
#  (2, 2, 5, 6): tensor(0.1200, device='cuda:0'),
#  ...}

# %% [markdown]
# ## Tensorize τ and τ_log for the aggregate methods
#
# Build dense `(N, N, N, N)` tensors on DEVICE so the aggregate cost reduces to one broadcast subtract + reduce over `(i, v)` — no per-cell Python loops.

# %%
def to_tensor(tau_dict):
    """Pack {(i, j, v, u): scalar} → tensor of shape (N, N, N, N) indexed [i, j, v, u]."""
    T = torch.zeros((N, N, N, N), device=DEVICE)
    for i in range(N):
        for j in range(N):
            for v in range(N):
                for u in range(N):
                    T[i, j, v, u] = tau_dict[(i, j, v, u)]
    return T

tau_tensor     = to_tensor(tau)
tau_log_tensor = to_tensor(tau_log)
print(f'tau_tensor    : {tuple(tau_tensor.shape)}, device={tau_tensor.device}')
print(f'tau_log_tensor: {tuple(tau_log_tensor.shape)}, device={tau_log_tensor.device}')
# Out:
# tau_tensor    : (7, 7, 7, 7), device=cuda:0
# tau_log_tensor: (7, 7, 7, 7), device=cuda:0

# %% [markdown]
# ## Pick witnesses (for the four single-witness methods)

# %%
def pick_witnesses(tau_dict):
    """Return (opts_max_spread, opts_max_min_spread): each {j: (i_j, v_j)}."""
    opts_ms, opts_mm = {}, {}
    for j in range(N):
        scores_ms = torch.zeros((N, N))
        scores_mm = torch.zeros((N, N))
        for i in range(N):
            for v in range(N):
                u_func = torch.tensor([tau_dict[(i, j, v, u)].item()
                                       if torch.is_tensor(tau_dict[(i, j, v, u)])
                                       else tau_dict[(i, j, v, u)]
                                       for u in range(N)])
                scores_ms[i, v] = u_func.max() - u_func.min()
                sorted_, _ = torch.sort(u_func, descending=True)
                scores_mm[i, v] = sorted_[0] - sorted_[1]
        i_ms = (scores_ms.argmax() // N).item(); v_ms = (scores_ms.argmax() % N).item()
        i_mm = (scores_mm.argmax() // N).item(); v_mm = (scores_mm.argmax() % N).item()
        opts_ms[j], opts_mm[j] = (i_ms, v_ms), (i_mm, v_mm)
    return opts_ms, opts_mm

opts_max_spread,     opts_max_min_spread     = pick_witnesses(tau)
opts_max_spread_log, opts_max_min_spread_log = pick_witnesses(tau_log)

print('raw — opts_max_spread:    ', opts_max_spread)
print('raw — opts_max_min_spread:', opts_max_min_spread)
print('log — opts_max_spread:    ', opts_max_spread_log)
print('log — opts_max_spread:    ', opts_max_min_spread_log)
# Out:
# raw — opts_max_spread:     {0: (1, 4), 1: (3, 3), 2: (0, 2), 3: (1, 2), 4: (0, 6), 5: (0, 6), 6: (0, 0)}
# raw — opts_max_min_spread: {0: (1, 4), 1: (3, 3), 2: (5, 2), 3: (0, 0), 4: (1, 0), 5: (6, 4), 6: (3, 6)}
# log — opts_max_spread:     {0: (2, 6), 1: (3, 0), 2: (0, 1), 3: (1, 2), 4: (5, 1), 5: (4, 2), 6: (0, 4)}
# log — opts_max_spread:     {0: (4, 2), 1: (4, 6), 2: (1, 2), 3: (0, 4), 4: (1, 5), 5: (3, 2), 6: (0, 4)}

# %% [markdown]
# ## Extract over all permutations — all 8 methods
#
# For each test phi:
# 1. Sample `B` psis (chunked by `B_CHUNK`); compute `mm` and `log_mm`.
# 2. For each of the 8 methods, build cost matrix `C[j, u]`, run brute-force ranking, record rank of truth.
# 3. Track top-1 / top-N / mean rank per method, plus union (any method).
#
# **Cost matrix construction by method `kind`:**
# - `raw` — single witness, raw scale: `C[j,u] = |τ[i_j,j,v_j,u] - mm[i_j,v_j]|`
# - `log` — single witness, log scale: `C[j,u] = |τ_log[i_j,j,v_j,u] - log_mm[i_j,v_j]|`
# - `agg_l2_log` / `agg_l1_log` / `agg_linf_log` — aggregate over (i, v) of `|log_mm - τ_log[:, j, :, u]|` under L2 / L1 / L∞
# - `agg_l2_raw` — same but raw: aggregate L2 of `|mm - τ[:, j, :, u]|`

# %%
B = K2                                                 # psi samples per test phi
B_CHUNK = CHUNK                                           # forward-pass batch size
permutations = list(itertools.permutations(range(N)))

seed = 0
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

# (witness_dict_or_None, tau_dict_or_None, kind)
METHODS = {
    'max-min raw':       (opts_max_min_spread,     tau,     'raw'),
    'max     raw':       (opts_max_spread,         tau,     'raw'),
    'max-min log':       (opts_max_min_spread_log, tau_log, 'log'),
    'max     log':       (opts_max_spread_log,     tau_log, 'log'),
    'aggregate L2  log': (None, None, 'agg_l2_log'),
    'aggregate L1  log': (None, None, 'agg_l1_log'),
    'aggregate L\u221E  log': (None, None, 'agg_linf_log'),
    'aggregate L2  raw': (None, None, 'agg_l2_log'),
    'aggregate L1  raw': (None, None, 'agg_l1_raw'),
    'aggregate L\u221E  raw': (None, None, 'agg_linf_raw'),
}

ranks = {m: [] for m in METHODS}
top1  = {m: 0  for m in METHODS}
topN  = {m: 0  for m in METHODS}
union_top1 = 0
union_topN = 0

def build_cost(kind, opts_dict, tau_dict, mm, log_mm):
    """Return (N, N) cost matrix on CPU."""
    if kind == 'raw':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            p_j = mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - p_j)
        return C
    if kind == 'log':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            lp_j = log_mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - lp_j)
        return C

    # aggregate methods: broadcast (N, N) test marginal vs. (N, N, N, N) tau tensor
    if kind == 'agg_l2_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    if kind == 'agg_l2_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    raise ValueError(f'unknown kind: {kind}')

for permutation in permutations:
    base = torch.tensor(permutation, device=DEVICE).long()
    counts = torch.zeros((N, N), device=DEVICE)
    for start in range(0, B, B_CHUNK):
        S = min(B_CHUNK, B - start)
        perm_rep = base.unsqueeze(0).expand(S, -1).contiguous()
        psis = sample_psi_rejection_fallback(model, perm_rep)
        counts += F.one_hot(psis.long(), N).float().sum(dim=0)
    mm     = counts / B
    log_mm = torch.log(mm.clamp_min(EPS))

    truth_tup = tuple(permutation)
    print(f'truth = {truth_tup}')
    iter_in_top1 = iter_in_topN = False

    for name, (opts_dict, tau_dict, kind) in METHODS.items():
        C = build_cost(kind, opts_dict, tau_dict, mm, log_mm)
        full   = top_k_assignments(C, k=None)
        top_N  = full[:N]
        rank   = next(i + 1 for i, (p, _) in enumerate(full) if tuple(p.tolist()) == truth_tup)
        in_top = rank <= N
        ranks[name].append(rank)
        if rank == 1:
            top1[name] += 1
            iter_in_top1 = True
        if in_top:
            topN[name] += 1
            iter_in_topN = True
        print(f'  {name:<22}  best={full[0][0].tolist()} (cost {full[0][1]:.4f})  '
              f'rank={rank}/{len(permutations)}  in-top-{N}={in_top}')
    if iter_in_top1: union_top1 += 1
    if iter_in_topN: union_topN += 1
    print()
# Out:
# truth = (0, 1, 2, 3, 4, 5, 6)
#   max-min raw             best=[1, 5, 4, 2, 6, 3, 0] (cost 0.8969)  rank=2836/5040  in-top-7=False
#   max     raw             best=[1, 5, 0, 2, 4, 3, 6] (cost 1.4401)  rank=805/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 4, 1, 0, 3] (cost 41.0871)  rank=2316/5040  in-top-7=False
#   max     log             best=[4, 3, 2, 1, 0, 5, 6] (cost 40.4672)  rank=45/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 468.7314)  rank=81/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 2995.3579)  rank=144/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 1, 4, 3, 5, 2, 6] (cost 123.1443)  rank=131/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 468.7314)  rank=81/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 5, 0, 4, 6, 1, 2] (cost 60.2695)  rank=2539/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 1, 0, 4, 5, 3, 2] (cost 5.6645)  rank=841/5040  in-top-7=False
#
# truth = (0, 1, 2, 3, 4, 6, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 0.5681)  rank=1134/5040  in-top-7=False
#   max     raw             best=[0, 1, 6, 5, 3, 4, 2] (cost 0.5924)  rank=3122/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 3, 5, 0, 4] (cost 54.4332)  rank=841/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 49.7631)  rank=349/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 453.8473)  rank=195/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3018.0039)  rank=261/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 1, 5, 3, 6, 0, 4] (cost 102.8951)  rank=807/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 453.8473)  rank=195/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 4, 3, 6, 1, 5, 0] (cost 37.3219)  rank=3464/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 4, 6, 1, 5, 3, 0] (cost 2.8859)  rank=3267/5040  in-top-7=False
#
# truth = (0, 1, 2, 3, 5, 4, 6)
#   max-min raw             best=[6, 0, 4, 1, 3, 2, 5] (cost 0.8649)  rank=1068/5040  in-top-7=False
#   max     raw             best=[5, 0, 3, 1, 4, 2, 6] (cost 0.7550)  rank=2402/5040  in-top-7=False
#   max-min log             best=[2, 6, 3, 4, 1, 5, 0] (cost 59.0412)  rank=868/5040  in-top-7=False
#   max     log             best=[4, 2, 0, 1, 3, 5, 6] (cost 49.8773)  rank=1541/5040  in-top-7=False
#   aggregate L2  log       best=[4, 0, 2, 3, 5, 1, 6] (cost 484.6716)  rank=28/5040  in-top-7=False
#   aggregate L1  log       best=[6, 0, 2, 3, 5, 1, 4] (cost 3193.9822)  rank=97/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 0, 2, 1, 5, 4, 6] (cost 117.9395)  rank=373/5040  in-top-7=False
#   aggregate L2  raw       best=[4, 0, 2, 3, 5, 1, 6] (cost 484.6716)  rank=28/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 0, 2, 1, 3, 5, 6] (cost 55.7383)  rank=99/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 0, 2, 4, 5, 1, 6] (cost 5.0788)  rank=258/5040  in-top-7=False
#
# truth = (0, 1, 2, 3, 5, 6, 4)
#   max-min raw             best=[6, 5, 4, 2, 3, 0, 1] (cost 1.0549)  rank=1152/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.4811)  rank=573/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 51.5062)  rank=300/5040  in-top-7=False
#   max     log             best=[1, 3, 2, 5, 0, 6, 4] (cost 56.3588)  rank=68/5040  in-top-7=False
#   aggregate L2  log       best=[0, 6, 2, 3, 1, 5, 4] (cost 438.7809)  rank=16/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 2810.4702)  rank=43/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 5, 4, 0, 1, 6, 3] (cost 109.6108)  rank=355/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 6, 2, 3, 1, 5, 4] (cost 438.7809)  rank=16/5040  in-top-7=False
#   aggregate L1  raw       best=[0, 2, 6, 3, 1, 5, 4] (cost 65.3406)  rank=521/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 2, 6, 4, 5, 3, 0] (cost 5.6259)  rank=296/5040  in-top-7=False
#
# truth = (0, 1, 2, 3, 6, 4, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 1.0823)  rank=639/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 4, 6, 1, 2] (cost 0.8735)  rank=1971/5040  in-top-7=False
#   max-min log             best=[2, 3, 1, 5, 4, 0, 6] (cost 65.7893)  rank=4648/5040  in-top-7=False
#   max     log             best=[6, 0, 4, 2, 1, 5, 3] (cost 66.6596)  rank=4401/5040  in-top-7=False
#   aggregate L2  log       best=[1, 0, 3, 6, 2, 4, 5] (cost 602.3483)  rank=799/5040  in-top-7=False
#   aggregate L1  log       best=[1, 0, 3, 6, 2, 4, 5] (cost 3991.3799)  rank=659/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 0, 3, 6, 2, 4, 5] (cost 127.6451)  rank=1058/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 0, 3, 6, 2, 4, 5] (cost 602.3483)  rank=799/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 63.6377)  rank=736/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 3, 0, 6, 2, 4, 5] (cost 5.6600)  rank=1893/5040  in-top-7=False
#
# truth = (0, 1, 2, 3, 6, 5, 4)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6777)  rank=378/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 0.9843)  rank=385/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 3, 5, 0, 4] (cost 63.2403)  rank=475/5040  in-top-7=False
#   max     log             best=[3, 0, 6, 1, 2, 5, 4] (cost 63.8330)  rank=1165/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 530.3988)  rank=17/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 3391.8269)  rank=19/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 5, 3, 1, 6, 0, 4] (cost 128.1951)  rank=1604/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 2, 3, 6, 0, 4] (cost 530.3988)  rank=17/5040  in-top-7=False
#   aggregate L1  raw       best=[0, 3, 4, 1, 6, 2, 5] (cost 64.5512)  rank=22/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 5.7583)  rank=166/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 3, 5, 6)
#   max-min raw             best=[6, 0, 5, 2, 4, 1, 3] (cost 1.4049)  rank=1491/5040  in-top-7=False
#   max     raw             best=[6, 0, 5, 2, 4, 3, 1] (cost 1.1397)  rank=1321/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 4, 3, 5, 0] (cost 57.6876)  rank=85/5040  in-top-7=False
#   max     log             best=[4, 2, 0, 1, 3, 5, 6] (cost 45.3555)  rank=1070/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 2, 4, 3, 0, 6] (cost 474.2054)  rank=35/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 2, 4, 3, 0, 6] (cost 3090.9709)  rank=51/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 4, 0, 3, 5, 1, 2] (cost 124.6996)  rank=525/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 2, 4, 3, 0, 6] (cost 474.2054)  rank=35/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 0, 1, 2, 3, 5, 6] (cost 59.8958)  rank=40/5040  in-top-7=False
#   aggregate L∞  raw       best=[5, 4, 0, 2, 1, 3, 6] (cost 5.5369)  rank=45/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 3, 6, 5)
#   max-min raw             best=[1, 5, 6, 2, 4, 0, 3] (cost 0.5179)  rank=4114/5040  in-top-7=False
#   max     raw             best=[1, 5, 3, 4, 2, 0, 6] (cost 0.3636)  rank=1574/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 54.7907)  rank=1745/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 56.3671)  rank=584/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 496.4180)  rank=277/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3244.1033)  rank=314/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 2, 4, 6, 3, 1, 5] (cost 124.8766)  rank=1107/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 496.4180)  rank=277/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 2, 4, 0, 5, 6, 3] (cost 38.0772)  rank=2369/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 2, 3, 4, 6, 0, 5] (cost 2.3185)  rank=669/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 5, 3, 6)
#   max-min raw             best=[1, 6, 2, 5, 3, 4, 0] (cost 0.3941)  rank=3617/5040  in-top-7=False
#   max     raw             best=[2, 4, 5, 1, 0, 3, 6] (cost 0.5013)  rank=2658/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 4, 1, 0, 3] (cost 48.6767)  rank=383/5040  in-top-7=False
#   max     log             best=[4, 3, 2, 1, 0, 5, 6] (cost 48.5582)  rank=409/5040  in-top-7=False
#   aggregate L2  log       best=[5, 4, 2, 3, 1, 0, 6] (cost 472.6462)  rank=133/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3131.7297)  rank=321/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 4, 5, 0, 1, 2, 3] (cost 112.1939)  rank=256/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 4, 2, 3, 1, 0, 6] (cost 472.6462)  rank=133/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 0, 2, 1, 5, 3, 6] (cost 34.4186)  rank=13/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 1, 6, 4, 5, 2, 0] (cost 2.0088)  rank=30/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 5, 6, 3)
#   max-min raw             best=[0, 5, 4, 1, 2, 6, 3] (cost 0.7167)  rank=82/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 2, 4, 5] (cost 0.3530)  rank=1215/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 48.1805)  rank=2236/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 51.4542)  rank=943/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 471.7108)  rank=438/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3064.9788)  rank=545/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 0, 6, 4, 2, 5, 1] (cost 120.2962)  rank=3567/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 471.7108)  rank=438/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 4, 5, 6, 0, 1, 3] (cost 50.5857)  rank=389/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 4, 5, 6, 3, 2, 0] (cost 4.2648)  rank=1203/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 6, 3, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 0.9509)  rank=529/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 6, 2] (cost 0.7279)  rank=1437/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 51.1686)  rank=1759/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 48.3432)  rank=780/5040  in-top-7=False
#   aggregate L2  log       best=[2, 6, 5, 3, 1, 0, 4] (cost 522.4906)  rank=128/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3301.9951)  rank=317/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 0, 4, 2, 6, 5] (cost 125.6845)  rank=1579/5040  in-top-7=False
#   aggregate L2  raw       best=[2, 6, 5, 3, 1, 0, 4] (cost 522.4906)  rank=128/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 1, 3, 5, 0, 6, 2] (cost 66.5057)  rank=1075/5040  in-top-7=False
#   aggregate L∞  raw       best=[5, 2, 6, 4, 1, 3, 0] (cost 5.4172)  rank=413/5040  in-top-7=False
#
# truth = (0, 1, 2, 4, 6, 5, 3)
#   max-min raw             best=[0, 5, 3, 6, 2, 4, 1] (cost 1.3648)  rank=1994/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 1.2275)  rank=158/5040  in-top-7=False
#   max-min log             best=[4, 3, 0, 2, 1, 5, 6] (cost 80.1235)  rank=2095/5040  in-top-7=False
#   max     log             best=[3, 0, 5, 4, 1, 2, 6] (cost 63.0105)  rank=4512/5040  in-top-7=False
#   aggregate L2  log       best=[1, 2, 3, 5, 6, 4, 0] (cost 672.7842)  rank=4132/5040  in-top-7=False
#   aggregate L1  log       best=[1, 2, 3, 5, 6, 4, 0] (cost 4509.1860)  rank=4180/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 2, 0, 6, 1, 4, 5] (cost 133.2257)  rank=2219/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 2, 3, 5, 6, 4, 0] (cost 672.7842)  rank=4132/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 6, 0, 4, 1, 5, 2] (cost 82.0273)  rank=1016/5040  in-top-7=False
#   aggregate L∞  raw       best=[0, 6, 3, 4, 1, 5, 2] (cost 6.2219)  rank=297/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 3, 4, 6)
#   max-min raw             best=[6, 0, 5, 3, 2, 4, 1] (cost 1.3627)  rank=2714/5040  in-top-7=False
#   max     raw             best=[5, 0, 3, 1, 4, 2, 6] (cost 1.8398)  rank=2219/5040  in-top-7=False
#   max-min log             best=[0, 6, 1, 4, 2, 5, 3] (cost 71.9514)  rank=36/5040  in-top-7=False
#   max     log             best=[1, 0, 4, 5, 3, 2, 6] (cost 56.7579)  rank=2077/5040  in-top-7=False
#   aggregate L2  log       best=[3, 2, 0, 1, 5, 4, 6] (cost 678.6893)  rank=1069/5040  in-top-7=False
#   aggregate L1  log       best=[3, 2, 0, 1, 5, 4, 6] (cost 4565.1958)  rank=591/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 3, 0, 2, 1, 4, 5] (cost 135.4425)  rank=1911/5040  in-top-7=False
#   aggregate L2  raw       best=[3, 2, 0, 1, 5, 4, 6] (cost 678.6893)  rank=1069/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 0, 2, 1, 4, 5, 6] (cost 80.4083)  rank=356/5040  in-top-7=False
#   aggregate L∞  raw       best=[5, 0, 2, 1, 4, 3, 6] (cost 6.0533)  rank=264/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 3, 6, 4)
#   max-min raw             best=[0, 5, 4, 3, 2, 1, 6] (cost 0.7187)  rank=2175/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 1.0879)  rank=432/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 0, 3, 5, 4] (cost 54.7066)  rank=641/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 5, 1, 0, 4] (cost 56.3120)  rank=129/5040  in-top-7=False
#   aggregate L2  log       best=[4, 0, 2, 1, 3, 6, 5] (cost 541.0385)  rank=397/5040  in-top-7=False
#   aggregate L1  log       best=[4, 0, 2, 1, 3, 6, 5] (cost 3526.6462)  rank=169/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 3, 0, 1, 6, 4, 5] (cost 132.0645)  rank=2108/5040  in-top-7=False
#   aggregate L2  raw       best=[4, 0, 2, 1, 3, 6, 5] (cost 541.0385)  rank=397/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 0, 2, 1, 3, 6, 5] (cost 64.5323)  rank=426/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 0, 2, 5, 4, 1, 6] (cost 5.7392)  rank=699/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 4, 3, 6)
#   max-min raw             best=[0, 5, 4, 3, 2, 1, 6] (cost 0.9824)  rank=543/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 1.1289)  rank=18/5040  in-top-7=False
#   max-min log             best=[0, 6, 1, 4, 2, 5, 3] (cost 69.3786)  rank=39/5040  in-top-7=False
#   max     log             best=[4, 3, 0, 1, 5, 2, 6] (cost 54.3685)  rank=1340/5040  in-top-7=False
#   aggregate L2  log       best=[4, 0, 2, 1, 5, 3, 6] (cost 568.4553)  rank=413/5040  in-top-7=False
#   aggregate L1  log       best=[4, 0, 2, 1, 5, 3, 6] (cost 3722.7522)  rank=278/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 3, 1, 2, 5, 4, 6] (cost 130.7066)  rank=532/5040  in-top-7=False
#   aggregate L2  raw       best=[4, 0, 2, 1, 5, 3, 6] (cost 568.4553)  rank=413/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 3, 2, 1, 5, 0, 6] (cost 68.2630)  rank=178/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 0, 2, 5, 4, 1, 6] (cost 5.7978)  rank=122/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 4, 6, 3)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 1.1774)  rank=2534/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 6, 2] (cost 1.0658)  rank=42/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 5, 4, 0, 3] (cost 44.8188)  rank=678/5040  in-top-7=False
#   max     log             best=[4, 2, 0, 1, 3, 5, 6] (cost 50.9847)  rank=1593/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 0, 1, 4] (cost 502.5081)  rank=75/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 0, 1, 4] (cost 3255.9199)  rank=150/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 4, 0, 5, 6, 2, 1] (cost 117.8594)  rank=397/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 0, 1, 4] (cost 502.5081)  rank=75/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 1, 2, 5, 4, 0, 6] (cost 55.6142)  rank=221/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 4, 2, 1, 5, 6, 0] (cost 4.7711)  rank=123/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 6, 3, 4)
#   max-min raw             best=[0, 5, 4, 3, 2, 1, 6] (cost 1.4512)  rank=542/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 1.1914)  rank=237/5040  in-top-7=False
#   max-min log             best=[0, 3, 1, 4, 2, 5, 6] (cost 77.8339)  rank=2612/5040  in-top-7=False
#   max     log             best=[0, 3, 4, 5, 1, 2, 6] (cost 68.5518)  rank=4047/5040  in-top-7=False
#   aggregate L2  log       best=[1, 2, 3, 5, 6, 4, 0] (cost 717.5541)  rank=4133/5040  in-top-7=False
#   aggregate L1  log       best=[1, 4, 3, 5, 2, 6, 0] (cost 4904.1309)  rank=4015/5040  in-top-7=False
#   aggregate L∞  log       best=[4, 5, 0, 6, 1, 3, 2] (cost 136.9108)  rank=3643/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 2, 3, 5, 6, 4, 0] (cost 717.5541)  rank=4133/5040  in-top-7=False
#   aggregate L1  raw       best=[4, 2, 3, 1, 0, 6, 5] (cost 82.1959)  rank=1489/5040  in-top-7=False
#   aggregate L∞  raw       best=[4, 1, 0, 5, 2, 6, 3] (cost 6.1738)  rank=567/5040  in-top-7=False
#
# truth = (0, 1, 2, 5, 6, 4, 3)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6269)  rank=1532/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5026)  rank=3159/5040  in-top-7=False
#   max-min log             best=[2, 3, 1, 5, 4, 0, 6] (cost 59.3640)  rank=1282/5040  in-top-7=False
#   max     log             best=[4, 3, 2, 1, 0, 5, 6] (cost 40.9956)  rank=593/5040  in-top-7=False
#   aggregate L2  log       best=[6, 3, 1, 5, 2, 0, 4] (cost 510.9127)  rank=62/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3315.0781)  rank=292/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 5, 2, 6, 4, 0] (cost 122.6085)  rank=318/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 3, 1, 5, 2, 0, 4] (cost 510.9127)  rank=62/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 2, 0, 6, 3, 4] (cost 57.4914)  rank=351/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 0, 6, 5, 4, 3, 2] (cost 5.2278)  rank=2677/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 3, 4, 5)
#   max-min raw             best=[0, 1, 5, 3, 6, 2, 4] (cost 0.4004)  rank=2510/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 2, 5, 4, 6] (cost 1.0647)  rank=21/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 59.3008)  rank=4299/5040  in-top-7=False
#   max     log             best=[1, 3, 2, 6, 0, 5, 4] (cost 54.3194)  rank=341/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 485.3633)  rank=1876/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3153.5601)  rank=2145/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 5, 4, 3, 6, 0, 1] (cost 118.1257)  rank=1444/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 485.3633)  rank=1876/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 5, 3, 0, 6, 4, 1] (cost 52.4660)  rank=418/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 0, 4, 6, 3, 5, 1] (cost 4.2704)  rank=1404/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 3, 5, 4)
#   max-min raw             best=[0, 5, 6, 3, 2, 4, 1] (cost 0.9470)  rank=2940/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5202)  rank=750/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 46.6912)  rank=706/5040  in-top-7=False
#   max     log             best=[3, 2, 0, 1, 6, 5, 4] (cost 48.9168)  rank=399/5040  in-top-7=False
#   aggregate L2  log       best=[6, 1, 2, 3, 5, 0, 4] (cost 449.5127)  rank=187/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 2887.4722)  rank=200/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 3, 5, 0, 6, 1, 4] (cost 114.2944)  rank=1197/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 1, 2, 3, 5, 0, 4] (cost 449.5127)  rank=187/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 0, 2, 6, 5, 3, 4] (cost 64.7908)  rank=377/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 3, 6, 5, 4, 2, 0] (cost 5.4704)  rank=1488/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 4, 3, 5)
#   max-min raw             best=[0, 1, 5, 2, 6, 4, 3] (cost 1.1441)  rank=2309/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5007)  rank=42/5040  in-top-7=False
#   max-min log             best=[3, 6, 1, 0, 2, 5, 4] (cost 74.9073)  rank=628/5040  in-top-7=False
#   max     log             best=[1, 3, 6, 5, 0, 2, 4] (cost 56.0882)  rank=1023/5040  in-top-7=False
#   aggregate L2  log       best=[0, 6, 1, 5, 2, 3, 4] (cost 559.5847)  rank=38/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 1, 0, 3, 4] (cost 3563.9175)  rank=92/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 3, 1, 2, 5, 4, 0] (cost 133.0605)  rank=412/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 6, 1, 5, 2, 3, 4] (cost 559.5847)  rank=38/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 2, 5, 4, 6, 3, 0] (cost 71.1410)  rank=1319/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 0, 4, 3, 1, 6, 5] (cost 6.0007)  rank=1856/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 4, 5, 3)
#   max-min raw             best=[0, 5, 4, 3, 2, 1, 6] (cost 0.3691)  rank=3717/5040  in-top-7=False
#   max     raw             best=[0, 5, 2, 1, 3, 4, 6] (cost 1.1134)  rank=3355/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 4, 1, 0, 3] (cost 49.7172)  rank=2785/5040  in-top-7=False
#   max     log             best=[4, 3, 2, 1, 0, 5, 6] (cost 47.7315)  rank=484/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 461.9474)  rank=231/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3032.1311)  rank=352/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 1, 5, 4, 2, 0, 3] (cost 112.3765)  rank=376/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 461.9474)  rank=231/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 1, 6, 5, 0, 4, 3] (cost 42.8253)  rank=2204/5040  in-top-7=False
#   aggregate L∞  raw       best=[0, 4, 6, 1, 2, 3, 5] (cost 3.2531)  rank=1903/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 5, 3, 4)
#   max-min raw             best=[0, 5, 6, 3, 2, 4, 1] (cost 0.9001)  rank=1894/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5358)  rank=586/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 3, 5, 0, 4] (cost 61.3872)  rank=318/5040  in-top-7=False
#   max     log             best=[3, 0, 2, 1, 6, 5, 4] (cost 52.9856)  rank=702/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 464.9197)  rank=163/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 2999.0652)  rank=251/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 2, 4, 3, 1, 6, 5] (cost 122.2028)  rank=366/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 464.9197)  rank=163/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 2, 6, 0, 4] (cost 59.2931)  rank=518/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 5.6762)  rank=613/5040  in-top-7=False
#
# truth = (0, 1, 2, 6, 5, 4, 3)
#   max-min raw             best=[0, 1, 5, 3, 2, 4, 6] (cost 0.3789)  rank=2633/5040  in-top-7=False
#   max     raw             best=[6, 1, 3, 5, 2, 0, 4] (cost 1.2605)  rank=67/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 5, 4, 0, 3] (cost 51.0779)  rank=1701/5040  in-top-7=False
#   max     log             best=[4, 3, 2, 1, 0, 5, 6] (cost 46.9599)  rank=1269/5040  in-top-7=False
#   aggregate L2  log       best=[2, 6, 5, 4, 0, 1, 3] (cost 510.4431)  rank=689/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3288.4033)  rank=1725/5040  in-top-7=False
#   aggregate L∞  log       best=[4, 2, 3, 6, 0, 1, 5] (cost 119.7138)  rank=485/5040  in-top-7=False
#   aggregate L2  raw       best=[2, 6, 5, 4, 0, 1, 3] (cost 510.4431)  rank=689/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 0, 1, 6, 5, 4, 3] (cost 61.8891)  rank=52/5040  in-top-7=False
#   aggregate L∞  raw       best=[0, 4, 1, 3, 5, 6, 2] (cost 5.0839)  rank=43/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 4, 5, 6)
#   max-min raw             best=[0, 2, 5, 3, 4, 6, 1] (cost 0.4729)  rank=432/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 2, 4, 6, 5] (cost 0.3928)  rank=6/5040  in-top-7=True
#   max-min log             best=[2, 6, 5, 4, 1, 0, 3] (cost 53.5592)  rank=3100/5040  in-top-7=False
#   max     log             best=[1, 2, 0, 3, 4, 5, 6] (cost 51.6498)  rank=804/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 488.9876)  rank=2201/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3176.7246)  rank=2348/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 2, 6, 4, 0, 5, 1] (cost 123.1003)  rank=4207/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 488.9876)  rank=2201/5040  in-top-7=False
#   aggregate L1  raw       best=[0, 2, 6, 5, 3, 1, 4] (cost 48.5573)  rank=1530/5040  in-top-7=False
#   aggregate L∞  raw       best=[0, 6, 1, 5, 4, 2, 3] (cost 4.4123)  rank=3598/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 4, 6, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 1.0791)  rank=832/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 0.9371)  rank=24/5040  in-top-7=False
#   max-min log             best=[4, 6, 1, 5, 2, 0, 3] (cost 58.1990)  rank=1681/5040  in-top-7=False
#   max     log             best=[1, 3, 6, 5, 4, 2, 0] (cost 53.7030)  rank=2743/5040  in-top-7=False
#   aggregate L2  log       best=[1, 6, 3, 5, 0, 4, 2] (cost 506.7207)  rank=1123/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 3, 1, 2, 0, 4] (cost 3273.7583)  rank=1835/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 5, 6, 2, 4, 0] (cost 117.7810)  rank=645/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 6, 3, 5, 0, 4, 2] (cost 506.7207)  rank=1123/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 6, 4, 0, 2] (cost 65.9394)  rank=885/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 4.9886)  rank=3148/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 5, 4, 6)
#   max-min raw             best=[0, 5, 4, 3, 2, 6, 1] (cost 0.4722)  rank=338/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 2, 5, 4, 6] (cost 1.8440)  rank=1/5040  in-top-7=True
#   max-min log             best=[2, 3, 1, 4, 0, 5, 6] (cost 69.1427)  rank=1435/5040  in-top-7=False
#   max     log             best=[1, 2, 0, 3, 4, 5, 6] (cost 52.8628)  rank=1684/5040  in-top-7=False
#   aggregate L2  log       best=[3, 2, 1, 6, 5, 4, 0] (cost 588.4744)  rank=16/5040  in-top-7=False
#   aggregate L1  log       best=[2, 4, 3, 5, 0, 1, 6] (cost 3857.9150)  rank=43/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 2, 5, 6, 3, 4, 0] (cost 127.8196)  rank=1074/5040  in-top-7=False
#   aggregate L2  raw       best=[3, 2, 1, 6, 5, 4, 0] (cost 588.4744)  rank=16/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 4, 5, 2, 3, 1, 0] (cost 73.1939)  rank=44/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 4, 5, 3, 2, 1, 0] (cost 5.7408)  rank=197/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 5, 6, 4)
#   max-min raw             best=[0, 5, 6, 3, 2, 4, 1] (cost 0.6814)  rank=585/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 2, 4, 6] (cost 0.3092)  rank=1197/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 3, 5, 0, 4] (cost 55.1354)  rank=1176/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 62.8452)  rank=753/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 456.4604)  rank=675/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 2951.1187)  rank=1091/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 3, 5, 0, 1, 6, 4] (cost 112.5651)  rank=527/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 456.4604)  rank=675/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 2, 3, 1, 5, 4, 0] (cost 45.3813)  rank=213/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 2, 3, 1, 0, 4, 5] (cost 2.9828)  rank=3831/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 6, 4, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 2.0856)  rank=1471/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 1.2411)  rank=1248/5040  in-top-7=False
#   max-min log             best=[1, 3, 4, 5, 2, 0, 6] (cost 72.1641)  rank=2379/5040  in-top-7=False
#   max     log             best=[6, 0, 5, 4, 1, 2, 3] (cost 71.2942)  rank=2372/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 706.5986)  rank=238/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 4825.7749)  rank=293/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 3, 5, 6, 1, 4, 2] (cost 136.6178)  rank=135/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 706.5986)  rank=238/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 6, 4, 0, 2] (cost 81.4169)  rank=992/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 3, 0, 6, 4, 2, 5] (cost 6.1982)  rank=243/5040  in-top-7=False
#
# truth = (0, 1, 3, 2, 6, 5, 4)
#   max-min raw             best=[0, 2, 6, 3, 4, 1, 5] (cost 0.2568)  rank=687/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 2, 4, 6] (cost 1.2696)  rank=1861/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 3, 5, 0, 4] (cost 54.9147)  rank=1816/5040  in-top-7=False
#   max     log             best=[1, 2, 0, 5, 3, 6, 4] (cost 58.2273)  rank=417/5040  in-top-7=False
#   aggregate L2  log       best=[2, 1, 6, 3, 5, 0, 4] (cost 501.4452)  rank=136/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3285.2407)  rank=326/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 2, 3, 1, 6, 4, 5] (cost 121.2499)  rank=1159/5040  in-top-7=False
#   aggregate L2  raw       best=[2, 1, 6, 3, 5, 0, 4] (cost 501.4452)  rank=136/5040  in-top-7=False
#   aggregate L1  raw       best=[0, 6, 3, 2, 5, 4, 1] (cost 49.1908)  rank=847/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 5, 4, 6, 3, 0, 1] (cost 3.5942)  rank=2477/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 2, 5, 6)
#   max-min raw             best=[0, 5, 3, 6, 2, 4, 1] (cost 0.8746)  rank=292/5040  in-top-7=False
#   max     raw             best=[0, 5, 6, 1, 3, 4, 2] (cost 1.0668)  rank=1694/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 5, 4, 0, 3] (cost 53.1474)  rank=1107/5040  in-top-7=False
#   max     log             best=[4, 2, 0, 1, 3, 5, 6] (cost 49.4167)  rank=783/5040  in-top-7=False
#   aggregate L2  log       best=[0, 1, 6, 3, 2, 5, 4] (cost 538.8197)  rank=182/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 6, 3, 2, 0, 4] (cost 3542.6128)  rank=382/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 1, 3, 6, 2, 4, 5] (cost 124.1728)  rank=1122/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 1, 6, 3, 2, 5, 4] (cost 538.8197)  rank=182/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 6, 3, 1, 2, 4, 0] (cost 47.9835)  rank=420/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 6, 1, 5, 2, 4, 0] (cost 3.6510)  rank=2991/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 2, 6, 5)
#   max-min raw             best=[0, 5, 3, 6, 2, 4, 1] (cost 0.5560)  rank=558/5040  in-top-7=False
#   max     raw             best=[6, 5, 3, 1, 2, 4, 0] (cost 1.7145)  rank=1342/5040  in-top-7=False
#   max-min log             best=[4, 6, 1, 5, 2, 0, 3] (cost 61.3293)  rank=750/5040  in-top-7=False
#   max     log             best=[4, 3, 1, 5, 0, 2, 6] (cost 54.3756)  rank=2748/5040  in-top-7=False
#   aggregate L2  log       best=[0, 6, 1, 5, 2, 4, 3] (cost 575.4491)  rank=592/5040  in-top-7=False
#   aggregate L1  log       best=[0, 6, 1, 5, 2, 4, 3] (cost 3777.7197)  rank=870/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 1, 3, 6, 2, 4, 5] (cost 125.7937)  rank=639/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 6, 1, 5, 2, 4, 3] (cost 575.4491)  rank=592/5040  in-top-7=False
#   aggregate L1  raw       best=[0, 5, 3, 6, 2, 4, 1] (cost 64.7756)  rank=437/5040  in-top-7=False
#   aggregate L∞  raw       best=[0, 1, 6, 3, 5, 4, 2] (cost 4.6985)  rank=845/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 5, 2, 6)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6015)  rank=302/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.4011)  rank=39/5040  in-top-7=False
#   max-min log             best=[1, 6, 5, 3, 2, 0, 4] (cost 68.6829)  rank=3672/5040  in-top-7=False
#   max     log             best=[5, 0, 1, 6, 3, 2, 4] (cost 67.3392)  rank=1504/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 4, 2, 3, 0, 6] (cost 518.1710)  rank=285/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 4, 2, 3, 0, 6] (cost 3360.0171)  rank=650/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 4, 0, 6, 2, 5] (cost 129.5040)  rank=2404/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 4, 2, 3, 0, 6] (cost 518.1710)  rank=285/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 3, 0, 6, 2, 4] (cost 67.3304)  rank=1709/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 5, 4, 0, 6, 2, 1] (cost 5.1786)  rank=907/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 5, 6, 2)
#   max-min raw             best=[0, 5, 6, 1, 2, 4, 3] (cost 0.8685)  rank=787/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.4460)  rank=1023/5040  in-top-7=False
#   max-min log             best=[5, 3, 2, 0, 6, 1, 4] (cost 75.5164)  rank=3723/5040  in-top-7=False
#   max     log             best=[5, 3, 6, 1, 0, 2, 4] (cost 62.8981)  rank=2988/5040  in-top-7=False
#   aggregate L2  log       best=[0, 6, 5, 1, 4, 2, 3] (cost 521.5397)  rank=645/5040  in-top-7=False
#   aggregate L1  log       best=[0, 6, 5, 3, 1, 2, 4] (cost 3368.9905)  rank=1059/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 5, 3, 2, 6, 4, 1] (cost 129.1514)  rank=2229/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 6, 5, 1, 4, 2, 3] (cost 521.5397)  rank=645/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 5, 3, 1, 0, 2, 4] (cost 64.9773)  rank=2227/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 2, 4, 5, 0, 3, 1] (cost 5.2733)  rank=4146/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 6, 2, 5)
#   max-min raw             best=[0, 5, 3, 6, 2, 4, 1] (cost 1.3082)  rank=245/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 1.1728)  rank=195/5040  in-top-7=False
#   max-min log             best=[5, 3, 6, 0, 2, 1, 4] (cost 73.1955)  rank=2375/5040  in-top-7=False
#   max     log             best=[1, 0, 5, 6, 3, 2, 4] (cost 57.0240)  rank=868/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 588.3677)  rank=223/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 0, 4] (cost 3905.1499)  rank=182/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 0, 3, 6, 2, 4, 5] (cost 127.4370)  rank=300/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 588.3677)  rank=223/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 69.2801)  rank=518/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 0, 3, 6, 4, 5, 2] (cost 5.6375)  rank=1653/5040  in-top-7=False
#
# truth = (0, 1, 3, 4, 6, 5, 2)
#   max-min raw             best=[5, 0, 3, 6, 2, 4, 1] (cost 1.3419)  rank=986/5040  in-top-7=False
#   max     raw             best=[5, 0, 3, 6, 4, 1, 2] (cost 1.4531)  rank=58/5040  in-top-7=False
#   max-min log             best=[2, 3, 5, 0, 6, 1, 4] (cost 67.1287)  rank=4783/5040  in-top-7=False
#   max     log             best=[3, 0, 1, 2, 6, 5, 4] (cost 62.2497)  rank=2868/5040  in-top-7=False
#   aggregate L2  log       best=[6, 1, 5, 3, 2, 0, 4] (cost 530.5398)  rank=375/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 6, 3, 2, 0, 4] (cost 3451.8687)  rank=945/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 5, 0, 6, 2, 4, 3] (cost 121.7927)  rank=1062/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 1, 5, 3, 2, 0, 4] (cost 530.5398)  rank=375/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 0, 3, 6, 2, 5, 4] (cost 59.8331)  rank=102/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 6, 4, 0, 2] (cost 5.2197)  rank=77/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 2, 4, 6)
#   max-min raw             best=[0, 2, 5, 3, 6, 4, 1] (cost 0.6232)  rank=138/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 2, 4, 6] (cost 0.4055)  rank=4/5040  in-top-7=True
#   max-min log             best=[2, 6, 1, 5, 4, 0, 3] (cost 47.6394)  rank=734/5040  in-top-7=False
#   max     log             best=[1, 2, 0, 3, 4, 5, 6] (cost 54.0401)  rank=662/5040  in-top-7=False
#   aggregate L2  log       best=[6, 1, 3, 5, 2, 0, 4] (cost 512.3406)  rank=10/5040  in-top-7=False
#   aggregate L1  log       best=[6, 1, 2, 5, 3, 0, 4] (cost 3275.6284)  rank=309/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 1, 0, 6, 2, 4, 5] (cost 125.7658)  rank=123/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 1, 3, 5, 2, 0, 4] (cost 512.3406)  rank=10/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 2, 1, 0, 3, 4, 6] (cost 61.9762)  rank=80/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 2, 6, 0, 5, 4, 1] (cost 5.2668)  rank=733/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 2, 6, 4)
#   max-min raw             best=[0, 5, 6, 3, 2, 4, 1] (cost 0.7048)  rank=574/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 2, 4, 6] (cost 0.5945)  rank=357/5040  in-top-7=False
#   max-min log             best=[5, 6, 2, 3, 1, 0, 4] (cost 62.7536)  rank=1410/5040  in-top-7=False
#   max     log             best=[5, 3, 6, 1, 0, 2, 4] (cost 60.9625)  rank=340/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 2, 0, 3, 6, 4] (cost 486.2333)  rank=739/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3143.8088)  rank=1078/5040  in-top-7=False
#   aggregate L∞  log       best=[4, 1, 5, 0, 2, 6, 3] (cost 117.4577)  rank=628/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 2, 0, 3, 6, 4] (cost 486.2333)  rank=739/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 1, 3, 5, 2, 4, 0] (cost 51.9015)  rank=13/5040  in-top-7=False
#   aggregate L∞  raw       best=[4, 1, 5, 3, 0, 6, 2] (cost 3.3016)  rank=289/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 4, 2, 6)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.7421)  rank=261/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5749)  rank=22/5040  in-top-7=False
#   max-min log             best=[1, 3, 6, 0, 2, 5, 4] (cost 88.8826)  rank=2995/5040  in-top-7=False
#   max     log             best=[6, 0, 5, 3, 1, 2, 4] (cost 75.2295)  rank=3114/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 709.4531)  rank=2060/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 4846.5825)  rank=1869/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 2, 5, 1, 6, 4, 0] (cost 136.4404)  rank=1708/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 709.4531)  rank=2060/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 3, 0, 6, 2, 4] (cost 80.8382)  rank=1665/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 6.0891)  rank=1547/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 4, 6, 2)
#   max-min raw             best=[0, 1, 5, 3, 2, 4, 6] (cost 0.6126)  rank=760/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 1.0527)  rank=185/5040  in-top-7=False
#   max-min log             best=[4, 6, 1, 5, 2, 0, 3] (cost 61.9437)  rank=378/5040  in-top-7=False
#   max     log             best=[4, 3, 6, 5, 1, 2, 0] (cost 67.0852)  rank=1023/5040  in-top-7=False
#   aggregate L2  log       best=[0, 3, 1, 5, 4, 6, 2] (cost 518.8757)  rank=16/5040  in-top-7=False
#   aggregate L1  log       best=[0, 6, 2, 5, 1, 3, 4] (cost 3409.9768)  rank=70/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 5, 2, 6, 4, 0] (cost 122.2246)  rank=364/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 3, 1, 5, 4, 6, 2] (cost 518.8757)  rank=16/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 3, 2, 1, 4, 6, 0] (cost 62.0820)  rank=57/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 2, 3, 5, 4, 6, 0] (cost 5.4002)  rank=117/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 6, 2, 4)
#   max-min raw             best=[0, 1, 5, 3, 2, 4, 6] (cost 0.6760)  rank=79/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 2, 4, 6] (cost 0.5574)  rank=856/5040  in-top-7=False
#   max-min log             best=[5, 3, 2, 0, 6, 1, 4] (cost 78.7767)  rank=865/5040  in-top-7=False
#   max     log             best=[5, 3, 6, 1, 0, 2, 4] (cost 61.1605)  rank=25/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 3, 0, 6, 2, 4] (cost 553.0167)  rank=20/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 3591.7180)  rank=61/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 3, 5, 1, 6, 4, 2] (cost 130.0108)  rank=149/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 3, 0, 6, 2, 4] (cost 553.0167)  rank=20/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 3, 0, 6, 2, 4] (cost 49.1141)  rank=22/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 2.8298)  rank=33/5040  in-top-7=False
#
# truth = (0, 1, 3, 5, 6, 4, 2)
#   max-min raw             best=[0, 5, 4, 3, 2, 1, 6] (cost 0.7246)  rank=1095/5040  in-top-7=False
#   max     raw             best=[0, 5, 6, 2, 3, 4, 1] (cost 1.6951)  rank=1790/5040  in-top-7=False
#   max-min log             best=[5, 6, 1, 3, 2, 0, 4] (cost 59.6708)  rank=3818/5040  in-top-7=False
#   max     log             best=[1, 3, 0, 5, 6, 2, 4] (cost 49.4110)  rank=1735/5040  in-top-7=False
#   aggregate L2  log       best=[0, 1, 3, 6, 5, 4, 2] (cost 574.8042)  rank=6/5040  in-top-7=True
#   aggregate L1  log       best=[5, 1, 3, 0, 2, 6, 4] (cost 3762.8972)  rank=111/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 5, 1, 6, 4, 2, 0] (cost 130.0672)  rank=218/5040  in-top-7=False
#   aggregate L2  raw       best=[0, 1, 3, 6, 5, 4, 2] (cost 574.8042)  rank=6/5040  in-top-7=True
#   aggregate L1  raw       best=[0, 4, 3, 2, 5, 1, 6] (cost 70.5256)  rank=50/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 4, 5, 3, 1, 6, 0] (cost 5.6617)  rank=1833/5040  in-top-7=False
#
# truth = (0, 1, 3, 6, 2, 4, 5)
#   max-min raw             best=[0, 5, 4, 6, 2, 3, 1] (cost 2.0270)  rank=314/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 1.2392)  rank=2635/5040  in-top-7=False
#   max-min log             best=[4, 3, 6, 5, 1, 0, 2] (cost 68.8272)  rank=3599/5040  in-top-7=False
#   max     log             best=[6, 0, 5, 4, 1, 2, 3] (cost 71.2942)  rank=2784/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 644.1996)  rank=138/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 4284.3833)  rank=223/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 4, 1, 6, 2, 5, 3] (cost 134.4602)  rank=165/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 644.1996)  rank=138/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 6, 4, 0, 2] (cost 79.7490)  rank=578/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 3, 0, 6, 2, 4, 5] (cost 6.0793)  rank=58/5040  in-top-7=False
#
# truth = (0, 1, 3, 6, 2, 5, 4)
#   max-min raw             best=[5, 0, 6, 2, 3, 4, 1] (cost 1.5290)  rank=3481/5040  in-top-7=False
#   max     raw             best=[5, 0, 3, 2, 4, 6, 1] (cost 0.6921)  rank=987/5040  in-top-7=False
#   max-min log             best=[2, 6, 1, 0, 3, 5, 4] (cost 66.4985)  rank=239/5040  in-top-7=False
#   max     log             best=[1, 2, 0, 5, 3, 6, 4] (cost 47.8552)  rank=273/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 6, 0, 3, 2, 4] (cost 546.1504)  rank=580/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 6, 0, 3, 2, 4] (cost 3508.6479)  rank=546/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 2, 4, 0, 1, 6, 5] (cost 129.1934)  rank=1754/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 6, 0, 3, 2, 4] (cost 546.1504)  rank=580/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 1, 6, 0, 4, 2, 5] (cost 71.8360)  rank=801/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 5.9327)  rank=358/5040  in-top-7=False
#
# truth = (0, 1, 3, 6, 4, 2, 5)
#   max-min raw             best=[5, 0, 3, 6, 2, 4, 1] (cost 1.8165)  rank=342/5040  in-top-7=False
#   max     raw             best=[5, 0, 3, 6, 4, 1, 2] (cost 1.6542)  rank=202/5040  in-top-7=False
#   max-min log             best=[1, 3, 4, 5, 2, 0, 6] (cost 70.9692)  rank=2163/5040  in-top-7=False
#   max     log             best=[1, 0, 5, 4, 3, 2, 6] (cost 60.1466)  rank=830/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 603.3613)  rank=167/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 4000.8081)  rank=100/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 1, 0, 2, 4, 5, 3] (cost 132.2152)  rank=245/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 603.3613)  rank=167/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 6, 3, 4, 0, 2] (cost 69.9962)  rank=373/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 6, 4, 0, 2] (cost 5.6940)  rank=751/5040  in-top-7=False
#
# truth = (0, 1, 3, 6, 4, 5, 2)
#   max-min raw             best=[0, 6, 5, 3, 2, 4, 1] (cost 0.5218)  rank=2266/5040  in-top-7=False
#   max     raw             best=[0, 3, 5, 2, 4, 6, 1] (cost 1.0954)  rank=1724/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 46.3219)  rank=4912/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 45.8078)  rank=1845/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 472.3896)  rank=2113/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3083.7974)  rank=2634/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 1, 4, 0, 5, 3, 2] (cost 123.6240)  rank=1555/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 472.3896)  rank=2113/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 0, 4, 5, 1, 3, 2] (cost 54.4004)  rank=2107/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 1, 0, 4, 5, 3, 2] (cost 5.0491)  rank=957/5040  in-top-7=False
#
# truth = (0, 1, 3, 6, 5, 2, 4)
#   max-min raw             best=[0, 5, 6, 3, 2, 4, 1] (cost 0.5331)  rank=1027/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5456)  rank=159/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 0, 3, 1, 4] (cost 63.8990)  rank=1124/5040  in-top-7=False
#   max     log             best=[3, 0, 6, 2, 1, 5, 4] (cost 64.4731)  rank=3140/5040  in-top-7=False
#   aggregate L2  log       best=[1, 3, 0, 6, 2, 4, 5] (cost 611.3862)  rank=453/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 0, 4] (cost 4043.7134)  rank=273/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 2, 3, 0, 6, 4, 5] (cost 130.2782)  rank=421/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 3, 0, 6, 2, 4, 5] (cost 611.3862)  rank=453/5040  in-top-7=False
# ...
#   aggregate L2  log       best=[3, 0, 5, 1, 4, 2, 6] (cost 581.2966)  rank=672/5040  in-top-7=False
#   aggregate L1  log       best=[3, 0, 5, 1, 4, 2, 6] (cost 3779.5518)  rank=401/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 5, 0, 1, 6, 4, 2] (cost 128.4775)  rank=1289/5040  in-top-7=False
#   aggregate L2  raw       best=[3, 0, 5, 1, 4, 2, 6] (cost 581.2966)  rank=672/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 0, 6, 4, 2, 3] (cost 63.6847)  rank=675/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 5, 0, 2, 1, 4, 6] (cost 4.1341)  rank=2677/5040  in-top-7=False
#
# truth = (6, 5, 4, 1, 2, 3, 0)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6835)  rank=128/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 6, 4, 2, 1] (cost 0.4858)  rank=3844/5040  in-top-7=False
#   max-min log             best=[5, 6, 2, 3, 1, 0, 4] (cost 49.5404)  rank=4503/5040  in-top-7=False
#   max     log             best=[1, 3, 6, 5, 0, 2, 4] (cost 55.7377)  rank=2623/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 6, 3, 4, 2, 0] (cost 532.4023)  rank=307/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 6, 0, 3, 2, 4] (cost 3442.7849)  rank=889/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 3, 5, 2, 6, 4, 0] (cost 124.9967)  rank=373/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 6, 3, 4, 2, 0] (cost 532.4023)  rank=307/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 3, 1, 5, 4, 2, 0] (cost 62.7348)  rank=243/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 2, 3, 5, 4, 6, 0] (cost 5.4329)  rank=1861/5040  in-top-7=False
#
# truth = (6, 5, 4, 1, 3, 0, 2)
#   max-min raw             best=[5, 2, 1, 3, 6, 4, 0] (cost 0.1671)  rank=1145/5040  in-top-7=False
#   max     raw             best=[6, 1, 3, 0, 4, 2, 5] (cost 0.1721)  rank=4883/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 48.3132)  rank=2599/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 42.5898)  rank=2476/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 505.8110)  rank=231/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3275.4399)  rank=416/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 1, 0, 4, 3, 2, 5] (cost 122.6094)  rank=2555/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 505.8110)  rank=231/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 0, 2, 4, 3, 5, 1] (cost 53.5832)  rank=981/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 4, 2, 1, 5, 0, 6] (cost 4.4627)  rank=824/5040  in-top-7=False
#
# truth = (6, 5, 4, 1, 3, 2, 0)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.7343)  rank=523/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5729)  rank=3497/5040  in-top-7=False
#   max-min log             best=[5, 6, 1, 3, 2, 0, 4] (cost 70.7635)  rank=4056/5040  in-top-7=False
#   max     log             best=[6, 0, 3, 5, 1, 2, 4] (cost 64.0004)  rank=669/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 672.6443)  rank=498/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 3, 6, 2, 4, 0] (cost 4486.2642)  rank=300/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 3, 5, 2, 1, 4, 0] (cost 136.3905)  rank=407/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 3, 6, 2, 4, 0] (cost 672.6443)  rank=498/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 2, 3, 6, 0, 4] (cost 82.4605)  rank=2140/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 5, 0, 3, 1, 6, 4] (cost 6.2357)  rank=2211/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 0, 1, 3)
#   max-min raw             best=[0, 5, 6, 2, 1, 4, 3] (cost 0.9652)  rank=1076/5040  in-top-7=False
#   max     raw             best=[0, 2, 5, 4, 3, 1, 6] (cost 0.8702)  rank=264/5040  in-top-7=False
#   max-min log             best=[2, 6, 3, 5, 4, 0, 1] (cost 49.2029)  rank=2262/5040  in-top-7=False
#   max     log             best=[4, 3, 1, 2, 0, 5, 6] (cost 45.7094)  rank=1958/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 1, 2, 4, 0, 3] (cost 517.3055)  rank=156/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3284.0957)  rank=600/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 4, 0, 1, 5, 3, 2] (cost 128.6853)  rank=456/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 1, 2, 4, 0, 3] (cost 517.3055)  rank=156/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 4, 2, 0, 5, 1, 3] (cost 59.0422)  rank=36/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 5, 2, 1, 4, 3, 0] (cost 4.4750)  rank=895/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 0, 3, 1)
#   max-min raw             best=[1, 5, 3, 6, 2, 4, 0] (cost 0.4854)  rank=2882/5040  in-top-7=False
#   max     raw             best=[1, 5, 6, 4, 3, 0, 2] (cost 0.2578)  rank=1989/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 54.7076)  rank=2788/5040  in-top-7=False
#   max     log             best=[3, 6, 2, 1, 0, 5, 4] (cost 49.9350)  rank=3539/5040  in-top-7=False
#   aggregate L2  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 461.3880)  rank=1485/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3065.4458)  rank=1873/5040  in-top-7=False
#   aggregate L∞  log       best=[2, 5, 4, 3, 6, 0, 1] (cost 113.8739)  rank=178/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 6, 2, 3, 1, 0, 4] (cost 461.3880)  rank=1485/5040  in-top-7=False
#   aggregate L1  raw       best=[2, 6, 0, 4, 5, 3, 1] (cost 34.6680)  rank=275/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 6, 4, 1, 5, 3, 0] (cost 2.0838)  rank=444/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 1, 0, 3)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6503)  rank=1078/5040  in-top-7=False
#   max     raw             best=[0, 5, 6, 2, 3, 4, 1] (cost 1.2602)  rank=455/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 47.6221)  rank=620/5040  in-top-7=False
#   max     log             best=[1, 3, 2, 6, 0, 5, 4] (cost 52.3545)  rank=3545/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 471.4448)  rank=69/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3048.9165)  rank=184/5040  in-top-7=False
#   aggregate L∞  log       best=[5, 4, 1, 2, 3, 0, 6] (cost 116.2079)  rank=86/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 471.4448)  rank=69/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 0, 1, 5, 2, 3, 4] (cost 58.4204)  rank=688/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 2, 0, 4, 1, 3, 5] (cost 4.1879)  rank=774/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 1, 3, 0)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.6562)  rank=270/5040  in-top-7=False
#   max     raw             best=[0, 1, 5, 2, 4, 3, 6] (cost 0.5338)  rank=1108/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 61.6229)  rank=2220/5040  in-top-7=False
#   max     log             best=[1, 3, 2, 5, 0, 6, 4] (cost 57.1439)  rank=4760/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 491.0698)  rank=1062/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3207.0168)  rank=1833/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 5, 4, 0, 3, 2, 1] (cost 121.4244)  rank=140/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 491.0698)  rank=1062/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 4, 3, 6, 0, 2] (cost 44.8888)  rank=1010/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 3.5844)  rank=1846/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 3, 0, 1)
#   max-min raw             best=[1, 0, 3, 6, 2, 4, 5] (cost 0.8494)  rank=4371/5040  in-top-7=False
#   max     raw             best=[1, 0, 6, 4, 5, 3, 2] (cost 0.6195)  rank=2696/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 60.7709)  rank=1233/5040  in-top-7=False
#   max     log             best=[3, 1, 2, 6, 0, 5, 4] (cost 53.8206)  rank=1747/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 499.4704)  rank=31/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3204.9958)  rank=132/5040  in-top-7=False
#   aggregate L∞  log       best=[4, 1, 5, 2, 6, 0, 3] (cost 121.8513)  rank=23/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 2, 3, 6, 0, 4] (cost 499.4704)  rank=31/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 6, 3, 4, 2, 0, 5] (cost 51.3557)  rank=85/5040  in-top-7=False
#   aggregate L∞  raw       best=[5, 1, 4, 0, 3, 2, 6] (cost 3.0474)  rank=262/5040  in-top-7=False
#
# truth = (6, 5, 4, 2, 3, 1, 0)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.7382)  rank=2600/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5729)  rank=2204/5040  in-top-7=False
#   max-min log             best=[5, 6, 3, 0, 1, 2, 4] (cost 78.9989)  rank=3093/5040  in-top-7=False
#   max     log             best=[5, 1, 0, 6, 3, 2, 4] (cost 49.9362)  rank=1643/5040  in-top-7=False
#   aggregate L2  log       best=[3, 5, 0, 4, 6, 1, 2] (cost 610.1994)  rank=159/5040  in-top-7=False
#   aggregate L1  log       best=[3, 1, 5, 4, 6, 0, 2] (cost 3961.0552)  rank=201/5040  in-top-7=False
#   aggregate L∞  log       best=[3, 5, 4, 1, 2, 6, 0] (cost 135.0500)  rank=1033/5040  in-top-7=False
#   aggregate L2  raw       best=[3, 5, 0, 4, 6, 1, 2] (cost 610.1994)  rank=159/5040  in-top-7=False
#   aggregate L1  raw       best=[5, 1, 2, 3, 6, 0, 4] (cost 74.8231)  rank=2762/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 5.9188)  rank=3198/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 0, 1, 2)
#   max-min raw             best=[0, 6, 5, 3, 2, 1, 4] (cost 0.7902)  rank=31/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 1, 4, 2, 6] (cost 0.8997)  rank=3503/5040  in-top-7=False
#   max-min log             best=[4, 6, 1, 5, 2, 0, 3] (cost 59.6608)  rank=3008/5040  in-top-7=False
#   max     log             best=[4, 3, 0, 1, 5, 2, 6] (cost 52.9989)  rank=1197/5040  in-top-7=False
#   aggregate L2  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 489.0038)  rank=1000/5040  in-top-7=False
#   aggregate L1  log       best=[5, 1, 2, 3, 6, 0, 4] (cost 3185.7148)  rank=1179/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 4, 5, 1, 6, 3, 2] (cost 125.9314)  rank=2479/5040  in-top-7=False
#   aggregate L2  raw       best=[5, 1, 2, 3, 6, 0, 4] (cost 489.0038)  rank=1000/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 4, 2, 5, 0, 1, 6] (cost 51.6936)  rank=1007/5040  in-top-7=False
#   aggregate L∞  raw       best=[3, 0, 2, 4, 5, 1, 6] (cost 5.2861)  rank=4633/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 0, 2, 1)
#   max-min raw             best=[1, 0, 3, 6, 2, 4, 5] (cost 1.2401)  rank=3319/5040  in-top-7=False
#   max     raw             best=[1, 0, 5, 3, 4, 6, 2] (cost 0.9272)  rank=3343/5040  in-top-7=False
#   max-min log             best=[5, 6, 2, 3, 1, 0, 4] (cost 65.1088)  rank=2691/5040  in-top-7=False
#   max     log             best=[1, 3, 6, 5, 0, 2, 4] (cost 52.1883)  rank=615/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 4, 3, 2, 0, 1] (cost 557.5612)  rank=28/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3624.1367)  rank=94/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 3, 5, 4, 6, 2, 1] (cost 129.5046)  rank=715/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 4, 3, 2, 0, 1] (cost 557.5612)  rank=28/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 3, 0, 4, 6, 2, 5] (cost 48.0318)  rank=1296/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 6, 0, 4, 2, 3, 5] (cost 2.5515)  rank=3239/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 1, 0, 2)
#   max-min raw             best=[0, 5, 3, 6, 2, 4, 1] (cost 0.9996)  rank=471/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 6, 4, 5, 2] (cost 0.8673)  rank=775/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 50.8193)  rank=1254/5040  in-top-7=False
#   max     log             best=[6, 2, 0, 3, 1, 5, 4] (cost 57.4713)  rank=639/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 480.3633)  rank=157/5040  in-top-7=False
#   aggregate L1  log       best=[5, 6, 2, 3, 1, 0, 4] (cost 3099.2905)  rank=333/5040  in-top-7=False
#   aggregate L∞  log       best=[1, 0, 3, 4, 6, 2, 5] (cost 120.3858)  rank=1236/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 480.3633)  rank=157/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 6, 0, 4, 1, 5, 2] (cost 63.0619)  rank=185/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 3, 5, 4, 1, 2, 0] (cost 4.8928)  rank=1036/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 1, 2, 0)
#   max-min raw             best=[0, 1, 5, 3, 6, 2, 4] (cost 0.7032)  rank=86/5040  in-top-7=False
#   max     raw             best=[0, 1, 3, 5, 4, 2, 6] (cost 0.5041)  rank=672/5040  in-top-7=False
#   max-min log             best=[5, 6, 2, 3, 1, 0, 4] (cost 65.0826)  rank=2041/5040  in-top-7=False
#   max     log             best=[1, 3, 6, 5, 0, 2, 4] (cost 59.8542)  rank=3146/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 2, 3, 6, 0, 4] (cost 538.4276)  rank=137/5040  in-top-7=False
#   aggregate L1  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 3478.8901)  rank=361/5040  in-top-7=False
#   aggregate L∞  log       best=[0, 6, 1, 2, 5, 4, 3] (cost 133.9397)  rank=1321/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 2, 3, 6, 0, 4] (cost 538.4276)  rank=137/5040  in-top-7=False
#   aggregate L1  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 53.7452)  rank=577/5040  in-top-7=False
#   aggregate L∞  raw       best=[1, 5, 3, 0, 6, 2, 4] (cost 4.6666)  rank=316/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 2, 0, 1)
#   max-min raw             best=[0, 5, 4, 3, 6, 2, 1] (cost 0.4902)  rank=3/5040  in-top-7=True
#   max     raw             best=[0, 1, 5, 2, 4, 3, 6] (cost 0.8790)  rank=1559/5040  in-top-7=False
#   max-min log             best=[2, 6, 5, 3, 1, 0, 4] (cost 51.9752)  rank=1627/5040  in-top-7=False
#   max     log             best=[1, 3, 2, 6, 0, 5, 4] (cost 50.4786)  rank=2984/5040  in-top-7=False
#   aggregate L2  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 493.3083)  rank=15/5040  in-top-7=False
#   aggregate L1  log       best=[6, 5, 2, 3, 1, 0, 4] (cost 3192.5625)  rank=65/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 1, 0, 4, 5, 3, 2] (cost 127.2050)  rank=873/5040  in-top-7=False
#   aggregate L2  raw       best=[6, 5, 2, 3, 1, 0, 4] (cost 493.3083)  rank=15/5040  in-top-7=False
#   aggregate L1  raw       best=[6, 4, 5, 3, 0, 1, 2] (cost 57.4203)  rank=948/5040  in-top-7=False
#   aggregate L∞  raw       best=[6, 4, 5, 3, 0, 1, 2] (cost 4.4706)  rank=1790/5040  in-top-7=False
#
# truth = (6, 5, 4, 3, 2, 1, 0)
#   max-min raw             best=[0, 1, 5, 2, 6, 4, 3] (cost 0.9741)  rank=1525/5040  in-top-7=False
#   max     raw             best=[0, 5, 3, 2, 4, 6, 1] (cost 0.5671)  rank=3053/5040  in-top-7=False
#   max-min log             best=[5, 6, 3, 0, 1, 2, 4] (cost 72.2872)  rank=3730/5040  in-top-7=False
#   max     log             best=[1, 3, 0, 6, 5, 2, 4] (cost 53.9539)  rank=2929/5040  in-top-7=False
#   aggregate L2  log       best=[1, 5, 0, 6, 3, 4, 2] (cost 649.0030)  rank=356/5040  in-top-7=False
#   aggregate L1  log       best=[1, 5, 4, 0, 3, 6, 2] (cost 4295.9819)  rank=253/5040  in-top-7=False
#   aggregate L∞  log       best=[6, 3, 5, 2, 1, 4, 0] (cost 136.7979)  rank=1000/5040  in-top-7=False
#   aggregate L2  raw       best=[1, 5, 0, 6, 3, 4, 2] (cost 649.0030)  rank=356/5040  in-top-7=False
#   aggregate L1  raw       best=[3, 5, 2, 0, 1, 6, 4] (cost 78.5296)  rank=1720/5040  in-top-7=False
#   aggregate L∞  raw       best=[2, 5, 3, 0, 1, 6, 4] (cost 6.2078)  rank=749/5040  in-top-7=False

# %%
T = len(permutations)
print('=' * 90)
print(f'Summary over all {T} permutations of S_{N}')
print(f'Random baselines: top-1 ~ {100/T:.1f}%, top-{N} ~ {100*N/T:.1f}%, mean rank ~ {(T+1)/2:.1f}')
print('-' * 90)
print(f'{"method":<24} {"top-1":>10} {"top-N":>10} {"mean rank":>14}')
for m in METHODS:
    print(f'{m:<24} {top1[m]}/{T:<6} {topN[m]}/{T:<6} {sum(ranks[m])/T:>12.2f}')
print('-' * 90)
print(f'{"union (any method)":<24} {union_top1}/{T:<6} {union_topN}/{T:<6}')
# Out:
# ==========================================================================================
# Summary over all 5040 permutations of S_7
# Random baselines: top-1 ~ 0.0%, top-7 ~ 0.1%, mean rank ~ 2520.5
# ------------------------------------------------------------------------------------------
# method                        top-1      top-N      mean rank
# max-min raw              1/5040   19/5040        2031.30
# max     raw              5/5040   22/5040        1931.99
# max-min log              3/5040   23/5040        1897.83
# max     log              7/5040   40/5040        1688.43
# aggregate L2  log        112/5040   509/5040         623.51
# aggregate L1  log        58/5040   289/5040         804.00
# aggregate L∞  log        11/5040   80/5040        1268.89
# aggregate L2  raw        112/5040   509/5040         623.51
# aggregate L1  raw        55/5040   318/5040         617.07
# aggregate L∞  raw        26/5040   128/5040        1070.60
# ------------------------------------------------------------------------------------------
# union (any method)       231/5040   963/5040
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
