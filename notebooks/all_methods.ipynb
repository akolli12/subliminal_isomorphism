# %% [markdown]
# # All 8 extraction algorithms
#
# Same τ and τ_log build as `raw_vs_log.ipynb`, plus four **aggregate** methods that use the entire (i, v) slice of τ instead of picking one witness coordinate.
#
# **Single-witness methods** (use one $(i_j, v_j)$ per $j$):
# 1. max-spread + raw cost
# 2. max-min spread + raw cost  (top1 − top2 margin)
# 3. max-spread + log cost
# 4. max-min spread + log cost
#
# **Aggregate methods** (use all $n^2$ cells in the (i, v) slice — no witness needed):
# 5. aggregate L2  + log cost   ←  paper's choice (Assumption `positional-leakage`)
# 6. aggregate L1  + log cost
# 7. aggregate L∞  + log cost
# 8. aggregate L2  + raw cost
#
# All eight methods report top-1 / top-N / mean rank, plus a union row.

# %%
import sys, random, itertools
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import linear_sum_assignment

import config
from model import TinyTransformer

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
N = config.N
EPS = 1e-12
print(f'N = {N}, device = {DEVICE}')
# Out:
# N = 4, device = cuda

# %%
CHECKPOINT = PROJECT_ROOT / 'checkpoints' / 'model_2500.pt'

def load_model(path):
    m = TinyTransformer().to(DEVICE)
    m.load_state_dict(torch.load(path, map_location=DEVICE))
    m.eval()
    return m

model = load_model(CHECKPOINT)
print(f'Loaded {CHECKPOINT.name}')
# Out:
# Loaded model_2500.pt
# /home/akash10/miniconda3/envs/aug-spm/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# /tmp/ipykernel_694441/2073868983.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   m.load_state_dict(torch.load(path, map_location=DEVICE))

# %%
@torch.no_grad()
def sample_psi_unconstrained(model, phis):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    psi_start = config.PSI.start
    psi_buf = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    seq = torch.cat([phis.to(DEVICE), psi_buf], dim=1)
    for j in range(N):
        logits = model(seq)
        step_logits = logits[:, psi_start - 1 + j, :]
        probs = F.softmax(step_logits, dim=-1)
        sampled = torch.multinomial(probs, num_samples=1).squeeze(-1)
        seq[:, psi_start + j] = sampled
    return seq[:, psi_start:psi_start + N]

def is_perm_rows(samples, n):
    sorted_, _ = torch.sort(samples, dim=1)
    expected = torch.arange(n, device=samples.device).unsqueeze(0).expand_as(sorted_)
    return (sorted_ == expected).all(dim=1)

@torch.no_grad()
def sample_psi_rejection(model, phis, max_attempts=50):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    phis = phis.to(DEVICE)
    out     = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    pending = torch.ones(B,        dtype=torch.bool, device=DEVICE)
    for _ in range(max_attempts):
        idx = torch.nonzero(pending, as_tuple=False).squeeze(1)
        if idx.numel() == 0:
            break
        psis_try = sample_psi_unconstrained(model, phis[idx])
        valid = is_perm_rows(psis_try, N)
        out[idx[valid]] = psis_try[valid]
        pending[idx[valid]] = False
    if pending.any():
        raise RuntimeError(
            f'{int(pending.sum().item())} rows still invalid after {max_attempts} attempts'
        )
    return out

def marginal_matrix(samples, n=N):
    return F.one_hot(samples.long(), n).float().mean(dim=0)

def random_phis_with_constraint(B, j, u, n=N, seed=None):
    g = torch.Generator()
    if seed is not None: g.manual_seed(seed)
    other_positions = torch.tensor([i for i in range(n) if i != j], dtype=torch.long)
    other_values    = torch.tensor([v for v in range(n) if v != u], dtype=torch.long)
    keys = torch.rand((B, n - 1), generator=g)
    perms = keys.argsort(dim=1)
    perm_values = other_values[perms]
    out = torch.zeros((B, n), dtype=torch.long)
    out[:, j] = u
    out[:, other_positions] = perm_values
    return out

# %%
def best_assignment(C):
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    row_ind, col_ind = linear_sum_assignment(C_np)
    return torch.tensor(col_ind, dtype=torch.long), float(C_np[row_ind, col_ind].sum())

def top_k_assignments(C, k=None):
    n = C.shape[0]
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    rows = np.arange(n)
    scored = [
        (C_np[rows, list(perm)].sum(), perm)
        for perm in itertools.permutations(range(n))
    ]
    scored.sort(key=lambda x: x[0])
    if k is not None:
        scored = scored[:k]
    return [(torch.tensor(p, dtype=torch.long), float(c)) for c, p in scored]

# %% [markdown]
# ## Build τ and τ_log
#
# K1 phis per (j, u); K2 psis per phi. Per-phi marginal computed first, then both raw average and log-then-average over the K1 phis.

# %%
tau     = {}
tau_log = {}

seed = 42
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

K1 = 2**6       # phis per (j, u)
K2 = 2**6         # psis per phi (large to keep log-bias small)
CHUNK = 2**14     # rows per model.forward call

for j in range(N):
    for u in range(N):
        phis = random_phis_with_constraint(K1, j=j, u=u)
        sum_p     = torch.zeros((N, N), device=DEVICE)
        sum_log_p = torch.zeros((N, N), device=DEVICE)

        if K2 <= CHUNK:
            phi_chunk = max(1, CHUNK // K2)
            psi_subchunk = K2
        else:
            phi_chunk = 1
            psi_subchunk = CHUNK

        for phi_start in range(0, K1, phi_chunk):
            P = min(phi_chunk, K1 - phi_start)
            this_phis = phis[phi_start:phi_start + P]
            counts = torch.zeros((P, N, N), device=DEVICE)
            for psi_start in range(0, K2, psi_subchunk):
                S = min(psi_subchunk, K2 - psi_start)
                phi_rep = this_phis.repeat_interleave(S, dim=0)
                psis    = sample_psi_rejection(model, phi_rep)
                psis    = psis.view(P, S, N)
                counts += F.one_hot(psis.long(), N).float().sum(dim=1)
            M_per_phi = counts / K2
            sum_p     += M_per_phi.sum(dim=0)
            sum_log_p += torch.log(M_per_phi.clamp_min(EPS)).sum(dim=0)

        avg_p     = sum_p / K1
        avg_log_p = sum_log_p / K1
        for i in range(N):
            for v in range(N):
                tau[(i, j, v, u)]     = avg_p[i, v]
                tau_log[(i, j, v, u)] = avg_log_p[i, v]
        print(f'  cell (j={j}, u={u}) done')
# Out:
#   cell (j=0, u=0) done
#   cell (j=0, u=1) done
#   cell (j=0, u=2) done
#   cell (j=0, u=3) done
#   cell (j=1, u=0) done
#   cell (j=1, u=1) done
#   cell (j=1, u=2) done
#   cell (j=1, u=3) done
#   cell (j=2, u=0) done
#   cell (j=2, u=1) done
#   cell (j=2, u=2) done
#   cell (j=2, u=3) done
#   cell (j=3, u=0) done
#   cell (j=3, u=1) done
#   cell (j=3, u=2) done
#   cell (j=3, u=3) done

# %%
tau
# Out:
# {(0, 0, 0, 0): tensor(0.2891, device='cuda:0'),
#  (0, 0, 1, 0): tensor(0.2173, device='cuda:0'),
#  (0, 0, 2, 0): tensor(0.3306, device='cuda:0'),
#  (0, 0, 3, 0): tensor(0.1631, device='cuda:0'),
#  (1, 0, 0, 0): tensor(0.2678, device='cuda:0'),
#  (1, 0, 1, 0): tensor(0.1838, device='cuda:0'),
#  (1, 0, 2, 0): tensor(0.3340, device='cuda:0'),
#  (1, 0, 3, 0): tensor(0.2144, device='cuda:0'),
#  (2, 0, 0, 0): tensor(0.3027, device='cuda:0'),
#  (2, 0, 1, 0): tensor(0.2693, device='cuda:0'),
#  (2, 0, 2, 0): tensor(0.0459, device='cuda:0'),
#  (2, 0, 3, 0): tensor(0.3821, device='cuda:0'),
#  (3, 0, 0, 0): tensor(0.1404, device='cuda:0'),
#  (3, 0, 1, 0): tensor(0.3296, device='cuda:0'),
#  (3, 0, 2, 0): tensor(0.2896, device='cuda:0'),
#  (3, 0, 3, 0): tensor(0.2405, device='cuda:0'),
#  (0, 0, 0, 1): tensor(0.2192, device='cuda:0'),
#  (0, 0, 1, 1): tensor(0.2046, device='cuda:0'),
#  (0, 0, 2, 1): tensor(0.4084, device='cuda:0'),
#  (0, 0, 3, 1): tensor(0.1677, device='cuda:0'),
#  (1, 0, 0, 1): tensor(0.0864, device='cuda:0'),
#  (1, 0, 1, 1): tensor(0.2886, device='cuda:0'),
#  (1, 0, 2, 1): tensor(0.2192, device='cuda:0'),
#  (1, 0, 3, 1): tensor(0.4058, device='cuda:0'),
#  (2, 0, 0, 1): tensor(0.3594, device='cuda:0'),
#  (2, 0, 1, 1): tensor(0.2178, device='cuda:0'),
#  (2, 0, 2, 1): tensor(0.1792, device='cuda:0'),
#  (2, 0, 3, 1): tensor(0.2437, device='cuda:0'),
#  (3, 0, 0, 1): tensor(0.3350, device='cuda:0'),
#  (3, 0, 1, 1): tensor(0.2891, device='cuda:0'),
#  (3, 0, 2, 1): tensor(0.1931, device='cuda:0'),
#  (3, 0, 3, 1): tensor(0.1829, device='cuda:0'),
#  (0, 0, 0, 2): tensor(0.0317, device='cuda:0'),
#  (0, 0, 1, 2): tensor(0.3132, device='cuda:0'),
#  (0, 0, 2, 2): tensor(0.1238, device='cuda:0'),
#  (0, 0, 3, 2): tensor(0.5312, device='cuda:0'),
#  (1, 0, 0, 2): tensor(0.2869, device='cuda:0'),
#  (1, 0, 1, 2): tensor(0.2183, device='cuda:0'),
#  (1, 0, 2, 2): tensor(0.3816, device='cuda:0'),
#  (1, 0, 3, 2): tensor(0.1133, device='cuda:0'),
#  (2, 0, 0, 2): tensor(0.3667, device='cuda:0'),
#  (2, 0, 1, 2): tensor(0.1824, device='cuda:0'),
#  (2, 0, 2, 2): tensor(0.1528, device='cuda:0'),
#  (2, 0, 3, 2): tensor(0.2981, device='cuda:0'),
#  (3, 0, 0, 2): tensor(0.3147, device='cuda:0'),
#  (3, 0, 1, 2): tensor(0.2861, device='cuda:0'),
#  (3, 0, 2, 2): tensor(0.3418, device='cuda:0'),
#  (3, 0, 3, 2): tensor(0.0574, device='cuda:0'),
#  (0, 0, 0, 3): tensor(0.2688, device='cuda:0'),
#  (0, 0, 1, 3): tensor(0.2756, device='cuda:0'),
#  (0, 0, 2, 3): tensor(0.2544, device='cuda:0'),
#  (0, 0, 3, 3): tensor(0.2012, device='cuda:0'),
#  (1, 0, 0, 3): tensor(0.0940, device='cuda:0'),
#  (1, 0, 1, 3): tensor(0.1809, device='cuda:0'),
#  (1, 0, 2, 3): tensor(0.2617, device='cuda:0'),
#  (1, 0, 3, 3): tensor(0.4634, device='cuda:0'),
#  (2, 0, 0, 3): tensor(0.2720, device='cuda:0'),
#  (2, 0, 1, 3): tensor(0.1956, device='cuda:0'),
#  (2, 0, 2, 3): tensor(0.4419, device='cuda:0'),
#  (2, 0, 3, 3): tensor(0.0906, device='cuda:0'),
#  (3, 0, 0, 3): tensor(0.3652, device='cuda:0'),
#  (3, 0, 1, 3): tensor(0.3479, device='cuda:0'),
#  (3, 0, 2, 3): tensor(0.0420, device='cuda:0'),
#  (3, 0, 3, 3): tensor(0.2449, device='cuda:0'),
#  (0, 1, 0, 0): tensor(0.2156, device='cuda:0'),
#  (0, 1, 1, 0): tensor(0.2800, device='cuda:0'),
#  (0, 1, 2, 0): tensor(0.1479, device='cuda:0'),
#  (0, 1, 3, 0): tensor(0.3564, device='cuda:0'),
#  (1, 1, 0, 0): tensor(0.1846, device='cuda:0'),
#  (1, 1, 1, 0): tensor(0.3271, device='cuda:0'),
#  (1, 1, 2, 0): tensor(0.2810, device='cuda:0'),
#  (1, 1, 3, 0): tensor(0.2073, device='cuda:0'),
#  (2, 1, 0, 0): tensor(0.2207, device='cuda:0'),
#  (2, 1, 1, 0): tensor(0.1790, device='cuda:0'),
#  (2, 1, 2, 0): tensor(0.3350, device='cuda:0'),
#  (2, 1, 3, 0): tensor(0.2654, device='cuda:0'),
#  (3, 1, 0, 0): tensor(0.3792, device='cuda:0'),
#  (3, 1, 1, 0): tensor(0.2139, device='cuda:0'),
#  (3, 1, 2, 0): tensor(0.2361, device='cuda:0'),
#  (3, 1, 3, 0): tensor(0.1709, device='cuda:0'),
#  (0, 1, 0, 1): tensor(0.2456, device='cuda:0'),
#  (0, 1, 1, 1): tensor(0.2266, device='cuda:0'),
#  (0, 1, 2, 1): tensor(0.2427, device='cuda:0'),
#  (0, 1, 3, 1): tensor(0.2852, device='cuda:0'),
#  (1, 1, 0, 1): tensor(0.1084, device='cuda:0'),
#  (1, 1, 1, 1): tensor(0.0808, device='cuda:0'),
#  (1, 1, 2, 1): tensor(0.3892, device='cuda:0'),
#  (1, 1, 3, 1): tensor(0.4216, device='cuda:0'),
#  (2, 1, 0, 1): tensor(0.3816, device='cuda:0'),
#  (2, 1, 1, 1): tensor(0.2346, device='cuda:0'),
#  (2, 1, 2, 1): tensor(0.2046, device='cuda:0'),
#  (2, 1, 3, 1): tensor(0.1792, device='cuda:0'),
#  (3, 1, 0, 1): tensor(0.2644, device='cuda:0'),
#  (3, 1, 1, 1): tensor(0.4580, device='cuda:0'),
#  (3, 1, 2, 1): tensor(0.1636, device='cuda:0'),
#  (3, 1, 3, 1): tensor(0.1140, device='cuda:0'),
#  (0, 1, 0, 2): tensor(0.2241, device='cuda:0'),
#  (0, 1, 1, 2): tensor(0.0945, device='cuda:0'),
#  (0, 1, 2, 2): tensor(0.3354, device='cuda:0'),
#  (0, 1, 3, 2): tensor(0.3459, device='cuda:0'),
#  (1, 1, 0, 2): tensor(0.2610, device='cuda:0'),
#  (1, 1, 1, 2): tensor(0.2380, device='cuda:0'),
#  (1, 1, 2, 2): tensor(0.2180, device='cuda:0'),
#  (1, 1, 3, 2): tensor(0.2830, device='cuda:0'),
#  (2, 1, 0, 2): tensor(0.3210, device='cuda:0'),
#  (2, 1, 1, 2): tensor(0.3635, device='cuda:0'),
#  (2, 1, 2, 2): tensor(0.1458, device='cuda:0'),
#  (2, 1, 3, 2): tensor(0.1697, device='cuda:0'),
#  (3, 1, 0, 2): tensor(0.1938, device='cuda:0'),
#  (3, 1, 1, 2): tensor(0.3040, device='cuda:0'),
#  (3, 1, 2, 2): tensor(0.3008, device='cuda:0'),
#  (3, 1, 3, 2): tensor(0.2014, device='cuda:0'),
#  (0, 1, 0, 3): tensor(0.1069, device='cuda:0'),
#  (0, 1, 1, 3): tensor(0.4614, device='cuda:0'),
#  (0, 1, 2, 3): tensor(0.3594, device='cuda:0'),
#  (0, 1, 3, 3): tensor(0.0723, device='cuda:0'),
#  (1, 1, 0, 3): tensor(0.1768, device='cuda:0'),
#  (1, 1, 1, 3): tensor(0.2253, device='cuda:0'),
#  (1, 1, 2, 3): tensor(0.3252, device='cuda:0'),
#  (1, 1, 3, 3): tensor(0.2727, device='cuda:0'),
#  (2, 1, 0, 3): tensor(0.4053, device='cuda:0'),
#  (2, 1, 1, 3): tensor(0.0955, device='cuda:0'),
#  (2, 1, 2, 3): tensor(0.1028, device='cuda:0'),
#  (2, 1, 3, 3): tensor(0.3965, device='cuda:0'),
#  (3, 1, 0, 3): tensor(0.3110, device='cuda:0'),
#  (3, 1, 1, 3): tensor(0.2178, device='cuda:0'),
#  (3, 1, 2, 3): tensor(0.2126, device='cuda:0'),
#  (3, 1, 3, 3): tensor(0.2585, device='cuda:0'),
#  (0, 2, 0, 0): tensor(0.1667, device='cuda:0'),
#  (0, 2, 1, 0): tensor(0.4185, device='cuda:0'),
#  (0, 2, 2, 0): tensor(0.1599, device='cuda:0'),
#  (0, 2, 3, 0): tensor(0.2549, device='cuda:0'),
#  (1, 2, 0, 0): tensor(0.1670, device='cuda:0'),
#  (1, 2, 1, 0): tensor(0.0684, device='cuda:0'),
#  (1, 2, 2, 0): tensor(0.2251, device='cuda:0'),
#  (1, 2, 3, 0): tensor(0.5396, device='cuda:0'),
#  (2, 2, 0, 0): tensor(0.4043, device='cuda:0'),
#  (2, 2, 1, 0): tensor(0.1663, device='cuda:0'),
#  (2, 2, 2, 0): tensor(0.3123, device='cuda:0'),
#  (2, 2, 3, 0): tensor(0.1172, device='cuda:0'),
#  (3, 2, 0, 0): tensor(0.2620, device='cuda:0'),
#  (3, 2, 1, 0): tensor(0.3469, device='cuda:0'),
#  (3, 2, 2, 0): tensor(0.3027, device='cuda:0'),
#  (3, 2, 3, 0): tensor(0.0884, device='cuda:0'),
#  (0, 2, 0, 1): tensor(0.1775, device='cuda:0'),
#  (0, 2, 1, 1): tensor(0.1323, device='cuda:0'),
#  (0, 2, 2, 1): tensor(0.4324, device='cuda:0'),
#  (0, 2, 3, 1): tensor(0.2578, device='cuda:0'),
#  (1, 2, 0, 1): tensor(0.2417, device='cuda:0'),
#  (1, 2, 1, 1): tensor(0.3528, device='cuda:0'),
#  (1, 2, 2, 1): tensor(0.1958, device='cuda:0'),
#  (1, 2, 3, 1): tensor(0.2097, device='cuda:0'),
#  (2, 2, 0, 1): tensor(0.1355, device='cuda:0'),
#  (2, 2, 1, 1): tensor(0.2383, device='cuda:0'),
#  (2, 2, 2, 1): tensor(0.2698, device='cuda:0'),
#  (2, 2, 3, 1): tensor(0.3564, device='cuda:0'),
#  (3, 2, 0, 1): tensor(0.4453, device='cuda:0'),
#  (3, 2, 1, 1): tensor(0.2766, device='cuda:0'),
#  (3, 2, 2, 1): tensor(0.1021, device='cuda:0'),
#  (3, 2, 3, 1): tensor(0.1760, device='cuda:0'),
#  (0, 2, 0, 2): tensor(0.2178, device='cuda:0'),
#  (0, 2, 1, 2): tensor(0.3794, device='cuda:0'),
#  (0, 2, 2, 2): tensor(0.2810, device='cuda:0'),
#  (0, 2, 3, 2): tensor(0.1218, device='cuda:0'),
#  (1, 2, 0, 2): tensor(0.0579, device='cuda:0'),
#  (1, 2, 1, 2): tensor(0.2808, device='cuda:0'),
#  (1, 2, 2, 2): tensor(0.4795, device='cuda:0'),
#  (1, 2, 3, 2): tensor(0.1819, device='cuda:0'),
#  (2, 2, 0, 2): tensor(0.4180, device='cuda:0'),
#  (2, 2, 1, 2): tensor(0.1350, device='cuda:0'),
#  (2, 2, 2, 2): tensor(0.0913, device='cuda:0'),
#  (2, 2, 3, 2): tensor(0.3557, device='cuda:0'),
#  (3, 2, 0, 2): tensor(0.3064, device='cuda:0'),
#  (3, 2, 1, 2): tensor(0.2048, device='cuda:0'),
#  (3, 2, 2, 2): tensor(0.1482, device='cuda:0'),
#  (3, 2, 3, 2): tensor(0.3406, device='cuda:0'),
#  (0, 2, 0, 3): tensor(0.1758, device='cuda:0'),
#  (0, 2, 1, 3): tensor(0.1692, device='cuda:0'),
#  (0, 2, 2, 3): tensor(0.2651, device='cuda:0'),
#  (0, 2, 3, 3): tensor(0.3899, device='cuda:0'),
#  (1, 2, 0, 3): tensor(0.2688, device='cuda:0'),
#  (1, 2, 1, 3): tensor(0.1733, device='cuda:0'),
#  (1, 2, 2, 3): tensor(0.3088, device='cuda:0'),
#  (1, 2, 3, 3): tensor(0.2490, device='cuda:0'),
#  (2, 2, 0, 3): tensor(0.4006, device='cuda:0'),
#  (2, 2, 1, 3): tensor(0.3069, device='cuda:0'),
#  (2, 2, 2, 3): tensor(0.1067, device='cuda:0'),
#  (2, 2, 3, 3): tensor(0.1858, device='cuda:0'),
#  (3, 2, 0, 3): tensor(0.1548, device='cuda:0'),
#  (3, 2, 1, 3): tensor(0.3506, device='cuda:0'),
#  (3, 2, 2, 3): tensor(0.3193, device='cuda:0'),
#  (3, 2, 3, 3): tensor(0.1753, device='cuda:0'),
#  (0, 3, 0, 0): tensor(0.1389, device='cuda:0'),
#  (0, 3, 1, 0): tensor(0.1111, device='cuda:0'),
#  (0, 3, 2, 0): tensor(0.4878, device='cuda:0'),
#  (0, 3, 3, 0): tensor(0.2622, device='cuda:0'),
#  (1, 3, 0, 0): tensor(0.1016, device='cuda:0'),
#  (1, 3, 1, 0): tensor(0.3459, device='cuda:0'),
#  (1, 3, 2, 0): tensor(0.3328, device='cuda:0'),
#  (1, 3, 3, 0): tensor(0.2197, device='cuda:0'),
#  (2, 3, 0, 0): tensor(0.3279, device='cuda:0'),
#  (2, 3, 1, 0): tensor(0.2153, device='cuda:0'),
#  (2, 3, 2, 0): tensor(0.1289, device='cuda:0'),
#  (2, 3, 3, 0): tensor(0.3279, device='cuda:0'),
#  (3, 3, 0, 0): tensor(0.4316, device='cuda:0'),
#  (3, 3, 1, 0): tensor(0.3276, device='cuda:0'),
#  (3, 3, 2, 0): tensor(0.0505, device='cuda:0'),
#  (3, 3, 3, 0): tensor(0.1902, device='cuda:0'),
#  (0, 3, 0, 1): tensor(0.1567, device='cuda:0'),
#  (0, 3, 1, 1): tensor(0.4543, device='cuda:0'),
#  (0, 3, 2, 1): tensor(0.0742, device='cuda:0'),
#  (0, 3, 3, 1): tensor(0.3147, device='cuda:0'),
#  (1, 3, 0, 1): tensor(0.2876, device='cuda:0'),
#  (1, 3, 1, 1): tensor(0.1489, device='cuda:0'),
#  (1, 3, 2, 1): tensor(0.4209, device='cuda:0'),
#  (1, 3, 3, 1): tensor(0.1426, device='cuda:0'),
#  (2, 3, 0, 1): tensor(0.4497, device='cuda:0'),
#  (2, 3, 1, 1): tensor(0.1812, device='cuda:0'),
#  (2, 3, 2, 1): tensor(0.1111, device='cuda:0'),
#  (2, 3, 3, 1): tensor(0.2581, device='cuda:0'),
#  (3, 3, 0, 1): tensor(0.1060, device='cuda:0'),
#  (3, 3, 1, 1): tensor(0.2156, device='cuda:0'),
#  (3, 3, 2, 1): tensor(0.3938, device='cuda:0'),
#  (3, 3, 3, 1): tensor(0.2847, device='cuda:0'),
#  (0, 3, 0, 2): tensor(0.2751, device='cuda:0'),
#  (0, 3, 1, 2): tensor(0.2466, device='cuda:0'),
#  (0, 3, 2, 2): tensor(0.3765, device='cuda:0'),
#  (0, 3, 3, 2): tensor(0.1018, device='cuda:0'),
#  (1, 3, 0, 2): tensor(0.1670, device='cuda:0'),
#  (1, 3, 1, 2): tensor(0.1536, device='cuda:0'),
#  (1, 3, 2, 2): tensor(0.1328, device='cuda:0'),
#  (1, 3, 3, 2): tensor(0.5466, device='cuda:0'),
#  (2, 3, 0, 2): tensor(0.2332, device='cuda:0'),
#  (2, 3, 1, 2): tensor(0.2119, device='cuda:0'),
#  (2, 3, 2, 2): tensor(0.3708, device='cuda:0'),
#  (2, 3, 3, 2): tensor(0.1841, device='cuda:0'),
#  (3, 3, 0, 2): tensor(0.3247, device='cuda:0'),
#  (3, 3, 1, 2): tensor(0.3879, device='cuda:0'),
#  (3, 3, 2, 2): tensor(0.1199, device='cuda:0'),
#  (3, 3, 3, 2): tensor(0.1675, device='cuda:0'),
#  (0, 3, 0, 3): tensor(0.2288, device='cuda:0'),
#  (0, 3, 1, 3): tensor(0.1858, device='cuda:0'),
#  (0, 3, 2, 3): tensor(0.2358, device='cuda:0'),
#  (0, 3, 3, 3): tensor(0.3496, device='cuda:0'),
#  (1, 3, 0, 3): tensor(0.1812, device='cuda:0'),
#  (1, 3, 1, 3): tensor(0.2942, device='cuda:0'),
#  (1, 3, 2, 3): tensor(0.3455, device='cuda:0'),
#  (1, 3, 3, 3): tensor(0.1792, device='cuda:0'),
#  (2, 3, 0, 3): tensor(0.2847, device='cuda:0'),
#  (2, 3, 1, 3): tensor(0.2102, device='cuda:0'),
#  (2, 3, 2, 3): tensor(0.1438, device='cuda:0'),
#  (2, 3, 3, 3): tensor(0.3613, device='cuda:0'),
#  (3, 3, 0, 3): tensor(0.3054, device='cuda:0'),
#  (3, 3, 1, 3): tensor(0.3098, device='cuda:0'),
#  (3, 3, 2, 3): tensor(0.2749, device='cuda:0'),
#  (3, 3, 3, 3): tensor(0.1099, device='cuda:0')}

# %% [markdown]
# ## Tensorize τ and τ_log for the aggregate methods
#
# Build dense `(N, N, N, N)` tensors on DEVICE so the aggregate cost reduces to one broadcast subtract + reduce over `(i, v)` — no per-cell Python loops.

# %%
def to_tensor(tau_dict):
    """Pack {(i, j, v, u): scalar} → tensor of shape (N, N, N, N) indexed [i, j, v, u]."""
    T = torch.zeros((N, N, N, N), device=DEVICE)
    for i in range(N):
        for j in range(N):
            for v in range(N):
                for u in range(N):
                    T[i, j, v, u] = tau_dict[(i, j, v, u)]
    return T

tau_tensor     = to_tensor(tau)
tau_log_tensor = to_tensor(tau_log)
print(f'tau_tensor    : {tuple(tau_tensor.shape)}, device={tau_tensor.device}')
print(f'tau_log_tensor: {tuple(tau_log_tensor.shape)}, device={tau_log_tensor.device}')
# Out:
# tau_tensor    : (4, 4, 4, 4), device=cuda:0
# tau_log_tensor: (4, 4, 4, 4), device=cuda:0

# %% [markdown]
# ## Pick witnesses (for the four single-witness methods)

# %%
def pick_witnesses(tau_dict):
    """Return (opts_max_spread, opts_max_min_spread): each {j: (i_j, v_j)}."""
    opts_ms, opts_mm = {}, {}
    for j in range(N):
        scores_ms = torch.zeros((N, N))
        scores_mm = torch.zeros((N, N))
        for i in range(N):
            for v in range(N):
                u_func = torch.tensor([tau_dict[(i, j, v, u)].item()
                                       if torch.is_tensor(tau_dict[(i, j, v, u)])
                                       else tau_dict[(i, j, v, u)]
                                       for u in range(N)])
                scores_ms[i, v] = u_func.max() - u_func.min()
                sorted_, _ = torch.sort(u_func, descending=True)
                scores_mm[i, v] = sorted_[0] - sorted_[1]
        i_ms = (scores_ms.argmax() // N).item(); v_ms = (scores_ms.argmax() % N).item()
        i_mm = (scores_mm.argmax() // N).item(); v_mm = (scores_mm.argmax() % N).item()
        opts_ms[j], opts_mm[j] = (i_ms, v_ms), (i_mm, v_mm)
    return opts_ms, opts_mm

opts_max_spread,     opts_max_min_spread     = pick_witnesses(tau)
opts_max_spread_log, opts_max_min_spread_log = pick_witnesses(tau_log)

print('raw — opts_max_spread:    ', opts_max_spread)
print('raw — opts_max_min_spread:', opts_max_min_spread)
print('log — opts_max_spread:    ', opts_max_spread_log)
print('log — opts_max_spread:    ', opts_max_min_spread_log)
# Out:
# raw — opts_max_spread:     {0: (2, 2), 1: (0, 1), 2: (1, 3), 3: (0, 2)}
# raw — opts_max_min_spread: {0: (0, 3), 1: (0, 1), 2: (1, 3), 3: (1, 3)}
# log — opts_max_spread:     {0: (3, 2), 1: (0, 3), 2: (1, 1), 3: (0, 1)}
# log — opts_max_spread:     {0: (2, 2), 1: (3, 1), 2: (1, 3), 3: (2, 2)}

# %% [markdown]
# ## Extract over all permutations — all 8 methods
#
# For each test phi:
# 1. Sample `B` psis (chunked by `B_CHUNK`); compute `mm` and `log_mm`.
# 2. For each of the 8 methods, build cost matrix `C[j, u]`, run brute-force ranking, record rank of truth.
# 3. Track top-1 / top-N / mean rank per method, plus union (any method).
#
# **Cost matrix construction by method `kind`:**
# - `raw` — single witness, raw scale: `C[j,u] = |τ[i_j,j,v_j,u] - mm[i_j,v_j]|`
# - `log` — single witness, log scale: `C[j,u] = |τ_log[i_j,j,v_j,u] - log_mm[i_j,v_j]|`
# - `agg_l2_log` / `agg_l1_log` / `agg_linf_log` — aggregate over (i, v) of `|log_mm - τ_log[:, j, :, u]|` under L2 / L1 / L∞
# - `agg_l2_raw` — same but raw: aggregate L2 of `|mm - τ[:, j, :, u]|`

# %%
B = K2                                                 # psi samples per test phi
B_CHUNK = CHUNK                                           # forward-pass batch size
permutations = list(itertools.permutations(range(N)))

seed = 0
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

# (witness_dict_or_None, tau_dict_or_None, kind)
METHODS = {
    'max-min raw':       (opts_max_min_spread,     tau,     'raw'),
    'max     raw':       (opts_max_spread,         tau,     'raw'),
    'max-min log':       (opts_max_min_spread_log, tau_log, 'log'),
    'max     log':       (opts_max_spread_log,     tau_log, 'log'),
    'aggregate L2  log': (None, None, 'agg_l2_log'),
    'aggregate L1  log': (None, None, 'agg_l1_log'),
    'aggregate L\u221E  log': (None, None, 'agg_linf_log'),
    'aggregate L2  raw': (None, None, 'agg_l2_log'),
    'aggregate L1  raw': (None, None, 'agg_l1_raw'),
    'aggregate L\u221E  raw': (None, None, 'agg_linf_raw'),
}

ranks = {m: [] for m in METHODS}
top1  = {m: 0  for m in METHODS}
topN  = {m: 0  for m in METHODS}
union_top1 = 0
union_topN = 0

def build_cost(kind, opts_dict, tau_dict, mm, log_mm):
    """Return (N, N) cost matrix on CPU."""
    if kind == 'raw':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            p_j = mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - p_j)
        return C
    if kind == 'log':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            lp_j = log_mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - lp_j)
        return C

    # aggregate methods: broadcast (N, N) test marginal vs. (N, N, N, N) tau tensor
    if kind == 'agg_l2_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    if kind == 'agg_l2_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    raise ValueError(f'unknown kind: {kind}')

for permutation in permutations:
    base = torch.tensor(permutation, device=DEVICE).long()
    counts = torch.zeros((N, N), device=DEVICE)
    for start in range(0, B, B_CHUNK):
        S = min(B_CHUNK, B - start)
        perm_rep = base.unsqueeze(0).expand(S, -1).contiguous()
        psis = sample_psi_rejection(model, perm_rep)
        counts += F.one_hot(psis.long(), N).float().sum(dim=0)
    mm     = counts / B
    log_mm = torch.log(mm.clamp_min(EPS))

    truth_tup = tuple(permutation)
    print(f'truth = {truth_tup}')
    iter_in_top1 = iter_in_topN = False

    for name, (opts_dict, tau_dict, kind) in METHODS.items():
        C = build_cost(kind, opts_dict, tau_dict, mm, log_mm)
        full   = top_k_assignments(C, k=None)
        top_N  = full[:N]
        rank   = next(i + 1 for i, (p, _) in enumerate(full) if tuple(p.tolist()) == truth_tup)
        in_top = rank <= N
        ranks[name].append(rank)
        if rank == 1:
            top1[name] += 1
            iter_in_top1 = True
        if in_top:
            topN[name] += 1
            iter_in_topN = True
        print(f'  {name:<22}  best={full[0][0].tolist()} (cost {full[0][1]:.4f})  '
              f'rank={rank}/{len(permutations)}  in-top-{N}={in_top}')
    if iter_in_top1: union_top1 += 1
    if iter_in_topN: union_topN += 1
    print()
# Out:
# truth = (0, 1, 2, 3)
#   max-min raw             best=[0, 2, 1, 3] (cost 0.1338)  rank=5/24  in-top-4=False
#   max     raw             best=[0, 2, 1, 3] (cost 0.2910)  rank=5/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.5504)  rank=18/24  in-top-4=False
#   max     log             best=[1, 2, 3, 0] (cost 15.2490)  rank=9/24  in-top-4=False
#   aggregate L2  log       best=[0, 2, 1, 3] (cost 152.5481)  rank=4/24  in-top-4=True
#   aggregate L1  log       best=[0, 2, 1, 3] (cost 503.3492)  rank=9/24  in-top-4=False
#   aggregate L∞  log       best=[2, 3, 1, 0] (cost 73.9000)  rank=8/24  in-top-4=False
#   aggregate L2  raw       best=[0, 2, 1, 3] (cost 152.5481)  rank=4/24  in-top-4=True
#   aggregate L1  raw       best=[0, 2, 1, 3] (cost 8.6533)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 1, 3, 2] (cost 1.5769)  rank=2/24  in-top-4=True
#
# truth = (0, 1, 3, 2)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.4514)  rank=2/24  in-top-4=True
#   max     raw             best=[0, 1, 3, 2] (cost 0.2876)  rank=1/24  in-top-4=True
#   max-min log             best=[0, 1, 2, 3] (cost 33.6619)  rank=5/24  in-top-4=False
#   max     log             best=[0, 3, 2, 1] (cost 18.5516)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[0, 1, 3, 2] (cost 156.2413)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[0, 1, 3, 2] (cost 516.8262)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 80.1184)  rank=3/24  in-top-4=True
#   aggregate L2  raw       best=[0, 1, 3, 2] (cost 156.2413)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[0, 1, 3, 2] (cost 8.0093)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 3, 1, 2] (cost 1.1816)  rank=9/24  in-top-4=False
#
# truth = (0, 2, 1, 3)
#   max-min raw             best=[0, 2, 1, 3] (cost 0.5078)  rank=1/24  in-top-4=True
#   max     raw             best=[1, 2, 3, 0] (cost 0.5574)  rank=2/24  in-top-4=True
#   max-min log             best=[0, 1, 2, 3] (cost 42.4256)  rank=3/24  in-top-4=True
#   max     log             best=[1, 2, 3, 0] (cost 15.1620)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[0, 2, 1, 3] (cost 155.4870)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[0, 2, 3, 1] (cost 502.2314)  rank=2/24  in-top-4=True
#   aggregate L∞  log       best=[0, 2, 1, 3] (cost 78.9456)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[0, 2, 1, 3] (cost 155.4870)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[0, 2, 1, 3] (cost 12.2549)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 3, 1, 0] (cost 2.0168)  rank=3/24  in-top-4=True
#
# truth = (0, 2, 3, 1)
#   max-min raw             best=[2, 0, 1, 3] (cost 0.5752)  rank=11/24  in-top-4=False
#   max     raw             best=[0, 2, 3, 1] (cost 0.4309)  rank=1/24  in-top-4=True
#   max-min log             best=[0, 2, 1, 3] (cost 55.4850)  rank=3/24  in-top-4=True
#   max     log             best=[2, 0, 3, 1] (cost 10.2603)  rank=2/24  in-top-4=True
#   aggregate L2  log       best=[0, 2, 3, 1] (cost 172.4016)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[0, 2, 3, 1] (cost 554.7656)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 83.6071)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[0, 2, 3, 1] (cost 172.4016)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[0, 2, 3, 1] (cost 12.8647)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 2.0715)  rank=1/24  in-top-4=True
#
# truth = (0, 3, 1, 2)
#   max-min raw             best=[1, 2, 3, 0] (cost 0.2153)  rank=19/24  in-top-4=False
#   max     raw             best=[1, 2, 3, 0] (cost 0.5837)  rank=15/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.1577)  rank=21/24  in-top-4=False
#   max     log             best=[3, 2, 1, 0] (cost 11.7419)  rank=20/24  in-top-4=False
#   aggregate L2  log       best=[3, 0, 1, 2] (cost 173.1120)  rank=3/24  in-top-4=True
#   aggregate L1  log       best=[3, 0, 1, 2] (cost 570.5106)  rank=7/24  in-top-4=False
#   aggregate L∞  log       best=[0, 3, 1, 2] (cost 81.9492)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[3, 0, 1, 2] (cost 173.1120)  rank=3/24  in-top-4=True
#   aggregate L1  raw       best=[1, 2, 3, 0] (cost 9.8525)  rank=5/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 3, 2, 0] (cost 2.0259)  rank=3/24  in-top-4=True
#
# truth = (0, 3, 2, 1)
#   max-min raw             best=[0, 3, 2, 1] (cost 0.6355)  rank=1/24  in-top-4=True
#   max     raw             best=[0, 3, 2, 1] (cost 0.5750)  rank=1/24  in-top-4=True
#   max-min log             best=[0, 1, 2, 3] (cost 33.2506)  rank=4/24  in-top-4=True
#   max     log             best=[2, 3, 0, 1] (cost 20.1013)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[0, 3, 2, 1] (cost 185.9478)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[0, 3, 2, 1] (cost 635.1786)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 83.4326)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[0, 3, 2, 1] (cost 185.9478)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[0, 3, 2, 1] (cost 15.1484)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 3, 2, 1] (cost 2.1260)  rank=1/24  in-top-4=True
#
# truth = (1, 0, 2, 3)
#   max-min raw             best=[2, 3, 1, 0] (cost 0.6555)  rank=8/24  in-top-4=False
#   max     raw             best=[0, 3, 2, 1] (cost 0.4187)  rank=7/24  in-top-4=False
#   max-min log             best=[0, 2, 1, 3] (cost 55.4850)  rank=10/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 9.2236)  rank=6/24  in-top-4=False
#   aggregate L2  log       best=[1, 0, 2, 3] (cost 213.6397)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 3, 1] (cost 719.0311)  rank=3/24  in-top-4=True
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 86.8468)  rank=4/24  in-top-4=True
#   aggregate L2  raw       best=[1, 0, 2, 3] (cost 213.6397)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[2, 3, 0, 1] (cost 12.7251)  rank=5/24  in-top-4=False
#   aggregate L∞  raw       best=[2, 0, 1, 3] (cost 1.4600)  rank=2/24  in-top-4=True
#
# truth = (1, 0, 3, 2)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.3147)  rank=3/24  in-top-4=True
#   max     raw             best=[3, 1, 0, 2] (cost 0.3813)  rank=9/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.0579)  rank=7/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 7.8645)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[1, 0, 3, 2] (cost 117.7523)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[1, 0, 3, 2] (cost 402.1328)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[1, 0, 3, 2] (cost 54.1452)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[1, 0, 3, 2] (cost 117.7523)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 1, 0, 2] (cost 5.4585)  rank=4/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 0, 1, 2] (cost 0.7573)  rank=3/24  in-top-4=True
#
# truth = (1, 2, 0, 3)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.4236)  rank=3/24  in-top-4=True
#   max     raw             best=[1, 2, 0, 3] (cost 0.5461)  rank=1/24  in-top-4=True
#   max-min log             best=[3, 1, 0, 2] (cost 4.4801)  rank=9/24  in-top-4=False
#   max     log             best=[1, 2, 3, 0] (cost 15.9557)  rank=13/24  in-top-4=False
#   aggregate L2  log       best=[1, 2, 0, 3] (cost 170.3730)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[1, 2, 0, 3] (cost 567.9107)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[1, 2, 0, 3] (cost 83.7379)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[1, 2, 0, 3] (cost 170.3730)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[1, 2, 3, 0] (cost 9.0596)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[1, 0, 3, 2] (cost 1.3979)  rank=5/24  in-top-4=False
#
# truth = (1, 2, 3, 0)
#   max-min raw             best=[1, 2, 3, 0] (cost 0.5361)  rank=1/24  in-top-4=True
#   max     raw             best=[1, 2, 3, 0] (cost 0.5994)  rank=1/24  in-top-4=True
#   max-min log             best=[3, 1, 0, 2] (cost 4.3108)  rank=12/24  in-top-4=False
#   max     log             best=[3, 2, 1, 0] (cost 13.6878)  rank=4/24  in-top-4=True
#   aggregate L2  log       best=[3, 2, 1, 0] (cost 155.7456)  rank=2/24  in-top-4=True
#   aggregate L1  log       best=[1, 2, 3, 0] (cost 520.5434)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[3, 1, 2, 0] (cost 75.8841)  rank=3/24  in-top-4=True
#   aggregate L2  raw       best=[3, 2, 1, 0] (cost 155.7456)  rank=2/24  in-top-4=True
#   aggregate L1  raw       best=[1, 2, 3, 0] (cost 10.7349)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[1, 2, 3, 0] (cost 1.3838)  rank=1/24  in-top-4=True
#
# truth = (1, 3, 0, 2)
#   max-min raw             best=[1, 3, 0, 2] (cost 1.2295)  rank=1/24  in-top-4=True
#   max     raw             best=[1, 3, 0, 2] (cost 0.7559)  rank=1/24  in-top-4=True
#   max-min log             best=[3, 1, 0, 2] (cost 4.8862)  rank=3/24  in-top-4=True
#   max     log             best=[2, 3, 0, 1] (cost 20.6225)  rank=2/24  in-top-4=True
#   aggregate L2  log       best=[1, 3, 0, 2] (cost 201.2747)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[1, 3, 0, 2] (cost 703.1792)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[1, 3, 0, 2] (cost 82.4585)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[1, 3, 0, 2] (cost 201.2747)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[1, 3, 0, 2] (cost 12.0938)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 1, 0, 2] (cost 2.0298)  rank=2/24  in-top-4=True
#
# truth = (1, 3, 2, 0)
#   max-min raw             best=[0, 2, 1, 3] (cost 0.6465)  rank=12/24  in-top-4=False
#   max     raw             best=[1, 2, 3, 0] (cost 0.7537)  rank=9/24  in-top-4=False
#   max-min log             best=[0, 2, 1, 3] (cost 55.4850)  rank=9/24  in-top-4=False
#   max     log             best=[2, 3, 1, 0] (cost 18.9096)  rank=2/24  in-top-4=True
#   aggregate L2  log       best=[1, 3, 2, 0] (cost 192.3452)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[1, 3, 2, 0] (cost 692.2159)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 76.1756)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[1, 3, 2, 0] (cost 192.3452)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[1, 3, 2, 0] (cost 15.2085)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 3, 1, 0] (cost 2.1882)  rank=3/24  in-top-4=True
#
# truth = (2, 0, 1, 3)
#   max-min raw             best=[2, 0, 1, 3] (cost 0.7002)  rank=1/24  in-top-4=True
#   max     raw             best=[3, 0, 2, 1] (cost 0.5552)  rank=9/24  in-top-4=False
#   max-min log             best=[3, 0, 1, 2] (cost 26.4866)  rank=8/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 10.3322)  rank=4/24  in-top-4=True
#   aggregate L2  log       best=[2, 0, 1, 3] (cost 149.0937)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 1, 3] (cost 491.2381)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[2, 0, 1, 3] (cost 71.9399)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[2, 0, 1, 3] (cost 149.0937)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[2, 0, 1, 3] (cost 10.3193)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 0, 1, 3] (cost 1.5842)  rank=1/24  in-top-4=True
#
# truth = (2, 0, 3, 1)
#   max-min raw             best=[2, 1, 3, 0] (cost 0.2422)  rank=2/24  in-top-4=True
#   max     raw             best=[2, 0, 1, 3] (cost 0.1333)  rank=3/24  in-top-4=True
#   max-min log             best=[1, 3, 0, 2] (cost 28.1030)  rank=14/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 9.5023)  rank=1/24  in-top-4=True
#   aggregate L2  log       best=[2, 0, 1, 3] (cost 173.8842)  rank=2/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 3, 1] (cost 569.6250)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[2, 3, 1, 0] (cost 81.0964)  rank=8/24  in-top-4=False
#   aggregate L2  raw       best=[2, 0, 1, 3] (cost 173.8842)  rank=2/24  in-top-4=True
#   aggregate L1  raw       best=[2, 0, 1, 3] (cost 9.3452)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 1.4624)  rank=3/24  in-top-4=True
#
# truth = (2, 1, 0, 3)
#   max-min raw             best=[2, 3, 1, 0] (cost 0.0471)  rank=10/24  in-top-4=False
#   max     raw             best=[0, 3, 2, 1] (cost 0.3079)  rank=18/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.7735)  rank=3/24  in-top-4=True
#   max     log             best=[1, 2, 0, 3] (cost 26.0278)  rank=7/24  in-top-4=False
#   aggregate L2  log       best=[2, 3, 0, 1] (cost 157.6274)  rank=2/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 3, 1] (cost 517.8715)  rank=3/24  in-top-4=True
#   aggregate L∞  log       best=[2, 3, 0, 1] (cost 71.1617)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[2, 3, 0, 1] (cost 157.6274)  rank=2/24  in-top-4=True
#   aggregate L1  raw       best=[2, 0, 3, 1] (cost 7.2466)  rank=3/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 0, 3, 1] (cost 1.0789)  rank=2/24  in-top-4=True
#
# truth = (2, 1, 3, 0)
#   max-min raw             best=[2, 0, 1, 3] (cost 1.1377)  rank=3/24  in-top-4=True
#   max     raw             best=[0, 2, 3, 1] (cost 0.4636)  rank=14/24  in-top-4=False
#   max-min log             best=[0, 1, 2, 3] (cost 42.6725)  rank=6/24  in-top-4=False
#   max     log             best=[3, 2, 1, 0] (cost 38.2127)  rank=11/24  in-top-4=False
#   aggregate L2  log       best=[3, 1, 2, 0] (cost 253.1101)  rank=4/24  in-top-4=True
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 938.3102)  rank=6/24  in-top-4=False
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 95.7511)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[3, 1, 2, 0] (cost 253.1101)  rank=4/24  in-top-4=True
#   aggregate L1  raw       best=[2, 1, 3, 0] (cost 20.4399)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 1, 3, 0] (cost 2.8577)  rank=1/24  in-top-4=True
#
# truth = (2, 3, 0, 1)
#   max-min raw             best=[2, 3, 1, 0] (cost 0.2815)  rank=9/24  in-top-4=False
#   max     raw             best=[0, 3, 2, 1] (cost 0.1853)  rank=8/24  in-top-4=False
#   max-min log             best=[0, 1, 2, 3] (cost 32.5632)  rank=6/24  in-top-4=False
#   max     log             best=[1, 2, 0, 3] (cost 26.5109)  rank=4/24  in-top-4=True
#   aggregate L2  log       best=[2, 3, 0, 1] (cost 174.7307)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[0, 2, 3, 1] (cost 574.2415)  rank=3/24  in-top-4=True
#   aggregate L∞  log       best=[2, 3, 0, 1] (cost 80.4114)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[2, 3, 0, 1] (cost 174.7307)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[2, 0, 3, 1] (cost 9.1426)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 1.2266)  rank=3/24  in-top-4=True
#
# truth = (2, 3, 1, 0)
#   max-min raw             best=[0, 3, 2, 1] (cost 0.6824)  rank=10/24  in-top-4=False
#   max     raw             best=[1, 3, 2, 0] (cost 0.6072)  rank=3/24  in-top-4=True
#   max-min log             best=[3, 0, 1, 2] (cost 22.8604)  rank=8/24  in-top-4=False
#   max     log             best=[0, 3, 2, 1] (cost 18.0278)  rank=5/24  in-top-4=False
#   aggregate L2  log       best=[2, 3, 1, 0] (cost 188.4077)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 1, 3] (cost 618.7336)  rank=11/24  in-top-4=False
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 81.4811)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[2, 3, 1, 0] (cost 188.4077)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[2, 3, 1, 0] (cost 12.2954)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 3, 2, 1] (cost 1.8269)  rank=6/24  in-top-4=False
#
# truth = (3, 0, 1, 2)
#   max-min raw             best=[1, 2, 3, 0] (cost 0.3628)  rank=12/24  in-top-4=False
#   max     raw             best=[3, 2, 0, 1] (cost 0.3430)  rank=6/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.5470)  rank=6/24  in-top-4=False
#   max     log             best=[3, 0, 1, 2] (cost 10.2630)  rank=1/24  in-top-4=True
#   aggregate L2  log       best=[3, 0, 1, 2] (cost 172.7840)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[3, 0, 1, 2] (cost 571.0095)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[3, 1, 2, 0] (cost 81.6458)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[3, 0, 1, 2] (cost 172.7840)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 0, 1, 2] (cost 10.1924)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 1, 0, 2] (cost 1.5100)  rank=2/24  in-top-4=True
#
# truth = (3, 0, 2, 1)
#   max-min raw             best=[1, 3, 2, 0] (cost 0.2598)  rank=5/24  in-top-4=False
#   max     raw             best=[1, 0, 2, 3] (cost 0.5322)  rank=8/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.8381)  rank=12/24  in-top-4=False
#   max     log             best=[3, 0, 2, 1] (cost 10.4596)  rank=1/24  in-top-4=True
#   aggregate L2  log       best=[3, 0, 1, 2] (cost 153.3526)  rank=5/24  in-top-4=False
#   aggregate L1  log       best=[3, 0, 1, 2] (cost 509.5292)  rank=5/24  in-top-4=False
#   aggregate L∞  log       best=[3, 0, 1, 2] (cost 72.9824)  rank=3/24  in-top-4=True
#   aggregate L2  raw       best=[3, 0, 1, 2] (cost 153.3526)  rank=5/24  in-top-4=False
#   aggregate L1  raw       best=[0, 3, 2, 1] (cost 8.2036)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 3, 2, 1] (cost 1.3037)  rank=3/24  in-top-4=True
#
# truth = (3, 1, 0, 2)
#   max-min raw             best=[1, 3, 0, 2] (cost 1.0576)  rank=2/24  in-top-4=True
#   max     raw             best=[2, 3, 0, 1] (cost 1.3892)  rank=3/24  in-top-4=True
#   max-min log             best=[3, 1, 0, 2] (cost 6.9437)  rank=1/24  in-top-4=True
#   max     log             best=[3, 2, 0, 1] (cost 14.4381)  rank=2/24  in-top-4=True
#   aggregate L2  log       best=[3, 1, 0, 2] (cost 169.3225)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[3, 1, 0, 2] (cost 562.5950)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[3, 1, 0, 2] (cost 81.5301)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[3, 1, 0, 2] (cost 169.3225)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 1, 0, 2] (cost 14.8970)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 1, 0, 2] (cost 2.5454)  rank=1/24  in-top-4=True
#
# truth = (3, 1, 2, 0)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.6541)  rank=13/24  in-top-4=False
#   max     raw             best=[1, 2, 0, 3] (cost 0.6555)  rank=11/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.9838)  rank=4/24  in-top-4=True
#   max     log             best=[3, 1, 2, 0] (cost 32.0125)  rank=1/24  in-top-4=True
#   aggregate L2  log       best=[3, 1, 2, 0] (cost 187.2301)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 661.2755)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[3, 1, 2, 0] (cost 83.4623)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[3, 1, 2, 0] (cost 187.2301)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 1, 0, 2] (cost 12.3584)  rank=3/24  in-top-4=True
#   aggregate L∞  raw       best=[1, 2, 3, 0] (cost 1.5842)  rank=5/24  in-top-4=False
#
# truth = (3, 2, 0, 1)
#   max-min raw             best=[3, 1, 2, 0] (cost 0.2039)  rank=20/24  in-top-4=False
#   max     raw             best=[3, 0, 2, 1] (cost 0.2705)  rank=14/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 4.7620)  rank=6/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 6.7500)  rank=17/24  in-top-4=False
#   aggregate L2  log       best=[0, 2, 3, 1] (cost 138.9656)  rank=3/24  in-top-4=True
#   aggregate L1  log       best=[0, 2, 3, 1] (cost 452.8116)  rank=3/24  in-top-4=True
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 70.1060)  rank=4/24  in-top-4=True
#   aggregate L2  raw       best=[0, 2, 3, 1] (cost 138.9656)  rank=3/24  in-top-4=True
#   aggregate L1  raw       best=[0, 2, 3, 1] (cost 7.3730)  rank=6/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 1.2000)  rank=8/24  in-top-4=False
#
# truth = (3, 2, 1, 0)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.5173)  rank=11/24  in-top-4=False
#   max     raw             best=[3, 1, 0, 2] (cost 0.4868)  rank=2/24  in-top-4=True
#   max-min log             best=[1, 3, 0, 2] (cost 30.5512)  rank=8/24  in-top-4=False
#   max     log             best=[3, 2, 1, 0] (cost 11.1248)  rank=1/24  in-top-4=True
#   aggregate L2  log       best=[3, 2, 1, 0] (cost 218.3730)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[3, 2, 1, 0] (cost 770.3403)  rank=1/24  in-top-4=True
#   aggregate L∞  log       best=[3, 2, 1, 0] (cost 91.2130)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[3, 2, 1, 0] (cost 218.3730)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 0, 1, 2] (cost 15.3872)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 0, 1, 2] (cost 2.4856)  rank=4/24  in-top-4=True

# %%
T = len(permutations)
print('=' * 90)
print(f'Summary over all {T} permutations of S_{N}')
print(f'Random baselines: top-1 ~ {100/T:.1f}%, top-{N} ~ {100*N/T:.1f}%, mean rank ~ {(T+1)/2:.1f}')
print('-' * 90)
print(f'{"method":<24} {"top-1":>10} {"top-N":>10} {"mean rank":>14}')
for m in METHODS:
    print(f'{m:<24} {top1[m]}/{T:<6} {topN[m]}/{T:<6} {sum(ranks[m])/T:>12.2f}')
print('-' * 90)
print(f'{"union (any method)":<24} {union_top1}/{T:<6} {union_topN}/{T:<6}')
# Out:
# ==========================================================================================
# Summary over all 24 permutations of S_4
# Random baselines: top-1 ~ 4.2%, top-4 ~ 16.7%, mean rank ~ 12.5
# ------------------------------------------------------------------------------------------
# method                        top-1      top-N      mean rank
# max-min raw              5/24     11/24             6.88
# max     raw              6/24     11/24             6.33
# max-min log              1/24     7/24             7.75
# max     log              5/24     16/24             5.21
# aggregate L2  log        16/24     23/24             1.71
# aggregate L1  log        14/24     19/24             2.75
# aggregate L∞  log        12/24     22/24             2.29
# aggregate L2  raw        16/24     23/24             1.71
# aggregate L1  raw        12/24     21/24             2.08
# aggregate L∞  raw        6/24     19/24             3.08
# ------------------------------------------------------------------------------------------
# union (any method)       21/24     24/24
