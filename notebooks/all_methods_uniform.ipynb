# %% [markdown]
# # All 8 extraction algorithms
#
# Same τ and τ_log build as `raw_vs_log.ipynb`, plus four **aggregate** methods that use the entire (i, v) slice of τ instead of picking one witness coordinate.
#
# **Single-witness methods** (use one $(i_j, v_j)$ per $j$):
# 1. max-spread + raw cost
# 2. max-min spread + raw cost  (top1 − top2 margin)
# 3. max-spread + log cost
# 4. max-min spread + log cost
#
# **Aggregate methods** (use all $n^2$ cells in the (i, v) slice — no witness needed):
# 5. aggregate L2  + log cost   ←  paper's choice (Assumption `positional-leakage`)
# 6. aggregate L1  + log cost
# 7. aggregate L∞  + log cost
# 8. aggregate L2  + raw cost
#
# All eight methods report top-1 / top-N / mean rank, plus a union row.

# %%
import sys, random, itertools
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import torch
import torch.nn.functional as F
import numpy as np
from scipy.optimize import linear_sum_assignment

import config
from model import TinyTransformer

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
N = config.N
EPS = 1e-12
print(f'N = {N}, device = {DEVICE}')
# Out:
# N = 4, device = cuda

# %%
CHECKPOINT = PROJECT_ROOT / 'checkpoints' / 'model_psi-uniform_2500.pt'

def load_model(path):
    m = TinyTransformer().to(DEVICE)
    m.load_state_dict(torch.load(path, map_location=DEVICE))
    m.eval()
    return m

model = load_model(CHECKPOINT)
print(f'Loaded {CHECKPOINT.name}')
# Out:
# Loaded model_psi-uniform_2500.pt
# /tmp/ipykernel_696193/2294479975.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   m.load_state_dict(torch.load(path, map_location=DEVICE))

# %%
@torch.no_grad()
def sample_psi_unconstrained(model, phis):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    psi_start = config.PSI.start
    psi_buf = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    seq = torch.cat([phis.to(DEVICE), psi_buf], dim=1)
    for j in range(N):
        logits = model(seq)
        step_logits = logits[:, psi_start - 1 + j, :]
        probs = F.softmax(step_logits, dim=-1)
        sampled = torch.multinomial(probs, num_samples=1).squeeze(-1)
        seq[:, psi_start + j] = sampled
    return seq[:, psi_start:psi_start + N]

def is_perm_rows(samples, n):
    sorted_, _ = torch.sort(samples, dim=1)
    expected = torch.arange(n, device=samples.device).unsqueeze(0).expand_as(sorted_)
    return (sorted_ == expected).all(dim=1)

@torch.no_grad()
def sample_psi_rejection(model, phis, max_attempts=50):
    model.eval()
    if phis.dim() == 1:
        phis = phis.unsqueeze(0)
    B = phis.shape[0]
    phis = phis.to(DEVICE)
    out     = torch.zeros((B, N), dtype=torch.long, device=DEVICE)
    pending = torch.ones(B,        dtype=torch.bool, device=DEVICE)
    for _ in range(max_attempts):
        idx = torch.nonzero(pending, as_tuple=False).squeeze(1)
        if idx.numel() == 0:
            break
        psis_try = sample_psi_unconstrained(model, phis[idx])
        valid = is_perm_rows(psis_try, N)
        out[idx[valid]] = psis_try[valid]
        pending[idx[valid]] = False
    if pending.any():
        raise RuntimeError(
            f'{int(pending.sum().item())} rows still invalid after {max_attempts} attempts'
        )
    return out

def marginal_matrix(samples, n=N):
    return F.one_hot(samples.long(), n).float().mean(dim=0)

def random_phis_with_constraint(B, j, u, n=N, seed=None):
    g = torch.Generator()
    if seed is not None: g.manual_seed(seed)
    other_positions = torch.tensor([i for i in range(n) if i != j], dtype=torch.long)
    other_values    = torch.tensor([v for v in range(n) if v != u], dtype=torch.long)
    keys = torch.rand((B, n - 1), generator=g)
    perms = keys.argsort(dim=1)
    perm_values = other_values[perms]
    out = torch.zeros((B, n), dtype=torch.long)
    out[:, j] = u
    out[:, other_positions] = perm_values
    return out

# %%
def best_assignment(C):
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    row_ind, col_ind = linear_sum_assignment(C_np)
    return torch.tensor(col_ind, dtype=torch.long), float(C_np[row_ind, col_ind].sum())

def top_k_assignments(C, k=None):
    n = C.shape[0]
    C_np = C.cpu().numpy() if torch.is_tensor(C) else C
    rows = np.arange(n)
    scored = [
        (C_np[rows, list(perm)].sum(), perm)
        for perm in itertools.permutations(range(n))
    ]
    scored.sort(key=lambda x: x[0])
    if k is not None:
        scored = scored[:k]
    return [(torch.tensor(p, dtype=torch.long), float(c)) for c, p in scored]

# %% [markdown]
# ## Build τ and τ_log
#
# K1 phis per (j, u); K2 psis per phi. Per-phi marginal computed first, then both raw average and log-then-average over the K1 phis.

# %%
tau     = {}
tau_log = {}

seed = 42
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

K1 = 2**6      # phis per (j, u)
K2 = 2**6         # psis per phi (large to keep log-bias small)
CHUNK = 2**14     # rows per model.forward call

for j in range(N):
    for u in range(N):
        phis = random_phis_with_constraint(K1, j=j, u=u)
        sum_p     = torch.zeros((N, N), device=DEVICE)
        sum_log_p = torch.zeros((N, N), device=DEVICE)

        if K2 <= CHUNK:
            phi_chunk = max(1, CHUNK // K2)
            psi_subchunk = K2
        else:
            phi_chunk = 1
            psi_subchunk = CHUNK

        for phi_start in range(0, K1, phi_chunk):
            P = min(phi_chunk, K1 - phi_start)
            this_phis = phis[phi_start:phi_start + P]
            counts = torch.zeros((P, N, N), device=DEVICE)
            for psi_start in range(0, K2, psi_subchunk):
                S = min(psi_subchunk, K2 - psi_start)
                phi_rep = this_phis.repeat_interleave(S, dim=0)
                psis    = sample_psi_rejection(model, phi_rep)
                psis    = psis.view(P, S, N)
                counts += F.one_hot(psis.long(), N).float().sum(dim=1)
            M_per_phi = counts / K2
            sum_p     += M_per_phi.sum(dim=0)
            sum_log_p += torch.log(M_per_phi.clamp_min(EPS)).sum(dim=0)

        avg_p     = sum_p / K1
        avg_log_p = sum_log_p / K1
        for i in range(N):
            for v in range(N):
                tau[(i, j, v, u)]     = avg_p[i, v]
                tau_log[(i, j, v, u)] = avg_log_p[i, v]
        print(f'  cell (j={j}, u={u}) done')
# Out:
#   cell (j=0, u=0) done
#   cell (j=0, u=1) done
#   cell (j=0, u=2) done
#   cell (j=0, u=3) done
#   cell (j=1, u=0) done
#   cell (j=1, u=1) done
#   cell (j=1, u=2) done
#   cell (j=1, u=3) done
#   cell (j=2, u=0) done
#   cell (j=2, u=1) done
#   cell (j=2, u=2) done
#   cell (j=2, u=3) done
#   cell (j=3, u=0) done
#   cell (j=3, u=1) done
#   cell (j=3, u=2) done
#   cell (j=3, u=3) done

# %%
tau
# Out:
# {(0, 0, 0, 0): tensor(0.2515, device='cuda:0'),
#  (3, 3, 3, 2): tensor(0.2451, device='cuda:0'),
#  (0, 3, 0, 3): tensor(0.2334, device='cuda:0'),
#  (0, 3, 1, 3): tensor(0.2815, device='cuda:0'),
#  (0, 3, 2, 3): tensor(0.2305, device='cuda:0'),
#  (0, 3, 3, 3): tensor(0.2546, device='cuda:0'),
#  (1, 3, 0, 3): tensor(0.2444, device='cuda:0'),
#  (1, 3, 1, 3): tensor(0.2407, device='cuda:0'),
#  (1, 3, 2, 3): tensor(0.2544, device='cuda:0'),
#  (1, 3, 3, 3): tensor(0.2605, device='cuda:0'),
#  (2, 3, 0, 3): tensor(0.2375, device='cuda:0'),
#  (2, 3, 1, 3): tensor(0.2681, device='cuda:0'),
#  (2, 3, 2, 3): tensor(0.2451, device='cuda:0'),
#  (2, 3, 3, 3): tensor(0.2493, device='cuda:0'),
#  (3, 3, 0, 3): tensor(0.2847, device='cuda:0'),
#  (3, 3, 1, 3): tensor(0.2097, device='cuda:0'),
#  (3, 3, 2, 3): tensor(0.2700, device='cuda:0'),
#  (3, 3, 3, 3): tensor(0.2356, device='cuda:0')}

# %% [markdown]
# ## Tensorize τ and τ_log for the aggregate methods
#
# Build dense `(N, N, N, N)` tensors on DEVICE so the aggregate cost reduces to one broadcast subtract + reduce over `(i, v)` — no per-cell Python loops.

# %%
def to_tensor(tau_dict):
    """Pack {(i, j, v, u): scalar} → tensor of shape (N, N, N, N) indexed [i, j, v, u]."""
    T = torch.zeros((N, N, N, N), device=DEVICE)
    for i in range(N):
        for j in range(N):
            for v in range(N):
                for u in range(N):
                    T[i, j, v, u] = tau_dict[(i, j, v, u)]
    return T

tau_tensor     = to_tensor(tau)
tau_log_tensor = to_tensor(tau_log)
print(f'tau_tensor    : {tuple(tau_tensor.shape)}, device={tau_tensor.device}')
print(f'tau_log_tensor: {tuple(tau_log_tensor.shape)}, device={tau_log_tensor.device}')
# Out:
# tau_tensor    : (4, 4, 4, 4), device=cuda:0
# tau_log_tensor: (4, 4, 4, 4), device=cuda:0

# %% [markdown]
# ## Pick witnesses (for the four single-witness methods)

# %%
def pick_witnesses(tau_dict):
    """Return (opts_max_spread, opts_max_min_spread): each {j: (i_j, v_j)}."""
    opts_ms, opts_mm = {}, {}
    for j in range(N):
        scores_ms = torch.zeros((N, N))
        scores_mm = torch.zeros((N, N))
        for i in range(N):
            for v in range(N):
                u_func = torch.tensor([tau_dict[(i, j, v, u)].item()
                                       if torch.is_tensor(tau_dict[(i, j, v, u)])
                                       else tau_dict[(i, j, v, u)]
                                       for u in range(N)])
                scores_ms[i, v] = u_func.max() - u_func.min()
                sorted_, _ = torch.sort(u_func, descending=True)
                scores_mm[i, v] = sorted_[0] - sorted_[1]
        i_ms = (scores_ms.argmax() // N).item(); v_ms = (scores_ms.argmax() % N).item()
        i_mm = (scores_mm.argmax() // N).item(); v_mm = (scores_mm.argmax() % N).item()
        opts_ms[j], opts_mm[j] = (i_ms, v_ms), (i_mm, v_mm)
    return opts_ms, opts_mm

opts_max_spread,     opts_max_min_spread     = pick_witnesses(tau)
opts_max_spread_log, opts_max_min_spread_log = pick_witnesses(tau_log)

print('raw — opts_max_spread:    ', opts_max_spread)
print('raw — opts_max_min_spread:', opts_max_min_spread)
print('log — opts_max_spread:    ', opts_max_spread_log)
print('log — opts_max_spread:    ', opts_max_min_spread_log)
# Out:
# raw — opts_max_spread:     {0: (3, 1), 1: (2, 1), 2: (3, 2), 3: (0, 0)}
# raw — opts_max_min_spread: {0: (3, 3), 1: (2, 2), 2: (3, 1), 3: (0, 0)}
# log — opts_max_spread:     {0: (3, 1), 1: (2, 0), 2: (3, 2), 3: (0, 0)}
# log — opts_max_spread:     {0: (3, 3), 1: (2, 2), 2: (3, 1), 3: (0, 0)}

# %% [markdown]
# ## Extract over all permutations — all 8 methods
#
# For each test phi:
# 1. Sample `B` psis (chunked by `B_CHUNK`); compute `mm` and `log_mm`.
# 2. For each of the 8 methods, build cost matrix `C[j, u]`, run brute-force ranking, record rank of truth.
# 3. Track top-1 / top-N / mean rank per method, plus union (any method).
#
# **Cost matrix construction by method `kind`:**
# - `raw` — single witness, raw scale: `C[j,u] = |τ[i_j,j,v_j,u] - mm[i_j,v_j]|`
# - `log` — single witness, log scale: `C[j,u] = |τ_log[i_j,j,v_j,u] - log_mm[i_j,v_j]|`
# - `agg_l2_log` / `agg_l1_log` / `agg_linf_log` — aggregate over (i, v) of `|log_mm - τ_log[:, j, :, u]|` under L2 / L1 / L∞
# - `agg_l2_raw` — same but raw: aggregate L2 of `|mm - τ[:, j, :, u]|`

# %%
B = K2                                                 # psi samples per test phi
B_CHUNK = CHUNK                                           # forward-pass batch size
permutations = list(itertools.permutations(range(N)))

seed = 0
torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)
np.random.seed(seed); random.seed(seed)

# (witness_dict_or_None, tau_dict_or_None, kind)
METHODS = {
    'max-min raw':       (opts_max_min_spread,     tau,     'raw'),
    'max     raw':       (opts_max_spread,         tau,     'raw'),
    'max-min log':       (opts_max_min_spread_log, tau_log, 'log'),
    'max     log':       (opts_max_spread_log,     tau_log, 'log'),
    'aggregate L2  log': (None, None, 'agg_l2_log'),
    'aggregate L1  log': (None, None, 'agg_l1_log'),
    'aggregate L\u221E  log': (None, None, 'agg_linf_log'),
    'aggregate L2  raw': (None, None, 'agg_l2_log'),
    'aggregate L1  raw': (None, None, 'agg_l1_raw'),
    'aggregate L\u221E  raw': (None, None, 'agg_linf_raw'),
}

ranks = {m: [] for m in METHODS}
top1  = {m: 0  for m in METHODS}
topN  = {m: 0  for m in METHODS}
union_top1 = 0
union_topN = 0

def build_cost(kind, opts_dict, tau_dict, mm, log_mm):
    """Return (N, N) cost matrix on CPU."""
    if kind == 'raw':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            p_j = mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - p_j)
        return C
    if kind == 'log':
        C = torch.zeros((N, N))
        for j in range(N):
            i_j, v_j = opts_dict[j]
            lp_j = log_mm[i_j, v_j]
            for u in range(N):
                C[j, u] = torch.abs(tau_dict[(i_j, j, v_j, u)] - lp_j)
        return C

    # aggregate methods: broadcast (N, N) test marginal vs. (N, N, N, N) tau tensor
    if kind == 'agg_l2_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_raw':
        diff = mm.unsqueeze(1).unsqueeze(3) - tau_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    if kind == 'agg_l2_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return (diff.abs() ** 2).sum(dim=(0, 2)).sqrt().cpu()
    if kind == 'agg_l1_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().sum(dim=(0, 2)).cpu()
    if kind == 'agg_linf_log':
        diff = log_mm.unsqueeze(1).unsqueeze(3) - tau_log_tensor
        return diff.abs().amax(dim=(0, 2)).cpu()
    raise ValueError(f'unknown kind: {kind}')

for permutation in permutations:
    base = torch.tensor(permutation, device=DEVICE).long()
    counts = torch.zeros((N, N), device=DEVICE)
    for start in range(0, B, B_CHUNK):
        S = min(B_CHUNK, B - start)
        perm_rep = base.unsqueeze(0).expand(S, -1).contiguous()
        psis = sample_psi_rejection(model, perm_rep)
        counts += F.one_hot(psis.long(), N).float().sum(dim=0)
    mm     = counts / B
    log_mm = torch.log(mm.clamp_min(EPS))

    truth_tup = tuple(permutation)
    print(f'truth = {truth_tup}')
    iter_in_top1 = iter_in_topN = False

    for name, (opts_dict, tau_dict, kind) in METHODS.items():
        C = build_cost(kind, opts_dict, tau_dict, mm, log_mm)
        full   = top_k_assignments(C, k=None)
        top_N  = full[:N]
        rank   = next(i + 1 for i, (p, _) in enumerate(full) if tuple(p.tolist()) == truth_tup)
        in_top = rank <= N
        ranks[name].append(rank)
        if rank == 1:
            top1[name] += 1
            iter_in_top1 = True
        if in_top:
            topN[name] += 1
            iter_in_topN = True
        print(f'  {name:<22}  best={full[0][0].tolist()} (cost {full[0][1]:.4f})  '
              f'rank={rank}/{len(permutations)}  in-top-{N}={in_top}')
    if iter_in_top1: union_top1 += 1
    if iter_in_topN: union_topN += 1
    print()
# Out:
# truth = (0, 1, 2, 3)
#   max-min raw             best=[3, 2, 1, 0] (cost 0.1108)  rank=17/24  in-top-4=False
#   max     raw             best=[3, 2, 1, 0] (cost 0.1072)  rank=12/24  in-top-4=False
#   max-min log             best=[3, 2, 1, 0] (cost 0.4679)  rank=16/24  in-top-4=False
#   max     log             best=[3, 1, 2, 0] (cost 0.3973)  rank=9/24  in-top-4=False
#   aggregate L2  log       best=[1, 3, 2, 0] (cost 3.3196)  rank=20/24  in-top-4=False
#   aggregate L1  log       best=[3, 2, 0, 1] (cost 10.5247)  rank=16/24  in-top-4=False
#   aggregate L∞  log       best=[1, 2, 3, 0] (cost 1.7710)  rank=22/24  in-top-4=False
#   aggregate L2  raw       best=[1, 3, 2, 0] (cost 3.3196)  rank=20/24  in-top-4=False
#   aggregate L1  raw       best=[3, 2, 0, 1] (cost 2.6118)  rank=17/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 2, 3, 0] (cost 0.4067)  rank=20/24  in-top-4=False
#
# truth = (0, 1, 3, 2)
#   max-min raw             best=[3, 1, 2, 0] (cost 0.0605)  rank=15/24  in-top-4=False
#   max     raw             best=[2, 1, 3, 0] (cost 0.1118)  rank=3/24  in-top-4=True
#   max-min log             best=[3, 1, 2, 0] (cost 0.2797)  rank=19/24  in-top-4=False
#   max     log             best=[2, 1, 3, 0] (cost 0.3575)  rank=6/24  in-top-4=False
#   aggregate L2  log       best=[0, 1, 3, 2] (cost 2.4457)  rank=1/24  in-top-4=True
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 8.1016)  rank=3/24  in-top-4=True
#   aggregate L∞  log       best=[0, 1, 3, 2] (cost 1.0844)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[0, 1, 3, 2] (cost 2.4457)  rank=1/24  in-top-4=True
#   aggregate L1  raw       best=[3, 1, 2, 0] (cost 2.0908)  rank=3/24  in-top-4=True
#   aggregate L∞  raw       best=[0, 1, 3, 2] (cost 0.2654)  rank=1/24  in-top-4=True
#
# truth = (0, 2, 1, 3)
#   max-min raw             best=[1, 2, 3, 0] (cost 0.1780)  rank=9/24  in-top-4=False
#   max     raw             best=[1, 2, 3, 0] (cost 0.0977)  rank=10/24  in-top-4=False
#   max-min log             best=[1, 2, 3, 0] (cost 0.6484)  rank=9/24  in-top-4=False
#   max     log             best=[1, 3, 2, 0] (cost 0.5848)  rank=16/24  in-top-4=False
#   aggregate L2  log       best=[2, 3, 1, 0] (cost 3.5307)  rank=10/24  in-top-4=False
#   aggregate L1  log       best=[2, 3, 1, 0] (cost 11.1399)  rank=13/24  in-top-4=False
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 1.7334)  rank=8/24  in-top-4=False
#   aggregate L2  raw       best=[2, 3, 1, 0] (cost 3.5307)  rank=10/24  in-top-4=False
#   aggregate L1  raw       best=[2, 3, 1, 0] (cost 2.7939)  rank=13/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 0.4746)  rank=13/24  in-top-4=False
#
# truth = (0, 2, 3, 1)
#   max-min raw             best=[3, 0, 1, 2] (cost 0.0698)  rank=2/24  in-top-4=True
#   max     raw             best=[1, 0, 3, 2] (cost 0.0627)  rank=2/24  in-top-4=True
#   max-min log             best=[3, 2, 1, 0] (cost 0.3517)  rank=4/24  in-top-4=True
#   max     log             best=[0, 1, 3, 2] (cost 0.2138)  rank=5/24  in-top-4=False
#   aggregate L2  log       best=[1, 2, 3, 0] (cost 3.8698)  rank=13/24  in-top-4=False
#   aggregate L1  log       best=[1, 2, 3, 0] (cost 10.5617)  rank=4/24  in-top-4=True
#   aggregate L∞  log       best=[3, 2, 0, 1] (cost 2.6821)  rank=12/24  in-top-4=False
#   aggregate L2  raw       best=[1, 2, 3, 0] (cost 3.8698)  rank=13/24  in-top-4=False
#   aggregate L1  raw       best=[1, 2, 3, 0] (cost 2.4741)  rank=4/24  in-top-4=True
#   aggregate L∞  raw       best=[3, 2, 0, 1] (cost 0.5049)  rank=13/24  in-top-4=False
#
# truth = (0, 3, 1, 2)
#   max-min raw             best=[0, 1, 2, 3] (cost 0.1548)  rank=13/24  in-top-4=False
#   max     raw             best=[3, 0, 2, 1] (cost 0.2139)  rank=12/24  in-top-4=False
#   max-min log             best=[3, 0, 2, 1] (cost 0.7050)  rank=14/24  in-top-4=False
#   max     log             best=[3, 0, 2, 1] (cost 0.9685)  rank=17/24  in-top-4=False
#   aggregate L2  log       best=[3, 0, 2, 1] (cost 3.3958)  rank=11/24  in-top-4=False
#   aggregate L1  log       best=[2, 0, 1, 3] (cost 11.2188)  rank=9/24  in-top-4=False
#   aggregate L∞  log       best=[3, 0, 2, 1] (cost 1.6150)  rank=14/24  in-top-4=False
#   aggregate L2  raw       best=[3, 0, 2, 1] (cost 3.3958)  rank=11/24  in-top-4=False
#   aggregate L1  raw       best=[2, 0, 1, 3] (cost 2.7310)  rank=5/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 3, 2, 1] (cost 0.4377)  rank=7/24  in-top-4=False
#
# truth = (0, 3, 2, 1)
#   max-min raw             best=[2, 3, 1, 0] (cost 0.0479)  rank=16/24  in-top-4=False
#   max     raw             best=[2, 3, 1, 0] (cost 0.0618)  rank=13/24  in-top-4=False
#   max-min log             best=[2, 3, 1, 0] (cost 0.1315)  rank=17/24  in-top-4=False
#   max     log             best=[2, 3, 1, 0] (cost 0.2880)  rank=9/24  in-top-4=False
#   aggregate L2  log       best=[1, 3, 2, 0] (cost 1.6674)  rank=9/24  in-top-4=False
#   aggregate L1  log       best=[1, 3, 2, 0] (cost 5.3782)  rank=8/24  in-top-4=False
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 0.8515)  rank=5/24  in-top-4=False
#   aggregate L2  raw       best=[1, 3, 2, 0] (cost 1.6674)  rank=9/24  in-top-4=False
#   aggregate L1  raw       best=[1, 3, 2, 0] (cost 1.3516)  rank=13/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 3, 2, 0] (cost 0.1904)  rank=5/24  in-top-4=False
#
# truth = (1, 0, 2, 3)
#   max-min raw             best=[3, 1, 0, 2] (cost 0.1045)  rank=6/24  in-top-4=False
#   max     raw             best=[3, 1, 0, 2] (cost 0.0789)  rank=14/24  in-top-4=False
#   max-min log             best=[3, 1, 0, 2] (cost 0.4050)  rank=9/24  in-top-4=False
#   max     log             best=[3, 1, 0, 2] (cost 0.2631)  rank=19/24  in-top-4=False
#   aggregate L2  log       best=[0, 3, 1, 2] (cost 2.9444)  rank=20/24  in-top-4=False
#   aggregate L1  log       best=[0, 3, 1, 2] (cost 9.5290)  rank=17/24  in-top-4=False
#   aggregate L∞  log       best=[0, 1, 3, 2] (cost 1.3425)  rank=23/24  in-top-4=False
#   aggregate L2  raw       best=[0, 3, 1, 2] (cost 2.9444)  rank=20/24  in-top-4=False
#   aggregate L1  raw       best=[0, 3, 1, 2] (cost 2.3042)  rank=17/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 1, 3, 2] (cost 0.3623)  rank=23/24  in-top-4=False
#
# truth = (1, 0, 3, 2)
#   max-min raw             best=[3, 0, 2, 1] (cost 0.1089)  rank=20/24  in-top-4=False
#   max     raw             best=[2, 0, 3, 1] (cost 0.1917)  rank=8/24  in-top-4=False
#   max-min log             best=[3, 0, 2, 1] (cost 0.4170)  rank=20/24  in-top-4=False
#   max     log             best=[2, 0, 3, 1] (cost 0.5373)  rank=6/24  in-top-4=False
#   aggregate L2  log       best=[0, 1, 3, 2] (cost 4.1855)  rank=6/24  in-top-4=False
#   aggregate L1  log       best=[3, 1, 0, 2] (cost 13.2877)  rank=8/24  in-top-4=False
#   aggregate L∞  log       best=[3, 0, 2, 1] (cost 2.5009)  rank=5/24  in-top-4=False
#   aggregate L2  raw       best=[0, 1, 3, 2] (cost 4.1855)  rank=6/24  in-top-4=False
#   aggregate L1  raw       best=[0, 1, 3, 2] (cost 3.2056)  rank=7/24  in-top-4=False
#   aggregate L∞  raw       best=[3, 0, 2, 1] (cost 0.4653)  rank=5/24  in-top-4=False
#
# truth = (1, 2, 0, 3)
#   max-min raw             best=[1, 2, 0, 3] (cost 0.1736)  rank=1/24  in-top-4=True
#   max     raw             best=[3, 2, 0, 1] (cost 0.1785)  rank=4/24  in-top-4=True
#   max-min log             best=[1, 2, 0, 3] (cost 0.7699)  rank=1/24  in-top-4=True
#   max     log             best=[3, 2, 0, 1] (cost 0.7463)  rank=11/24  in-top-4=False
#   aggregate L2  log       best=[2, 0, 1, 3] (cost 4.0825)  rank=15/24  in-top-4=False
#   aggregate L1  log       best=[0, 2, 1, 3] (cost 13.1543)  rank=13/24  in-top-4=False
#   aggregate L∞  log       best=[0, 3, 1, 2] (cost 2.5786)  rank=21/24  in-top-4=False
#   aggregate L2  raw       best=[2, 0, 1, 3] (cost 4.0825)  rank=15/24  in-top-4=False
#   aggregate L1  raw       best=[0, 2, 1, 3] (cost 3.0693)  rank=12/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 3, 1, 2] (cost 0.4766)  rank=21/24  in-top-4=False
#
# truth = (1, 2, 3, 0)
#   max-min raw             best=[2, 1, 3, 0] (cost 0.1372)  rank=4/24  in-top-4=True
#   max     raw             best=[2, 3, 1, 0] (cost 0.1121)  rank=5/24  in-top-4=False
#   max-min log             best=[2, 1, 3, 0] (cost 0.5479)  rank=4/24  in-top-4=True
#   max     log             best=[1, 3, 2, 0] (cost 0.4583)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[1, 3, 2, 0] (cost 2.4141)  rank=2/24  in-top-4=True
#   aggregate L1  log       best=[1, 3, 2, 0] (cost 7.8649)  rank=2/24  in-top-4=True
#   aggregate L∞  log       best=[1, 2, 3, 0] (cost 1.1296)  rank=1/24  in-top-4=True
#   aggregate L2  raw       best=[1, 3, 2, 0] (cost 2.4141)  rank=2/24  in-top-4=True
#   aggregate L1  raw       best=[1, 3, 2, 0] (cost 1.9531)  rank=2/24  in-top-4=True
#   aggregate L∞  raw       best=[1, 2, 3, 0] (cost 0.2637)  rank=1/24  in-top-4=True
#
# truth = (1, 3, 0, 2)
#   max-min raw             best=[1, 2, 3, 0] (cost 0.0999)  rank=13/24  in-top-4=False
#   max     raw             best=[1, 3, 2, 0] (cost 0.0681)  rank=7/24  in-top-4=False
#   max-min log             best=[1, 2, 3, 0] (cost 0.4296)  rank=13/24  in-top-4=False
#   max     log             best=[1, 3, 2, 0] (cost 0.3173)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[2, 3, 1, 0] (cost 2.2510)  rank=6/24  in-top-4=False
#   aggregate L1  log       best=[2, 3, 1, 0] (cost 7.3923)  rank=5/24  in-top-4=False
#   aggregate L∞  log       best=[2, 0, 1, 3] (cost 0.9918)  rank=17/24  in-top-4=False
#   aggregate L2  raw       best=[2, 3, 1, 0] (cost 2.2510)  rank=6/24  in-top-4=False
#   aggregate L1  raw       best=[2, 3, 1, 0] (cost 1.8223)  rank=7/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 3, 1, 2] (cost 0.2307)  rank=15/24  in-top-4=False
#
# truth = (1, 3, 2, 0)
#   max-min raw             best=[1, 2, 0, 3] (cost 0.1130)  rank=8/24  in-top-4=False
#   max     raw             best=[0, 1, 3, 2] (cost 0.0652)  rank=24/24  in-top-4=False
#   max-min log             best=[1, 2, 0, 3] (cost 0.4350)  rank=3/24  in-top-4=True
#   max     log             best=[0, 1, 3, 2] (cost 0.6132)  rank=18/24  in-top-4=False
#   aggregate L2  log       best=[0, 3, 1, 2] (cost 2.6064)  rank=14/24  in-top-4=False
#   aggregate L1  log       best=[0, 3, 1, 2] (cost 7.6959)  rank=18/24  in-top-4=False
#   aggregate L∞  log       best=[0, 1, 3, 2] (cost 1.4271)  rank=13/24  in-top-4=False
#   aggregate L2  raw       best=[0, 3, 1, 2] (cost 2.6064)  rank=14/24  in-top-4=False
#   aggregate L1  raw       best=[0, 3, 1, 2] (cost 1.9233)  rank=21/24  in-top-4=False
#   aggregate L∞  raw       best=[3, 1, 0, 2] (cost 0.4260)  rank=23/24  in-top-4=False
#
# truth = (2, 0, 1, 3)
#   max-min raw             best=[3, 0, 2, 1] (cost 0.1245)  rank=11/24  in-top-4=False
#   max     raw             best=[2, 0, 3, 1] (cost 0.1448)  rank=13/24  in-top-4=False
#   max-min log             best=[3, 0, 2, 1] (cost 0.5993)  rank=13/24  in-top-4=False
#   max     log             best=[0, 2, 3, 1] (cost 0.5805)  rank=16/24  in-top-4=False
#   aggregate L2  log       best=[2, 0, 3, 1] (cost 2.6768)  rank=3/24  in-top-4=True
#   aggregate L1  log       best=[3, 0, 2, 1] (cost 8.3576)  rank=12/24  in-top-4=False
#   aggregate L∞  log       best=[2, 0, 3, 1] (cost 1.6680)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[2, 0, 3, 1] (cost 2.6768)  rank=3/24  in-top-4=True
#   aggregate L1  raw       best=[3, 0, 2, 1] (cost 2.0024)  rank=8/24  in-top-4=False
#   aggregate L∞  raw       best=[2, 0, 3, 1] (cost 0.3511)  rank=2/24  in-top-4=True
#
# truth = (2, 0, 3, 1)
#   max-min raw             best=[3, 2, 1, 0] (cost 0.1514)  rank=24/24  in-top-4=False
#   max     raw             best=[3, 1, 2, 0] (cost 0.1184)  rank=23/24  in-top-4=False
#   max-min log             best=[3, 2, 1, 0] (cost 0.5823)  rank=24/24  in-top-4=False
#   max     log             best=[3, 1, 2, 0] (cost 0.4416)  rank=24/24  in-top-4=False
#   aggregate L2  log       best=[3, 0, 2, 1] (cost 3.4214)  rank=19/24  in-top-4=False
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 10.5923)  rank=20/24  in-top-4=False
#   aggregate L∞  log       best=[1, 3, 2, 0] (cost 2.1430)  rank=20/24  in-top-4=False
#   aggregate L2  raw       best=[3, 0, 2, 1] (cost 3.4214)  rank=19/24  in-top-4=False
#   aggregate L1  raw       best=[0, 3, 2, 1] (cost 2.4722)  rank=22/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 3, 2, 0] (cost 0.3787)  rank=22/24  in-top-4=False
#
# truth = (2, 1, 0, 3)
#   max-min raw             best=[2, 0, 3, 1] (cost 0.1719)  rank=3/24  in-top-4=True
#   max     raw             best=[0, 2, 3, 1] (cost 0.1287)  rank=10/24  in-top-4=False
#   max-min log             best=[2, 0, 3, 1] (cost 0.7078)  rank=4/24  in-top-4=True
#   max     log             best=[2, 0, 3, 1] (cost 0.7419)  rank=10/24  in-top-4=False
#   aggregate L2  log       best=[2, 0, 1, 3] (cost 3.0372)  rank=2/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 1, 3] (cost 10.2983)  rank=2/24  in-top-4=True
#   aggregate L∞  log       best=[2, 0, 1, 3] (cost 1.3567)  rank=2/24  in-top-4=True
#   aggregate L2  raw       best=[2, 0, 1, 3] (cost 3.0372)  rank=2/24  in-top-4=True
#   aggregate L1  raw       best=[2, 1, 0, 3] (cost 2.4429)  rank=1/24  in-top-4=True
#   aggregate L∞  raw       best=[2, 0, 1, 3] (cost 0.3054)  rank=2/24  in-top-4=True
#
# truth = (2, 1, 3, 0)
#   max-min raw             best=[3, 2, 1, 0] (cost 0.1733)  rank=16/24  in-top-4=False
#   max     raw             best=[3, 2, 1, 0] (cost 0.1165)  rank=12/24  in-top-4=False
#   max-min log             best=[3, 2, 1, 0] (cost 0.6214)  rank=15/24  in-top-4=False
#   max     log             best=[3, 1, 2, 0] (cost 0.6046)  rank=11/24  in-top-4=False
#   aggregate L2  log       best=[3, 1, 2, 0] (cost 3.8971)  rank=4/24  in-top-4=True
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 12.2277)  rank=8/24  in-top-4=False
#   aggregate L∞  log       best=[3, 1, 2, 0] (cost 2.2744)  rank=4/24  in-top-4=True
#   aggregate L2  raw       best=[3, 1, 2, 0] (cost 3.8971)  rank=4/24  in-top-4=True
#   aggregate L1  raw       best=[3, 2, 1, 0] (cost 2.9438)  rank=9/24  in-top-4=False
#   aggregate L∞  raw       best=[3, 1, 2, 0] (cost 0.4482)  rank=5/24  in-top-4=False
#
# truth = (2, 3, 0, 1)
#   max-min raw             best=[0, 1, 2, 3] (cost 0.1021)  rank=6/24  in-top-4=False
#   max     raw             best=[3, 1, 0, 2] (cost 0.0100)  rank=11/24  in-top-4=False
#   max-min log             best=[1, 3, 0, 2] (cost 0.3825)  rank=4/24  in-top-4=True
#   max     log             best=[0, 3, 1, 2] (cost 0.2434)  rank=7/24  in-top-4=False
#   aggregate L2  log       best=[2, 1, 0, 3] (cost 2.1404)  rank=8/24  in-top-4=False
#   aggregate L1  log       best=[3, 1, 0, 2] (cost 6.4096)  rank=13/24  in-top-4=False
#   aggregate L∞  log       best=[1, 2, 0, 3] (cost 1.1388)  rank=15/24  in-top-4=False
#   aggregate L2  raw       best=[2, 1, 0, 3] (cost 2.1404)  rank=8/24  in-top-4=False
#   aggregate L1  raw       best=[3, 1, 0, 2] (cost 1.5723)  rank=10/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 3, 2, 0] (cost 0.3005)  rank=12/24  in-top-4=False
#
# truth = (2, 3, 1, 0)
#   max-min raw             best=[0, 2, 3, 1] (cost 0.0874)  rank=23/24  in-top-4=False
#   max     raw             best=[0, 2, 3, 1] (cost 0.1130)  rank=22/24  in-top-4=False
#   max-min log             best=[0, 2, 3, 1] (cost 0.4314)  rank=23/24  in-top-4=False
#   max     log             best=[1, 0, 3, 2] (cost 0.2197)  rank=22/24  in-top-4=False
#   aggregate L2  log       best=[1, 2, 3, 0] (cost 2.4390)  rank=17/24  in-top-4=False
#   aggregate L1  log       best=[1, 2, 3, 0] (cost 8.0248)  rank=21/24  in-top-4=False
#   aggregate L∞  log       best=[0, 2, 3, 1] (cost 1.3844)  rank=14/24  in-top-4=False
#   aggregate L2  raw       best=[1, 2, 3, 0] (cost 2.4390)  rank=17/24  in-top-4=False
#   aggregate L1  raw       best=[1, 2, 3, 0] (cost 1.8711)  rank=21/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 0.3108)  rank=14/24  in-top-4=False
#
# truth = (3, 0, 1, 2)
#   max-min raw             best=[2, 0, 3, 1] (cost 0.1357)  rank=18/24  in-top-4=False
#   max     raw             best=[1, 0, 2, 3] (cost 0.0774)  rank=15/24  in-top-4=False
#   max-min log             best=[2, 0, 3, 1] (cost 0.5126)  rank=17/24  in-top-4=False
#   max     log             best=[1, 0, 2, 3] (cost 0.6729)  rank=13/24  in-top-4=False
#   aggregate L2  log       best=[2, 0, 1, 3] (cost 3.5266)  rank=4/24  in-top-4=True
#   aggregate L1  log       best=[2, 0, 1, 3] (cost 11.8322)  rank=6/24  in-top-4=False
#   aggregate L∞  log       best=[2, 0, 3, 1] (cost 1.8082)  rank=7/24  in-top-4=False
#   aggregate L2  raw       best=[2, 0, 1, 3] (cost 3.5266)  rank=4/24  in-top-4=True
#   aggregate L1  raw       best=[2, 0, 1, 3] (cost 2.9399)  rank=6/24  in-top-4=False
#   aggregate L∞  raw       best=[2, 0, 3, 1] (cost 0.4995)  rank=7/24  in-top-4=False
#
# truth = (3, 0, 2, 1)
#   max-min raw             best=[1, 3, 2, 0] (cost 0.1462)  rank=19/24  in-top-4=False
#   max     raw             best=[3, 1, 2, 0] (cost 0.2434)  rank=7/24  in-top-4=False
#   max-min log             best=[1, 3, 2, 0] (cost 0.6394)  rank=18/24  in-top-4=False
#   max     log             best=[3, 1, 2, 0] (cost 0.9682)  rank=11/24  in-top-4=False
#   aggregate L2  log       best=[0, 3, 2, 1] (cost 3.1546)  rank=6/24  in-top-4=False
#   aggregate L1  log       best=[1, 3, 2, 0] (cost 9.8562)  rank=13/24  in-top-4=False
#   aggregate L∞  log       best=[0, 3, 2, 1] (cost 1.6614)  rank=7/24  in-top-4=False
#   aggregate L2  raw       best=[0, 3, 2, 1] (cost 3.1546)  rank=6/24  in-top-4=False
#   aggregate L1  raw       best=[1, 3, 2, 0] (cost 2.3784)  rank=13/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 3, 2, 1] (cost 0.5002)  rank=11/24  in-top-4=False
#
# truth = (3, 1, 0, 2)
#   max-min raw             best=[3, 2, 1, 0] (cost 0.0684)  rank=4/24  in-top-4=True
#   max     raw             best=[3, 2, 1, 0] (cost 0.0930)  rank=12/24  in-top-4=False
#   max-min log             best=[3, 2, 1, 0] (cost 0.2622)  rank=7/24  in-top-4=False
#   max     log             best=[2, 0, 1, 3] (cost 0.3263)  rank=14/24  in-top-4=False
#   aggregate L2  log       best=[0, 2, 3, 1] (cost 2.6280)  rank=15/24  in-top-4=False
#   aggregate L1  log       best=[0, 2, 3, 1] (cost 8.7032)  rank=13/24  in-top-4=False
#   aggregate L∞  log       best=[0, 2, 3, 1] (cost 1.1778)  rank=15/24  in-top-4=False
#   aggregate L2  raw       best=[0, 2, 3, 1] (cost 2.6280)  rank=15/24  in-top-4=False
#   aggregate L1  raw       best=[3, 2, 1, 0] (cost 2.1138)  rank=12/24  in-top-4=False
#   aggregate L∞  raw       best=[0, 2, 3, 1] (cost 0.2954)  rank=13/24  in-top-4=False
#
# truth = (3, 1, 2, 0)
#   max-min raw             best=[2, 1, 3, 0] (cost 0.1431)  rank=6/24  in-top-4=False
#   max     raw             best=[1, 3, 2, 0] (cost 0.1150)  rank=4/24  in-top-4=True
#   max-min log             best=[2, 1, 3, 0] (cost 0.6721)  rank=2/24  in-top-4=True
#   max     log             best=[1, 3, 2, 0] (cost 0.8965)  rank=3/24  in-top-4=True
#   aggregate L2  log       best=[2, 1, 0, 3] (cost 3.5593)  rank=9/24  in-top-4=False
#   aggregate L1  log       best=[2, 1, 3, 0] (cost 10.7683)  rank=4/24  in-top-4=True
#   aggregate L∞  log       best=[2, 0, 1, 3] (cost 1.8328)  rank=16/24  in-top-4=False
#   aggregate L2  raw       best=[2, 1, 0, 3] (cost 3.5593)  rank=9/24  in-top-4=False
#   aggregate L1  raw       best=[2, 1, 3, 0] (cost 2.6440)  rank=7/24  in-top-4=False
#   aggregate L∞  raw       best=[2, 0, 3, 1] (cost 0.4468)  rank=17/24  in-top-4=False
#
# truth = (3, 2, 0, 1)
#   max-min raw             best=[3, 2, 1, 0] (cost 0.1353)  rank=4/24  in-top-4=True
#   max     raw             best=[1, 2, 3, 0] (cost 0.1338)  rank=16/24  in-top-4=False
#   max-min log             best=[3, 2, 1, 0] (cost 0.5313)  rank=7/24  in-top-4=False
#   max     log             best=[1, 2, 3, 0] (cost 0.5182)  rank=22/24  in-top-4=False
#   aggregate L2  log       best=[1, 2, 3, 0] (cost 3.2334)  rank=8/24  in-top-4=False
#   aggregate L1  log       best=[1, 2, 3, 0] (cost 9.5714)  rank=8/24  in-top-4=False
#   aggregate L∞  log       best=[1, 2, 3, 0] (cost 2.1192)  rank=9/24  in-top-4=False
#   aggregate L2  raw       best=[1, 2, 3, 0] (cost 3.2334)  rank=8/24  in-top-4=False
#   aggregate L1  raw       best=[0, 2, 3, 1] (cost 2.2407)  rank=7/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 2, 3, 0] (cost 0.4199)  rank=10/24  in-top-4=False
#
# truth = (3, 2, 1, 0)
#   max-min raw             best=[3, 1, 2, 0] (cost 0.1841)  rank=4/24  in-top-4=True
#   max     raw             best=[3, 1, 2, 0] (cost 0.3215)  rank=5/24  in-top-4=False
#   max-min log             best=[3, 1, 2, 0] (cost 0.8251)  rank=4/24  in-top-4=True
#   max     log             best=[3, 1, 2, 0] (cost 1.4081)  rank=2/24  in-top-4=True
#   aggregate L2  log       best=[1, 3, 2, 0] (cost 4.4830)  rank=10/24  in-top-4=False
#   aggregate L1  log       best=[3, 1, 2, 0] (cost 14.2778)  rank=8/24  in-top-4=False
#   aggregate L∞  log       best=[2, 3, 1, 0] (cost 2.2051)  rank=8/24  in-top-4=False
#   aggregate L2  raw       best=[1, 3, 2, 0] (cost 4.4830)  rank=10/24  in-top-4=False
#   aggregate L1  raw       best=[3, 1, 2, 0] (cost 3.3809)  rank=6/24  in-top-4=False
#   aggregate L∞  raw       best=[1, 3, 0, 2] (cost 0.5593)  rank=22/24  in-top-4=False

# %%
T = len(permutations)
print('=' * 90)
print(f'Summary over all {T} permutations of S_{N}')
print(f'Random baselines: top-1 ~ {100/T:.1f}%, top-{N} ~ {100*N/T:.1f}%, mean rank ~ {(T+1)/2:.1f}')
print('-' * 90)
print(f'{"method":<24} {"top-1":>10} {"top-N":>10} {"mean rank":>14}')
for m in METHODS:
    print(f'{m:<24} {top1[m]}/{T:<6} {topN[m]}/{T:<6} {sum(ranks[m])/T:>12.2f}')
print('-' * 90)
print(f'{"union (any method)":<24} {union_top1}/{T:<6} {union_topN}/{T:<6}')
# Out:
# ==========================================================================================
# Summary over all 24 permutations of S_4
# Random baselines: top-1 ~ 4.2%, top-4 ~ 16.7%, mean rank ~ 12.5
# ------------------------------------------------------------------------------------------
# method                        top-1      top-N      mean rank
# max-min raw              1/24     7/24            10.92
# max     raw              0/24     4/24            11.00
# max-min log              1/24     8/24            11.12
# max     log              0/24     4/24            11.54
# aggregate L2  log        1/24     6/24             9.67
# aggregate L1  log        0/24     5/24            10.17
# aggregate L∞  log        2/24     5/24            10.88
# aggregate L2  raw        1/24     6/24             9.67
# aggregate L1  raw        1/24     4/24            10.12
# aggregate L∞  raw        2/24     4/24            11.83
# ------------------------------------------------------------------------------------------
# union (any method)       4/24     15/24
